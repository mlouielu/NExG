# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC1')
evalObject.setSimsBound(30)
dataObject = evalObject.setDataObject()
# dataObject.setStepSize(0.02)
lowerBound = [0.2, -1.0]
upperBound = [0.4, -0.8]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.7, 0.9]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# 2022-07-10 11:50:40.656400: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-10 11:50:40.656422: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/manish/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# Run *** 0
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 76
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0027008735961005135
# Starting distance is very less
# Best robustness -0.011477483847079473
# Final distance 0.0027008735961005135
# Final simulation: 1
# Time taken: 0.00012969970703125
# idx **** 0
# Run *** 0
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 2022-07-10 11:50:42.287598: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-10 11:50:42.287621: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-10 11:50:42.287636: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (manish-yoga-ubuntu): /proc/driver/nvidia/version does not exist
# 2022-07-10 11:50:42.287807: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 71
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1483585527200431
# Best robustness -0.01374140553394132
# Final distance 0.0010318324244207703
# Final simulation: 15
# Time taken: 2.588068723678589
# idx **** 1
# Run *** 1
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11167039497555047
# Best robustness 0.0033483490683160477
# Final distance 0.005406891118129234
# Final simulation: 31
# Time taken: 5.461180686950684
# idx **** 2
# Run *** 2
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 84
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.055373217898052385
# Best robustness -0.057233616996116954
# Final distance 0.0015347928872197214
# Final simulation: 11
# Time taken: 1.9234702587127686
# idx **** 3
# Run *** 3
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 75
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04361698794212084
# Best robustness -0.011472440194226108
# Final distance 0.0015605920498129068
# Final simulation: 11
# Time taken: 1.8174500465393066
# idx **** 4
# Run *** 4
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14917516793294414
# Best robustness -0.018483084789425286
# Final distance 0.0014868622049175287
# Final simulation: 6
# Time taken: 0.921076774597168
# idx **** 5
# Run *** 5
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.00566602940368698
# Starting distance is very less
# Best robustness -0.015026532906528334
# Final distance 0.00566602940368698
# Final simulation: 1
# Time taken: 0.00012803077697753906
# idx **** 5
# Run *** 5
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15174019542250514
# Best robustness -0.047659672468163494
# Final distance 0.01480289736786341
# Final simulation: 31
# Time taken: 5.414280652999878
# idx **** 6
# Run *** 6
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 71
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06434151369669742
# Best robustness -0.0006046710109277598
# Final distance 0.0008605961768706268
# Final simulation: 13
# Time taken: 2.1625449657440186
# idx **** 7
# Run *** 7
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 74
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.013349168273912878
# Starting distance is very less
# Best robustness -0.0006044223199237475
# Final distance 0.013349168273912878
# Final simulation: 1
# Time taken: 0.00012993812561035156
# idx **** 7
# Run *** 7
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 86
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.039321538432477016
# Best robustness -0.002483953563749197
# Final distance 0.0019492658794195384
# Final simulation: 3
# Time taken: 0.3870224952697754
# idx **** 8
# Run *** 8
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07425789446098709
# Best robustness -0.03951468474064379
# Final distance 0.0017543805427084615
# Final simulation: 11
# Time taken: 1.8303101062774658
# idx **** 9
# Run *** 9
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13530517670120593
# Best robustness 0.0002933830560694073
# Final distance 0.0018478114577343016
# Final simulation: 11
# Time taken: 1.7944929599761963
# idx **** 10
# Run *** 10
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18532862658596885
# Best robustness -0.01788542372731572
# Final distance 0.0015442062908831737
# Final simulation: 12
# Time taken: 1.989731788635254
# idx **** 11
# Run *** 11
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12004016957670252
# Best robustness -0.00852813110240841
# Final distance 0.00182362368959389
# Final simulation: 12
# Time taken: 2.1650590896606445
# idx **** 12
# Run *** 12
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05877679593876082
# Best robustness -0.004101765549134551
# Final distance 0.001478062060513328
# Final simulation: 13
# Time taken: 2.1836562156677246
# idx **** 13
# Run *** 13
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.003103428701409185
# Starting distance is very less
# Best robustness 0.0016191354279548875
# Final distance 0.003103428701409185
# Final simulation: 1
# Time taken: 0.00013375282287597656
# idx **** 13
# Run *** 13
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11368630148966434
# Best robustness -0.03158020446989235
# Final distance 0.0011224490156984564
# Final simulation: 6
# Time taken: 0.9170928001403809
# idx **** 14
# Run *** 14
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.29894747161106344
# Best robustness -0.007896491749425305
# Final distance 0.001013371283457823
# Final simulation: 7
# Time taken: 1.0994889736175537
# idx **** 15
# Run *** 15
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 77
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.017930530053376904
# Starting distance is very less
# Best robustness -0.0021038058131105375
# Final distance 0.017930530053376904
# Final simulation: 1
# Time taken: 0.00012826919555664062
# idx **** 15
# Run *** 15
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1573107975453125
# Best robustness -0.0015974170867021353
# Final distance 0.001463553580407931
# Final simulation: 6
# Time taken: 0.9177460670471191
# idx **** 16
# Run *** 16
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17496365843848716
# Best robustness 0.0031756297322206306
# Final distance 0.0005577007123488381
# Final simulation: 7
# Time taken: 1.0870838165283203
# idx **** 17
# Run *** 17
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12406292425186229
# Best robustness -0.043400877482440925
# Final distance 0.004477595334721536
# Final simulation: 31
# Time taken: 5.419934511184692
# idx **** 18
# Run *** 18
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2220880085506432
# Best robustness -0.0034315099618058564
# Final distance 0.001185754891119212
# Final simulation: 11
# Time taken: 1.8372249603271484
# idx **** 19
# Run *** 19
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 81
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.019207011083851505
# Starting distance is very less
# Best robustness 0.01058913878201706
# Final distance 0.019207011083851505
# Final simulation: 1
# Time taken: 0.0001277923583984375
# idx **** 19
# Run *** 19
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 79
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05701599760908966
# Best robustness -0.0019369278791332989
# Final distance 0.001615308651714035
# Final simulation: 6
# Time taken: 0.9151747226715088
# idx **** 20
# Run *** 20
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 75
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04886369708329501
# Best robustness -0.004491573375643543
# Final distance 0.0017390624315094673
# Final simulation: 13
# Time taken: 2.342717409133911
# idx **** 21
# Run *** 21
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.045846226364792
# Best robustness 0.001881380522796794
# Final distance 0.0011824866663689545
# Final simulation: 3
# Time taken: 0.3967411518096924
# idx **** 22
# Run *** 22
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.060062102127709883
# Best robustness 0.0042702480843727075
# Final distance 0.0016020860271131656
# Final simulation: 8
# Time taken: 1.2994780540466309
# idx **** 23
# Run *** 23
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 80
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.039278141001867106
# Best robustness -0.017364131293699292
# Final distance 0.0015377792817634255
# Final simulation: 17
# Time taken: 2.9151153564453125
# idx **** 24
# Run *** 24
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.28669082616154495
# Best robustness -0.004350443323007158
# Final distance 0.00170118544450578
# Final simulation: 9
# Time taken: 1.4747791290283203
# idx **** 25
# Run *** 25
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09308299730247876
# Best robustness -0.008507955183518656
# Final distance 0.027009513365799456
# Final simulation: 31
# Time taken: 5.367694616317749
# idx **** 26
# Run *** 26
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2936527174221303
# Best robustness 0.005485631963280502
# Final distance 0.0019115967688574835
# Final simulation: 16
# Time taken: 2.718991756439209
# idx **** 27
# Run *** 27
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11082268544601238
# Best robustness -0.005865781317785479
# Final distance 0.0045641608027662
# Final simulation: 31
# Time taken: 5.535851955413818
# idx **** 28
# Run *** 28
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 82
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04904864963709891
# Best robustness -0.011339330400184977
# Final distance 0.0009760434373241743
# Final simulation: 4
# Time taken: 0.5695493221282959
# idx **** 29
# Run *** 29
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09718789138484914
# Best robustness -0.038563607759300456
# Final distance 0.0018479755827814327
# Final simulation: 8
# Time taken: 1.3078174591064453
# idx **** 30
# Run *** 30
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17553933426650803
# Best robustness -0.03292050079670461
# Final distance 0.000971234422480683
# Final simulation: 8
# Time taken: 1.304030179977417
# idx **** 31
# Run *** 31
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11529910981682273
# Best robustness 0.00607054568195986
# Final distance 0.0009984828377749204
# Final simulation: 6
# Time taken: 0.9420011043548584
# idx **** 32
# Run *** 32
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14909434443050776
# Best robustness -0.010831242407621344
# Final distance 0.0014994477604818991
# Final simulation: 7
# Time taken: 1.113264799118042
# idx **** 33
# Run *** 33
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 86
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.030110123062216214
# Best robustness -0.0066400121263797685
# Final distance 0.0012142540096550906
# Final simulation: 10
# Time taken: 1.6707782745361328
# idx **** 34
# Run *** 34
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09374583171520896
# Best robustness -0.0055570889090762465
# Final distance 0.0045466317056985775
# Final simulation: 31
# Time taken: 5.350578308105469
# idx **** 35
# Run *** 35
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 87
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07772128652525506
# Best robustness -0.007453577926843424
# Final distance 0.0057130705264517865
# Final simulation: 31
# Time taken: 5.551888704299927
# idx **** 36
# Run *** 36
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06838727538018001
# Best robustness -0.037465408749666584
# Final distance 0.0019323963730282993
# Final simulation: 13
# Time taken: 2.2163729667663574
# idx **** 37
# Run *** 37
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.34987614953273016
# Best robustness -0.05047090293281187
# Final distance 0.001962526629951239
# Final simulation: 26
# Time taken: 4.536361217498779
# idx **** 38
# Run *** 38
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.031502681412960885
# Best robustness -0.0474498519271469
# Final distance 0.0016718854981504297
# Final simulation: 10
# Time taken: 1.6780190467834473
# idx **** 39
# Run *** 39
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 75
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07961258231879152
# Best robustness -0.020878193822375435
# Final distance 0.0011973778030453079
# Final simulation: 9
# Time taken: 1.4810242652893066
# idx **** 40
# Run *** 40
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 74
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10600677729016261
# Best robustness -0.010965790383753005
# Final distance 0.0007966338363519461
# Final simulation: 5
# Time taken: 0.7462544441223145
# idx **** 41
# Run *** 41
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12311389793011915
# Best robustness -0.01112026980491898
# Final distance 0.0012479289820726996
# Final simulation: 12
# Time taken: 1.9875354766845703
# idx **** 42
# Run *** 42
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09637169770651145
# Best robustness -0.025929122771156887
# Final distance 0.0003612880902896363
# Final simulation: 7
# Time taken: 1.1000289916992188
# idx **** 43
# Run *** 43
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19813714131116114
# Best robustness -0.006273887497949826
# Final distance 0.0009735479575973471
# Final simulation: 4
# Time taken: 0.5633838176727295
# idx **** 44
# Run *** 44
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14851073669771012
# Best robustness -0.002947439288333964
# Final distance 0.0014864457943228229
# Final simulation: 12
# Time taken: 2.042239189147949
# idx **** 45
# Run *** 45
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 87
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03690989657437055
# Best robustness 0.005860557652438869
# Final distance 0.0014846983551177575
# Final simulation: 6
# Time taken: 0.9334697723388672
# idx **** 46
# Run *** 46
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.270708021958464
# Best robustness 0.002207874568709134
# Final distance 0.005536138814601625
# Final simulation: 31
# Time taken: 5.4467387199401855
# idx **** 47
# Run *** 47
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 83
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03165957550359227
# Best robustness 0.004446118465237459
# Final distance 0.0018952915412284977
# Final simulation: 3
# Time taken: 0.39996933937072754
# idx **** 48
# Run *** 48
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 81
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0940242821054362
# Best robustness -0.027125979266891864
# Final distance 0.0016603171715092188
# Final simulation: 19
# Time taken: 3.302811861038208
# idx **** 49
# Run *** 49
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04510110776756226
# Best robustness 0.004072517294501532
# Final distance 0.001892643727712385
# Final simulation: 6
# Time taken: 0.9264967441558838
# idx **** 50
# Run *** 50
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12708593274613983
# Best robustness -0.003422205796661526
# Final distance 0.0016024873096930985
# Final simulation: 17
# Time taken: 2.9128823280334473
# idx **** 51
# Run *** 51
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025225792677763797
# Best robustness -0.041647992940716305
# Final distance 0.0008101824187741861
# Final simulation: 6
# Time taken: 0.9377751350402832
# idx **** 52
# Run *** 52
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.050687491676916795
# Best robustness -0.009431972460469229
# Final distance 0.0013877330609660594
# Final simulation: 8
# Time taken: 1.4707281589508057
# idx **** 53
# Run *** 53
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 87
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1402197425659522
# Best robustness -0.004907228817705722
# Final distance 0.0013686242969623873
# Final simulation: 8
# Time taken: 1.3196239471435547
# idx **** 54
# Run *** 54
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1018842896612279
# Best robustness -0.0033271164065340475
# Final distance 0.001640116980486524
# Final simulation: 10
# Time taken: 1.6800017356872559
# idx **** 55
# Run *** 55
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0959161440394613
# Best robustness -0.008702089137801905
# Final distance 0.0009828988435012548
# Final simulation: 8
# Time taken: 1.3027617931365967
# idx **** 56
# Run *** 56
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 78
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05756585356210669
# Best robustness -0.005560595592020712
# Final distance 0.004065782316856269
# Final simulation: 31
# Time taken: 5.642161130905151
# idx **** 57
# Run *** 57
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09617181211322026
# Best robustness 0.0021661795648018622
# Final distance 0.0015705258368853476
# Final simulation: 10
# Time taken: 1.758314847946167
# idx **** 58
# Run *** 58
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 86
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0786723214506086
# Best robustness -0.005753616423870178
# Final distance 0.0014394356153532753
# Final simulation: 13
# Time taken: 2.244687795639038
# idx **** 59
# Run *** 59
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06368681619447016
# Best robustness -0.007278119778241221
# Final distance 0.0019638814422798163
# Final simulation: 9
# Time taken: 1.5466179847717285
# idx **** 60
# Run *** 60
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 78
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0574568064412364
# Best robustness -0.009665697587300126
# Final distance 0.0007149208147962306
# Final simulation: 22
# Time taken: 4.071469783782959
# idx **** 61
# Run *** 61
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 73
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0902650367237686
# Best robustness 0.009572531717658705
# Final distance 0.001616333868914991
# Final simulation: 11
# Time taken: 1.9080455303192139
# idx **** 62
# Run *** 62
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04468425949626388
# Best robustness -0.0429172754749344
# Final distance 0.004920819795381957
# Final simulation: 31
# Time taken: 5.67732310295105
# idx **** 63
# Run *** 63
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.054482021615923464
# Best robustness -0.007321349216031503
# Final distance 0.0013133094023717446
# Final simulation: 9
# Time taken: 1.512242078781128
# idx **** 64
# Run *** 64
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 81
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.016331037384710173
# Starting distance is very less
# Best robustness -0.009462271820738333
# Final distance 0.016331037384710173
# Final simulation: 1
# Time taken: 0.0001201629638671875
# idx **** 64
# Run *** 64
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 73
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09115782932435569
# Best robustness -0.0005447715283216636
# Final distance 0.0019351654350514484
# Final simulation: 10
# Time taken: 1.681396722793579
# idx **** 65
# Run *** 65
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33748350098510066
# Best robustness -0.0005280756779990625
# Final distance 0.0010996373592357805
# Final simulation: 17
# Time taken: 3.0482265949249268
# idx **** 66
# Run *** 66
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14314916512072381
# Best robustness 0.0014066007889353416
# Final distance 0.0013002168144047018
# Final simulation: 17
# Time taken: 3.1527090072631836
# idx **** 67
# Run *** 67
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08198902517693933
# Best robustness -0.00188522141032621
# Final distance 0.0009999340080897037
# Final simulation: 5
# Time taken: 0.760094165802002
# idx **** 68
# Run *** 68
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08497859445337685
# Best robustness 0.0008402068378293714
# Final distance 0.0016514761309768318
# Final simulation: 10
# Time taken: 1.6923491954803467
# idx **** 69
# Run *** 69
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 73
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.022067763452700055
# Best robustness -0.010891612020081154
# Final distance 0.001195501503617164
# Final simulation: 7
# Time taken: 1.1186163425445557
# idx **** 70
# Run *** 70
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 71
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025581417815527314
# Best robustness -0.00993958370469239
# Final distance 0.0013344624285322262
# Final simulation: 10
# Time taken: 1.689478874206543
# idx **** 71
# Run *** 71
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09786756911454139
# Best robustness -0.011804094348487393
# Final distance 0.001273433980144951
# Final simulation: 7
# Time taken: 1.1086492538452148
# idx **** 72
# Run *** 72
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02835817979547253
# Best robustness -0.013515499884436677
# Final distance 0.0013632037737074977
# Final simulation: 6
# Time taken: 0.9405367374420166
# idx **** 73
# Run *** 73
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04924179044336081
# Best robustness 0.008217104177147161
# Final distance 0.00816847132728843
# Final simulation: 31
# Time taken: 5.478504657745361
# idx **** 74
# Run *** 74
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17296195504749212
# Best robustness -0.007453577926843424
# Final distance 0.010668435264852217
# Final simulation: 31
# Time taken: 5.56535005569458
# idx **** 75
# Run *** 75
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08337361164495287
# Best robustness -0.006480171150535119
# Final distance 0.0007691292912834378
# Final simulation: 8
# Time taken: 1.328373908996582
# idx **** 76
# Run *** 76
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0536849563264192
# Best robustness -0.00041005772404212326
# Final distance 0.0016982995574351199
# Final simulation: 12
# Time taken: 2.0348823070526123
# idx **** 77
# Run *** 77
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16225739460495217
# Best robustness -0.03831310844482316
# Final distance 0.0016731422356598467
# Final simulation: 13
# Time taken: 2.2407751083374023
# idx **** 78
# Run *** 78
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14271995274967952
# Best robustness 0.00354482047288851
# Final distance 0.0016918780913547987
# Final simulation: 9
# Time taken: 1.527531623840332
# idx **** 79
# Run *** 79
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11908263467261436
# Best robustness -0.0057698131330129465
# Final distance 0.001560373616189121
# Final simulation: 7
# Time taken: 1.1198227405548096
# idx **** 80
# Run *** 80
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15475852569629653
# Best robustness 0.013960662834635484
# Final distance 0.0016558207623758154
# Final simulation: 4
# Time taken: 0.5776879787445068
# idx **** 81
# Run *** 81
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05466205666681185
# Best robustness -0.06474439654000602
# Final distance 0.001561592146753906
# Final simulation: 9
# Time taken: 1.5005238056182861
# idx **** 82
# Run *** 82
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 85
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06853095445300786
# Best robustness -0.03844985032586906
# Final distance 0.001818923631643078
# Final simulation: 8
# Time taken: 1.309523105621338
# idx **** 83
# Run *** 83
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 74
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0586873857126494
# Best robustness 0.0068955643221820795
# Final distance 0.001685181973005127
# Final simulation: 11
# Time taken: 1.8668851852416992
# idx **** 84
# Run *** 84
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 84
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0860961595780983
# Best robustness -0.017069815721918014
# Final distance 0.0014890920080550766
# Final simulation: 12
# Time taken: 2.0043983459472656
# idx **** 85
# Run *** 85
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04827210156902548
# Best robustness 0.002243853226837622
# Final distance 0.0015422219685907066
# Final simulation: 6
# Time taken: 1.083237648010254
# idx **** 86
# Run *** 86
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 82
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07309730107761955
# Best robustness 0.0009316112696062806
# Final distance 0.0018008599053636431
# Final simulation: 5
# Time taken: 0.7818858623504639
# idx **** 87
# Run *** 87
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 77
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11901660688553506
# Best robustness -0.05861909879321836
# Final distance 0.0015720501144896929
# Final simulation: 9
# Time taken: 1.519498586654663
# idx **** 88
# Run *** 88
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07124670738784382
# Best robustness 0.0038478154192949643
# Final distance 0.0015060816271979134
# Final simulation: 17
# Time taken: 2.954681396484375
# idx **** 89
# Run *** 89
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 87
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11023904651675785
# Best robustness -0.0011074110493158873
# Final distance 0.0018544213905236633
# Final simulation: 3
# Time taken: 0.39128828048706055
# idx **** 90
# Run *** 90
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2696653585758951
# Best robustness -0.04583701784863625
# Final distance 0.0019815210797950933
# Final simulation: 15
# Time taken: 2.596512794494629
# idx **** 91
# Run *** 91
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05428007703388093
# Best robustness 0.0020189391168858872
# Final distance 0.001894986284481678
# Final simulation: 5
# Time taken: 0.7596132755279541
# idx **** 92
# Run *** 92
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22046224090125804
# Best robustness -0.028723825876058262
# Final distance 0.0013678980744515914
# Final simulation: 11
# Time taken: 1.8594613075256348
# idx **** 93
# Run *** 93
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1437799656931287
# Best robustness 0.0027460264236689458
# Final distance 0.000754992934744399
# Final simulation: 7
# Time taken: 1.1036219596862793
# idx **** 94
# Run *** 94
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09112894309908696
# Best robustness -0.004812825277703325
# Final distance 0.001766454122381036
# Final simulation: 8
# Time taken: 1.3147106170654297
# idx **** 95
# Run *** 95
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 87
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12292392756736426
# Best robustness -0.004037328476871271
# Final distance 0.002873046303556907
# Final simulation: 31
# Time taken: 5.630602121353149
# idx **** 96
# Run *** 96
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 78
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0645542308454809
# Best robustness -0.008508965059834783
# Final distance 0.001417816874840429
# Final simulation: 6
# Time taken: 0.9424388408660889
# idx **** 97
# Run *** 97
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2008104856995266
# Best robustness -0.006007406409369254
# Final distance 0.0017429230164539553
# Final simulation: 8
# Time taken: 1.3122992515563965
# idx **** 98
# Run *** 98
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.033962352814464886
# Best robustness -0.010208845567779123
# Final distance 0.0014853279121186949
# Final simulation: 9
# Time taken: 1.5110197067260742
# idx **** 99
# Run *** 99
# /home/manish/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2487346804596175
# Best robustness 0.002444749497366283
# Final distance 0.012670323133141674
# Final simulation: 31
# Time taken: 5.511999845504761
# idx **** 100
# 12.58
# -0.011497131013430488
# 31
# 71.06360000000001

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC1')
evalObject.setSimsBound(30)
dataObject = evalObject.setDataObject()
# dataObject.setStepSize(0.02)
lowerBound = [0.2, -1.0]
upperBound = [0.4, -0.8]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.7, 0.9]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.003, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16328273083602726
# Setting new time step to 75
# Best robustness -0.004771814027401788
# Final distance 0.0017249539994566964
# Final simulation: 5
# Time taken: 2.544599771499634
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14268501511944504
# Setting new time step to 83
# Setting new time step to 73
# Setting new time step to 74
# Setting new time step to 73
# Best robustness -0.026153830123451405
# Final distance 0.03545308850657099
# Final simulation: 31
# Time taken: 19.728649377822876
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 74
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07952492864364669
# Setting new time step to 70
# Setting new time step to 77
# Setting new time step to 80
# Best robustness -0.005551722059653652
# Final distance 0.0007560370333954992
# Final simulation: 7
# Time taken: 3.836456775665283
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 74
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1175826534333791
# Setting new time step to 70
# Setting new time step to 81
# Best robustness -0.013559256032399825
# Final distance 0.0016719172039466326
# Final simulation: 6
# Time taken: 3.3145599365234375
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11537592509516455
# Setting new time step to 76
# Setting new time step to 79
# Best robustness -0.023703208883892657
# Final distance 0.0026496079200306645
# Final simulation: 7
# Time taken: 4.002656698226929
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 88
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.20461704402330075
# Setting new time step to 84
# Best robustness 0.002346355923209642
# Final distance 0.0024690716952462835
# Final simulation: 7
# Time taken: 3.9037487506866455
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 82
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.010969264768534407
# Starting distance is very less
# Best robustness -0.05277511887854269
# Final distance 0.010969264768534407
# Final simulation: 1
# Time taken: 0.0003123283386230469
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 81
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05595644970837929
# Setting new time step to 73
# Setting new time step to 76
# Best robustness -0.03109899674037675
# Final distance 0.0022396634318031963
# Final simulation: 6
# Time taken: 3.5190815925598145
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89]
# 70
# True None
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04665554240615753
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2485       with c_api_util.tf_buffer() as buf:
# -> 2486         pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2487         data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'GatherV2/axis' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/auto_control_deps_utils.py in get_read_write_resource_inputs(op)
#     108   try:
# --> 109     read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     110   except ValueError:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2489       # Convert to ValueError for backwards compatibility.
# -> 2490       raise ValueError(str(e))
#    2491     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'GatherV2/axis' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5758cb0a66b5> in <module>
#      31     dests = dest
#      32     evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.003,
# ---> 33                         correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
#      34     f_sims = evalObject.getFSimulations()
#      35     min_dist = evalObject.getFDistance()
#
# ~/Research/NExG/core/evaluation_isen.py in reachDestInvSen(self, dests, d_time_steps, threshold, correction_steps, scaling_factors, i_state, true_inv_sen)
#     377                                                      threshold=threshold,  model_v=trained_model, correction_steps=steps,
#     378                                                      scaling_factor=s_factor, sims_bound=self.sims_bound,
# --> 379                                                      dynamics=self.dynamics, true_inv_sen=true_inv_sen)
#     380                         print("Time taken: " + str(time.time() - start_time))
#     381
#
# ~/Research/NExG/core/evaluation_isen.py in reachDestInvNonBaseline(self, ref_traj, paths, d_time_step, threshold, model_v, correction_steps, sims_bound, scaling_factor, true_inv_sen, rand_area, dynamics)
#     582                         data_point = self.data_object.createDataPoint(x_val, xp_val, v_val, vp_val_normalized, t_val)
#     583
# --> 584                     predicted_v = self.evalModel(input=data_point, eval_var='v', model=model_v)
#     585
#     586                     if true_inv_sen is not None:
#
# ~/Research/NExG/core/evaluation.py in evalModel(self, input, eval_var, model)
#     124             xp_vp_t_pair = xp_vp_t_pair + [input[4]]
#     125             xp_vp_t_pair = np.asarray([xp_vp_t_pair], dtype=np.float64)
# --> 126             predicted_v = model.predict(xp_vp_t_pair)
#     127             predicted_v = predicted_v.flatten()
#     128             output = predicted_v
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1577           use_multiprocessing=use_multiprocessing,
#    1578           model=self,
# -> 1579           steps_per_execution=self._steps_per_execution)
#    1580
#    1581       # Container that configures and calls `tf.keras.Callback`s.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1115         use_multiprocessing=use_multiprocessing,
#    1116         distribution_strategy=ds_context.get_strategy(),
# -> 1117         model=model)
#    1118
#    1119     strategy = ds_context.get_strategy()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
# --> 364     dataset = self.slice_inputs(indices_dataset, inputs)
#     365
#     366     if shuffle == "batch":
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     395
#     396     dataset = dataset.map(
# --> 397         grab_batch, num_parallel_calls=dataset_ops.AUTOTUNE)
#     398
#     399     # Default optimizations are disabled to avoid the overhead of (unnecessary)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1700           num_parallel_calls,
#    1701           deterministic,
# -> 1702           preserve_cardinality=True)
#    1703
#    1704   def flat_map(self, map_func):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4082         self._transformation_name(),
#    4083         dataset=input_dataset,
# -> 4084         use_legacy_function=use_legacy_function)
#    4085     if deterministic is None:
#    4086       self._deterministic = "default"
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3369       with tracking.resource_tracker_scope(resource_tracker):
#    3370         # TODO(b/141462134): Switch to using garbage collection.
# -> 3371         self._function = wrapper_fn.get_concrete_function()
#    3372         if add_to_graph:
#    3373           self._function.add_to_graph(ops.get_default_graph())
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    2937     """
#    2938     graph_function = self._get_concrete_function_garbage_collected(
# -> 2939         *args, **kwargs)
#    2940     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2941     return graph_function
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2904       args, kwargs = None, None
#    2905     with self._lock:
# -> 2906       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2907       seen_names = set()
#    2908       captured = object_identity.ObjectIdentitySet(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#    1025         if x is not None)
#    1026
# -> 1027     func_graph.variables = variables
#    1028
#    1029   if add_control_dependencies:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     396       # Check for any resource inputs. If we find any, we update control_inputs
#     397       # and last_write_to_resource.
# --> 398       for inp, resource_type in _get_resource_inputs(op):
#     399         is_read = resource_type == ResourceType.READ_ONLY
#     400         input_id = ops.tensor_id(inp)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/auto_control_deps.py in _get_resource_inputs(op)
#     519 def _get_resource_inputs(op):
#     520   """Returns an iterable of resources touched by this `op`."""
# --> 521   reads, writes = utils.get_read_write_resource_inputs(op)
#     522   saturated = False
#     523   while not saturated:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/auto_control_deps_utils.py in get_read_write_resource_inputs(op)
#     110   except ValueError:
#     111     # Attr was not set. Add all resource inputs to `writes` and return.
# --> 112     writes.update(t for t in op.inputs if t.dtype == dtypes.resource)
#     113     return (reads, writes)
#     114
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in inputs(self)
#    2317       self._inputs_val = tuple(
#    2318           map(self.graph._get_tensor_by_tf_output,
# -> 2319               pywrap_tf_session.GetOperationInputs(self._c_op)))
#    2320       # pylint: enable=protected-access
#    2321     return self._inputs_val
#
# KeyboardInterrupt:

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC2')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(100)
# dataObject.setLowerBound([0.8, 0.9])
# dataObject.setUpperBound([1.2, 1.2])
# dataObject.setStepSize(0.02)
lowerBound = [1.5, 0.4]
upperBound = [1.7, 0.6]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.6, 0.8]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
#     print(ref_traj[60], ref_traj[70])
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22461033459634455
# Best robustness 0.09472815316679095
# Final distance 0.0007247869318031567
# Final simulation: 4
# Time taken: 2.2929329872131348
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.43220844431681454
# Best robustness -0.003696119890719274
# Final distance 0.0004188998774643634
# Final simulation: 7
# Time taken: 4.783484697341919
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.647820775819485
# Best robustness 0.0534733054637897
# Final distance 0.0008215982247817478
# Final simulation: 13
# Time taken: 9.24162483215332
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6958089654948395
# Best robustness -0.024946530612852236
# Final distance 0.0009699891580805005
# Final simulation: 13
# Time taken: 10.306266784667969
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5439533568308006
# Best robustness 0.07590861666203841
# Final distance 0.0004529802941922291
# Final simulation: 6
# Time taken: 3.947591781616211
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.34999540718904326
# Best robustness -0.044477447585783314
# Final distance 0.0005041205030860551
# Final simulation: 7
# Time taken: 4.679936170578003
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0864460598783086
# Best robustness -0.08259092193208828
# Final distance 0.0005108897080274132
# Final simulation: 6
# Time taken: 3.8529341220855713
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6347483150453674
# Best robustness -0.054615965478908124
# Final distance 0.0005840356565272053
# Final simulation: 8
# Time taken: 5.344974517822266
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7319750006877218
# Best robustness -0.10850671899866016
# Final distance 0.005388146554779827
# Final simulation: 51
# Time taken: 40.22212862968445
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5814451833847992
# Best robustness 0.03903629489366278
# Final distance 0.0033459598099507435
# Final simulation: 51
# Time taken: 37.12480401992798
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18451842070927826
# Best robustness -0.01087305909472791
# Final distance 0.0006237808572993955
# Final simulation: 2
# Time taken: 0.7101399898529053
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 68
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05558876810673369
# Best robustness -0.09731603620771834
# Final distance 0.0006823347992754306
# Final simulation: 5
# Time taken: 2.796116828918457
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.47976807414963163
# Best robustness -0.11970221489960853
# Final distance 0.0004643263538866983
# Final simulation: 16
# Time taken: 11.021673679351807
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.044151318625619676
# Best robustness -0.0016692031809055763
# Final distance 0.0009021850312898481
# Final simulation: 8
# Time taken: 5.039637327194214
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6610754264994875
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.022845417671157997
# Final distance 0.009897197551456386
# Final simulation: 6
# Time taken: 3.581174612045288
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6207178714102656
# Best robustness -0.08663157459921111
# Final distance 0.0005776080767145703
# Final simulation: 8
# Time taken: 4.883925437927246
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4792911099642631
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02156961100244259
# Final distance 0.003210834268414564
# Final simulation: 8
# Time taken: 5.0990283489227295
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.8040621296746853
# Best robustness 0.03405095976360473
# Final distance 0.003248179618716018
# Final simulation: 51
# Time taken: 33.634586811065674
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12711689443147975
# Best robustness -0.11929790724704165
# Final distance 0.006482417403481803
# Final simulation: 51
# Time taken: 36.547306299209595
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5233192713799929
# Best robustness -0.049893881888005476
# Final distance 0.0005773235338172117
# Final simulation: 5
# Time taken: 2.7773566246032715
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49704278982206523
# Best robustness -0.13012640209907833
# Final distance 0.006390779561991053
# Final simulation: 51
# Time taken: 36.336668729782104
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3382656483385256
# Best robustness -0.13218437776507175
# Final distance 0.000887218335327862
# Final simulation: 5
# Time taken: 3.0548815727233887
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5824360093802179
# Best robustness -0.06687500958868697
# Final distance 0.000821233640893675
# Final simulation: 22
# Time taken: 15.531546831130981
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.693699367046185
# Best robustness -0.09409024960389312
# Final distance 0.0008740536130750695
# Final simulation: 8
# Time taken: 4.564332008361816
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 69
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2471441946879952
# Best robustness -0.08822234478430979
# Final distance 0.0009913957762537227
# Final simulation: 5
# Time taken: 2.8993582725524902
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5192357451335029
# Best robustness -0.13508865867123548
# Final distance 0.000848477851479428
# Final simulation: 28
# Time taken: 17.690562963485718
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6472049184372977
# Best robustness 0.03489967245861614
# Final distance 0.0037344632258074894
# Final simulation: 51
# Time taken: 30.539298057556152
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3928139019095667
# Best robustness 0.10983743773646082
# Final distance 0.0006139501163320802
# Final simulation: 6
# Time taken: 3.1094157695770264
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4954842001530387
# Best robustness -0.09747690527022967
# Final distance 0.0005462669856443706
# Final simulation: 8
# Time taken: 4.181648254394531
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05287862879887888
# Best robustness -0.0027627362327065086
# Final distance 0.0009258627735003445
# Final simulation: 8
# Time taken: 4.46254825592041
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6558059013508886
# Best robustness -0.03655068912647763
# Final distance 0.0028447141088236566
# Final simulation: 51
# Time taken: 32.70912837982178
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08411860876159497
# Best robustness -0.07197250805367505
# Final distance 0.00041314770929007686
# Final simulation: 6
# Time taken: 3.2364401817321777
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 62
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.706066684943531
# Best robustness -0.009974116957646828
# Final distance 0.0009582040449747308
# Final simulation: 8
# Time taken: 4.323352813720703
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0922020068082079
# Best robustness -0.04056427246072658
# Final distance 0.0006979169582224399
# Final simulation: 6
# Time taken: 3.251579999923706
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5269370907213295
# Best robustness -0.107800303465585
# Final distance 0.00046417348523178625
# Final simulation: 7
# Time taken: 3.673603057861328
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16728720427393803
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.013642970473311755
# Final distance 0.07826138163567194
# Final simulation: 2
# Time taken: 0.6954641342163086
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.265280341067706
# Best robustness -0.05791268038251096
# Final distance 0.0005995034829864584
# Final simulation: 6
# Time taken: 3.0959296226501465
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49600300288733573
# Best robustness -0.11915722409158808
# Final distance 0.0009579232700537563
# Final simulation: 47
# Time taken: 30.51996159553528
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.184185017446509
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02490548366750045
# Final distance 0.02025846089464317
# Final simulation: 4
# Time taken: 2.054861307144165
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6454715784909123
# Best robustness -0.003956879354963139
# Final distance 0.0044734676664474815
# Final simulation: 51
# Time taken: 30.622596979141235
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5677658955739849
# Best robustness -0.06447797212369544
# Final distance 0.0007262408729895613
# Final simulation: 12
# Time taken: 6.850387334823608
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18181547430922124
# Best robustness -0.021671801867408136
# Final distance 0.0009132390079808534
# Final simulation: 11
# Time taken: 6.699826717376709
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3842778051859846
# Best robustness 0.12325083370024581
# Final distance 0.0005436745091456491
# Final simulation: 7
# Time taken: 3.728896379470825
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3333699681913092
# Best robustness -0.021300325609208026
# Final distance 0.0006945122658457204
# Final simulation: 8
# Time taken: 4.509762525558472
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5923627871309131
# Best robustness -0.07579197502960466
# Final distance 0.005994977506723294
# Final simulation: 51
# Time taken: 32.89271688461304
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11546952187100032
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02335851783959142
# Final distance 0.019218943071792543
# Final simulation: 4
# Time taken: 1.8947811126708984
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33214188762296937
# Best robustness -0.11903449942938493
# Final distance 0.0038028262705659456
# Final simulation: 51
# Time taken: 32.43810749053955
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4368199536589475
# Best robustness -0.09896124382842941
# Final distance 0.0008899982001257262
# Final simulation: 16
# Time taken: 9.698956727981567
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12746856106211943
# Best robustness -0.04675855536591844
# Final distance 0.0004611664380223739
# Final simulation: 7
# Time taken: 4.061619997024536
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 66
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13641688358838502
# Best robustness -0.017721261073528227
# Final distance 0.0004544232866545118
# Final simulation: 7
# Time taken: 3.7128102779388428
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.229614399554775
# Best robustness -0.10008582757474466
# Final distance 0.0007104965137348482
# Final simulation: 8
# Time taken: 4.449572324752808
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5026857238401138
# Best robustness -0.044959305124249394
# Final distance 0.0024688696441036865
# Final simulation: 51
# Time taken: 32.60349225997925
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5620129050628859
# Best robustness -0.03564751170122926
# Final distance 0.0009776808929509758
# Final simulation: 9
# Time taken: 4.946789503097534
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49619427205124533
# Best robustness -0.11904990711198432
# Final distance 0.009862317192097542
# Final simulation: 51
# Time taken: 32.68194270133972
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0899771856614716
# Best robustness -0.014124896815191024
# Final distance 0.0003455312680212333
# Final simulation: 6
# Time taken: 3.063939094543457
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5782630100246031
# Best robustness -0.07745846426997094
# Final distance 0.0009604154082144118
# Final simulation: 23
# Time taken: 14.066909790039062
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5625796779328084
# Best robustness 0.04371470177765058
# Final distance 0.0009973096860484954
# Final simulation: 18
# Time taken: 10.889032363891602
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.27805106112051275
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.015439712213430545
# Final distance 0.04576862746090644
# Final simulation: 3
# Time taken: 1.3443012237548828
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6616478287550431
# Best robustness 0.036765068895244446
# Final distance 0.0024348187958603
# Final simulation: 51
# Time taken: 35.66187119483948
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.40077470061537246
# Best robustness -0.048144996212233226
# Final distance 0.0007935693675667759
# Final simulation: 8
# Time taken: 5.8430681228637695
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19635558102443434
# Best robustness -0.025036709226801346
# Final distance 0.0006975213159968014
# Final simulation: 7
# Time taken: 4.792281866073608
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 68
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3550928596837683
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.022981800873663638
# Final distance 0.07801878691221809
# Final simulation: 3
# Time taken: 1.4931681156158447
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7353705874364287
# Best robustness -0.03226712291778344
# Final distance 0.0008366743325555625
# Final simulation: 17
# Time taken: 12.520212411880493
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 65
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18850203743679708
# Best robustness -0.13058848362704722
# Final distance 0.000633392410657332
# Final simulation: 7
# Time taken: 4.109492540359497
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 76
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2633860474071303
# Best robustness -0.039467253184522044
# Final distance 0.000960982915814459
# Final simulation: 7
# Time taken: 4.374598026275635
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6541994403854741
# Best robustness 0.0975323565709203
# Final distance 0.0005425918202839539
# Final simulation: 5
# Time taken: 2.813122272491455
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 65
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6702232227656733
# Best robustness 0.08155337487698877
# Final distance 0.0008104894135077437
# Final simulation: 5
# Time taken: 2.783621072769165
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03433673103423121
# Best robustness -0.09350728232242234
# Final distance 0.00043119791161526025
# Final simulation: 6
# Time taken: 3.6808652877807617
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0490829365848922
# Best robustness -0.06209416561255221
# Final distance 0.0009675366988480981
# Final simulation: 5
# Time taken: 2.759600877761841
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7525069319646036
# Best robustness -0.09312983220601723
# Final distance 0.0006281700165348138
# Final simulation: 8
# Time taken: 4.7293219566345215
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33834531408255547
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.015825191926848392
# Final distance 0.04234491549809552
# Final simulation: 3
# Time taken: 1.472224473953247
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3144430679999767
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012923580881931351
# Final distance 0.05168053984906436
# Final simulation: 3
# Time taken: 1.4940910339355469
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5018095612009391
# Best robustness -0.0968313422097451
# Final distance 0.0009691838726173845
# Final simulation: 13
# Time taken: 8.731405019760132
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 68
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0759778450257736
# Best robustness -0.07666527854604066
# Final distance 0.0006709000395203501
# Final simulation: 6
# Time taken: 3.510136842727661
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.141447709124226
# Best robustness 0.09542303556770726
# Final distance 0.00041270015841453534
# Final simulation: 7
# Time taken: 3.9106264114379883
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.39039664291511506
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02209452285836444
# Final distance 0.023319420465786056
# Final simulation: 4
# Time taken: 2.1324386596679688
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5576735584666683
# Best robustness -0.0193496217631276
# Final distance 0.0004575294733435078
# Final simulation: 9
# Time taken: 6.159406423568726
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.36405740386790447
# Best robustness -0.10831900201888339
# Final distance 0.0027708128333531826
# Final simulation: 51
# Time taken: 36.652971029281616
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5076246444570285
# Best robustness 0.03978144204987977
# Final distance 0.0009970636168735467
# Final simulation: 49
# Time taken: 34.63167119026184
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6333722685181356
# Best robustness -0.08890305980161184
# Final distance 0.0006858116311908591
# Final simulation: 8
# Time taken: 5.036271095275879
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6329772236669502
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02096950825674715
# Final distance 0.0076112533252882305
# Final simulation: 6
# Time taken: 3.4460744857788086
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7294982768398738
# Best robustness -0.013402502641657543
# Final distance 0.0006249753103571621
# Final simulation: 10
# Time taken: 6.41058611869812
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.28179941195616315
# Best robustness 0.038329388225834427
# Final distance 0.0009057170596830218
# Final simulation: 35
# Time taken: 24.702070236206055
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 69
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2550719542028251
# Best robustness -0.10272890499962861
# Final distance 0.000820775542446627
# Final simulation: 7
# Time taken: 4.145915269851685
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12824426172914147
# Best robustness -0.04009420997809199
# Final distance 0.0006703465468082877
# Final simulation: 11
# Time taken: 6.5953850746154785
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5369175855308703
# Best robustness -0.12639082776155003
# Final distance 0.0005557835506738553
# Final simulation: 9
# Time taken: 5.432371139526367
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5668971240804722
# Best robustness -0.07693912678757098
# Final distance 0.0004883721827915317
# Final simulation: 18
# Time taken: 12.722583770751953
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6292218865467121
# Best robustness -0.0558279693902316
# Final distance 0.0015784880658275223
# Final simulation: 51
# Time taken: 36.113173484802246
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.38259581233822193
# Best robustness 0.039232081811941155
# Final distance 0.003381463867907533
# Final simulation: 51
# Time taken: 35.500675439834595
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5793516834901506
# Best robustness -0.056669102939236216
# Final distance 0.0006924081934645127
# Final simulation: 26
# Time taken: 17.78741192817688
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6139816937255321
# Best robustness -0.07605430841699001
# Final distance 0.0008090845310864801
# Final simulation: 14
# Time taken: 9.142950296401978
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.30247568427532906
# Best robustness 0.07682857042263747
# Final distance 0.0007181742387182871
# Final simulation: 6
# Time taken: 3.329213857650757
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.30636512181625164
# Best robustness -0.1122832461095773
# Final distance 0.0009038680421782246
# Final simulation: 7
# Time taken: 3.8021080493927
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5706366736781344
# Best robustness -0.0772720541832953
# Final distance 0.0008292533978955729
# Final simulation: 18
# Time taken: 11.51743745803833
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.35884452739675565
# Best robustness -0.09944547562784345
# Final distance 0.0009007772668137978
# Final simulation: 10
# Time taken: 6.178282737731934
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5471761147890665
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.010126211140791375
# Final distance 0.040035310055219646
# Final simulation: 4
# Time taken: 2.136366367340088
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7191329564966347
# Best robustness -0.041994649541764795
# Final distance 0.0008749876989947805
# Final simulation: 15
# Time taken: 8.908132791519165
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4892777160724204
# Best robustness -0.04694147669688076
# Final distance 0.00046018838387496544
# Final simulation: 8
# Time taken: 4.284894943237305
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5778357913778117
# Best robustness -0.0964680723768373
# Final distance 0.0027756323551150126
# Final simulation: 51
# Time taken: 33.88246154785156
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6569723702584678
# Best robustness 0.03972375903402248
# Final distance 0.0009294620851639497
# Final simulation: 10
# Time taken: 6.142517328262329
# idx **** 100
# 16.98
# -0.0386540603927685
# 51
# 295.3796

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC3')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
# dataObject.setLowerBound([0.8, 0.9])
# dataObject.setUpperBound([1.2, 1.2])
# dataObject.setStepSize(0.02)
lowerBound = [0.4, -0.1]
upperBound = [0.5, 0.0]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.8, 1.0]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC3.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09456084099068186
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006984921867503574
# Final distance 0.0025399784854707366
# Final simulation: 45
# Time taken: 17.996691703796387
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06930325321994454
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01620435254747956
# Final distance 0.04400606614071274
# Final simulation: 2
# Time taken: 0.5005872249603271
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06052594803312805
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0077059182590241025
# Final distance 0.031276419814663274
# Final simulation: 2
# Time taken: 0.4966392517089844
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16954342616603968
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0024370890508520733
# Final distance 0.025688163122562287
# Final simulation: 4
# Time taken: 1.278397560119629
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1814855954761662
# /home/manishg/Research/NExG/core/evaluation_isen.py:541: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Best robustness -0.0004546903331698218
# Final distance 0.001265768304545376
# Final simulation: 6
# Time taken: 2.2804512977600098
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 84
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09848950311898022
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008267260863451049
# Final distance 0.024910323436376933
# Final simulation: 3
# Time taken: 0.9630887508392334
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08895017655499832
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003348610323974587
# Final distance 0.052843199603369855
# Final simulation: 2
# Time taken: 0.5089569091796875
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 96
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02814774217951417
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.01576066971102258
# Final distance 0.02814774217951417
# Final simulation: 1
# Time taken: 0.0006532669067382812
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08489552422079459
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00901940833216471
# Final distance 0.016980821681802236
# Final simulation: 4
# Time taken: 1.4543938636779785
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.028519969039369694
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.014018690999413164
# Final distance 0.028519969039369694
# Final simulation: 1
# Time taken: 0.000431060791015625
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22887222844433128
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008051165893844078
# Final distance 0.03256324638649448
# Final simulation: 4
# Time taken: 1.348879098892212
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10710694642505561
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006340277131102883
# Final distance 0.05474540100136303
# Final simulation: 2
# Time taken: 0.5046596527099609
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10409081523460675
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009627489203939611
# Final distance 0.001253839542002405
# Final simulation: 35
# Time taken: 14.32499098777771
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.016602098205822077
# Best robustness -0.00012342446244162364
# Final distance 0.0018372761595451042
# Final simulation: 6
# Time taken: 2.249478340148926
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08738915877531059
# Best robustness 0.00025264122478098816
# Final distance 0.009868062820499656
# Final simulation: 51
# Time taken: 22.928701162338257
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17192954538359695
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022295403464475416
# Final distance 0.028014679454543216
# Final simulation: 4
# Time taken: 1.74088454246521
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06560711303277376
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.00477156456565786
# Final distance 0.06560711303277376
# Final simulation: 1
# Time taken: 0.0005402565002441406
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07697020219353205
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.002145219834162382
# Final distance 0.005515998002441673
# Final simulation: 3
# Time taken: 1.188849687576294
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08010854647430822
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005594629618011266
# Final distance 0.008590276733739941
# Final simulation: 3
# Time taken: 1.060124158859253
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10358254577691652
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.032390947477842116
# Final distance 0.04981053949836975
# Final simulation: 2
# Time taken: 0.5648143291473389
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.20408883117401308
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02116612068931777
# Final distance 0.09890638275053124
# Final simulation: 2
# Time taken: 0.5506467819213867
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.018012461108924366
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.010959099724041152
# Final distance 0.018012461108924366
# Final simulation: 1
# Time taken: 0.00038743019104003906
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03401713623391208
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.008418897956424698
# Final distance 0.03401713623391208
# Final simulation: 1
# Time taken: 0.0004642009735107422
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 97
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04987311850163596
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.013136458057507239
# Final distance 0.04987311850163596
# Final simulation: 1
# Time taken: 0.0004942417144775391
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10169586608009198
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008949319626149532
# Final distance 0.024412106312764633
# Final simulation: 4
# Time taken: 1.5672194957733154
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09257617412890008
# Best robustness -0.00041723060942389307
# Final distance 0.0013843054530460418
# Final simulation: 7
# Time taken: 3.1356167793273926
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06566798331479587
# Best robustness -0.001613733222567137
# Final distance 0.0019897136863460847
# Final simulation: 12
# Time taken: 6.17474102973938
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2093227738972525
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0038624483270321376
# Final distance 0.0297136892537599
# Final simulation: 4
# Time taken: 1.5059807300567627
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 91
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07737382674118239
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01843351473454631
# Final distance 0.03968595509868462
# Final simulation: 2
# Time taken: 0.5760142803192139
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16668585299541933
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.029785712590143953
# Final distance 0.04046734558517513
# Final simulation: 3
# Time taken: 1.247863531112671
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17116981992691788
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004615213729420516
# Final distance 0.005263849699029132
# Final simulation: 7
# Time taken: 2.840481758117676
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18324510112507367
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0054870209660053265
# Final distance 0.0415735208631162
# Final simulation: 3
# Time taken: 1.0316531658172607
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.050469346762475054
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.023306235937455344
# Final distance 0.050469346762475054
# Final simulation: 1
# Time taken: 0.0003218650817871094
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05339319963830435
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.017890227186365612
# Final distance 0.04000450137923142
# Final simulation: 2
# Time taken: 0.5092048645019531
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07914546638899478
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02818240640628483
# Final distance 0.045717495546141095
# Final simulation: 2
# Time taken: 0.5086209774017334
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05198995263085619
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.016354056077946544
# Final distance 0.02894875263309997
# Final simulation: 2
# Time taken: 0.5969829559326172
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02999358992777881
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.024059610334054016
# Final distance 0.02999358992777881
# Final simulation: 1
# Time taken: 0.0003616809844970703
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11050594874535521
# Best robustness -0.007558545178251908
# Final distance 0.0013091759465005872
# Final simulation: 7
# Time taken: 2.660322904586792
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1009123483428285
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0051887681482319864
# Final distance 0.011900191491462852
# Final simulation: 4
# Time taken: 1.3273415565490723
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18347369380953163
# Best robustness -0.0008716762574951294
# Final distance 0.14088075449168427
# Final simulation: 51
# Time taken: 22.13171648979187
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08176767028037987
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0019821570737813747
# Final distance 0.01475019958813588
# Final simulation: 4
# Time taken: 1.9517521858215332
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19793175641366034
# Best robustness -0.0010363396665648422
# Final distance 0.0012412146942057474
# Final simulation: 4
# Time taken: 2.2405738830566406
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06950292298105348
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.010307201907854478
# Final distance 0.06950292298105348
# Final simulation: 1
# Time taken: 0.0005466938018798828
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07940586364743295
# Best robustness -0.00015126268705861756
# Final distance 0.001488194778668707
# Final simulation: 6
# Time taken: 3.0407984256744385
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.032676412836001575
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.027767381370624882
# Final distance 0.032676412836001575
# Final simulation: 1
# Time taken: 0.0004055500030517578
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08178065835442377
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005515439526413757
# Final distance 0.022083739988631345
# Final simulation: 3
# Time taken: 1.2295300960540771
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04712432860018518
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.02910183693407237
# Final distance 0.04712432860018518
# Final simulation: 1
# Time taken: 0.0017879009246826172
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07458129186716125
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0031068656215660602
# Final distance 0.07458129186716125
# Final simulation: 1
# Time taken: 0.0032172203063964844
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 97
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08473296360592773
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009061480402370621
# Final distance 0.030441640623941862
# Final simulation: 2
# Time taken: 0.78359055519104
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 97
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07068583073857475
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022197446873178876
# Final distance 0.025002468103849138
# Final simulation: 4
# Time taken: 1.798241376876831
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12312940111631118
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01319425601102845
# Final distance 0.05421269162654949
# Final simulation: 2
# Time taken: 0.5887396335601807
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05973744343660291
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009094218951472036
# Final distance 0.0045204124640486915
# Final simulation: 5
# Time taken: 2.184969663619995
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09951064273591846
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0020429820708586723
# Final distance 0.0017441613392346453
# Final simulation: 7
# Time taken: 3.108445167541504
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2621262483707347
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012784626425415696
# Final distance 0.04519879754895276
# Final simulation: 4
# Time taken: 1.5485613346099854
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05880557439138721
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.010523430527174131
# Final distance 0.05880557439138721
# Final simulation: 1
# Time taken: 0.0011239051818847656
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10884660136785343
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02391912315150113
# Final distance 0.01673142631049842
# Final simulation: 3
# Time taken: 1.0461413860321045
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07590088199527921
# Best robustness -1.7144622625081454e-05
# Final distance 0.07590088199527921
# Final simulation: 51
# Time taken: 24.061709880828857
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13443773424587852
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01677178345361349
# Final distance 0.0728931173381376
# Final simulation: 2
# Time taken: 0.8559391498565674
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11433602167160402
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0132374498677987
# Final distance 0.05896697032009437
# Final simulation: 2
# Time taken: 0.5795748233795166
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025322663613242598
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00795161036507741
# Final distance 0.015585586532051054
# Final simulation: 2
# Time taken: 0.5974948406219482
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.058223489118285766
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.02346788428481153
# Final distance 0.058223489118285766
# Final simulation: 1
# Time taken: 0.0010068416595458984
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05545058495822358
# Best robustness -0.0015386159181017128
# Final distance 0.05545058495822358
# Final simulation: 51
# Time taken: 23.580123901367188
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05358930681816606
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003574488364586348
# Final distance 0.034446768122892095
# Final simulation: 2
# Time taken: 0.569007158279419
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04859122650327726
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.01601289198589756
# Final distance 0.04859122650327726
# Final simulation: 1
# Time taken: 0.0010113716125488281
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1503494891992797
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.014421258622679744
# Final distance 0.0811384709851857
# Final simulation: 2
# Time taken: 0.5419127941131592
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 84
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0498706724324181
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022865384441848355
# Final distance 0.004881736528953731
# Final simulation: 6
# Time taken: 2.3903491497039795
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04903843847058803
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.02117511276143158
# Final distance 0.04903843847058803
# Final simulation: 1
# Time taken: 0.0004112720489501953
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0697506873563942
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0060942460401485765
# Final distance 0.0697506873563942
# Final simulation: 1
# Time taken: 0.00039768218994140625
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14828645792372572
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0014973541956856962
# Final distance 0.01816814244331487
# Final simulation: 4
# Time taken: 1.4410679340362549
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1368811546113374
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01469442666890134
# Final distance 0.031814121003163644
# Final simulation: 3
# Time taken: 0.9361164569854736
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04952189997623377
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02290275147470744
# Final distance 0.022455857472360348
# Final simulation: 2
# Time taken: 0.5350508689880371
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.029472507828888918
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.007331250791742338
# Final distance 0.029472507828888918
# Final simulation: 1
# Time taken: 0.00046634674072265625
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03111772631073746
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0018102591692186224
# Final distance 0.01612634174089922
# Final simulation: 3
# Time taken: 0.9775595664978027
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16973934841845892
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006366010044073644
# Final distance 0.08507344164283498
# Final simulation: 2
# Time taken: 0.5573499202728271
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08505305397164326
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.010748453277859137
# Final distance 0.012673007381576031
# Final simulation: 8
# Time taken: 3.4445130825042725
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.038417899882629405
# Best robustness -0.003975863370345247
# Final distance 0.007116890928207264
# Final simulation: 51
# Time taken: 21.937832355499268
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16640575722942608
# Best robustness -0.0013974411675961693
# Final distance 0.0013318840889369847
# Final simulation: 7
# Time taken: 3.0124704837799072
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16554412532373
# Best robustness 0.000367638704489764
# Final distance 0.011123345810419384
# Final simulation: 51
# Time taken: 22.56090235710144
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04709047767004519
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005416471814290669
# Final distance 0.005920151575456411
# Final simulation: 5
# Time taken: 2.222367286682129
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10687448091793118
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0019412956673864577
# Final distance 0.006086690529145336
# Final simulation: 4
# Time taken: 1.7956395149230957
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.25071258928088397
# Best robustness -0.007071307983338187
# Final distance 0.009426384899958897
# Final simulation: 51
# Time taken: 25.944141149520874
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08338531003846922
# Best robustness 0.003652823316838626
# Final distance 0.08338531003846922
# Final simulation: 51
# Time taken: 22.914196252822876
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1541608178503802
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004584728113847822
# Final distance 0.024729690120710787
# Final simulation: 4
# Time taken: 1.4104654788970947
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06630954392145816
# Best robustness 0.0005247868408426839
# Final distance 0.06630954392145816
# Final simulation: 51
# Time taken: 24.16951560974121
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07824374781182866
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.010234046919044027
# Final distance 0.07824374781182866
# Final simulation: 2
# Time taken: 0.545393705368042
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06127197174174673
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006155586592115476
# Final distance 0.009597696702881684
# Final simulation: 4
# Time taken: 1.5198118686676025
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16015444662523715
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005345048805730834
# Final distance 0.05018364145570334
# Final simulation: 3
# Time taken: 1.0202438831329346
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07577136196534681
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0076577213976889436
# Final distance 0.04331212948034328
# Final simulation: 2
# Time taken: 0.5670151710510254
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.29974071296533983
# Best robustness -0.003894053451706762
# Final distance 0.0114735475238743
# Final simulation: 51
# Time taken: 24.225963830947876
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08928320793180995
# Best robustness -0.001537058872568317
# Final distance 0.0011588748430859028
# Final simulation: 22
# Time taken: 10.498046398162842
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23194247830083706
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012260425880533814
# Final distance 0.02997774761633071
# Final simulation: 3
# Time taken: 1.316389560699463
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15077647992740056
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006019007746940679
# Final distance 0.013010566881251837
# Final simulation: 5
# Time taken: 2.031141996383667
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08279493164555952
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.011515119263019534
# Final distance 0.04546696496777701
# Final simulation: 2
# Time taken: 0.5737977027893066
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10080670828428567
# Best robustness -0.0007041864752680965
# Final distance 0.001700242748869572
# Final simulation: 7
# Time taken: 3.128965139389038
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04690159810799112
# Best robustness -0.0007294483828883536
# Final distance 0.0014798205567977398
# Final simulation: 9
# Time taken: 4.143861293792725
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.044207023199736004
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005477621590678994
# Final distance 0.002804878220243857
# Final simulation: 5
# Time taken: 2.058316230773926
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.034794545437330134
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009352633866334836
# Final distance 0.028808086228496715
# Final simulation: 3
# Time taken: 0.9985933303833008
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08852967052659237
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004102387239368279
# Final distance 0.0029375472811199034
# Final simulation: 6
# Time taken: 2.6556649208068848
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14498211870307245
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00910177753007409
# Final distance 0.002969246903401671
# Final simulation: 43
# Time taken: 19.34007453918457
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 96
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15474890801680324
# Best robustness -0.0003077288821298771
# Final distance 0.0013164893204314714
# Final simulation: 12
# Time taken: 5.268112421035767
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.034146048755207443
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0026082438201984674
# Final distance 0.0015876595822408258
# Final simulation: 3
# Time taken: 1.0354397296905518
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0699052223840304
# Best robustness -0.0008490934338298839
# Final distance 0.0013609024762787703
# Final simulation: 10
# Time taken: 4.164350271224976
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.026413536798294345
# Best robustness 0.00043667991606111123
# Final distance 0.0019614566014782247
# Final simulation: 7
# Time taken: 3.091791868209839
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1964380385599035
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005453364859537169
# Final distance 0.004328293739161586
# Final simulation: 8
# Time taken: 3.0834500789642334
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1781024107630231
# Best robustness -0.004758574184177917
# Final distance 0.0010253820027017486
# Final simulation: 9
# Time taken: 4.154749870300293
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.040111162597199566
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006586823687909617
# Final distance 0.025197366318712142
# Final simulation: 2
# Time taken: 0.5368177890777588
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06647819286976936
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009949380102814785
# Final distance 0.00628357972026347
# Final simulation: 3
# Time taken: 0.9986493587493896
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12751714044187373
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008667855974316614
# Final distance 0.01172802722579646
# Final simulation: 5
# Time taken: 1.8243494033813477
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05946328756124348
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.03140873609336553
# Final distance 0.05946328756124348
# Final simulation: 1
# Time taken: 0.0008313655853271484
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15203590196283384
# Best robustness -0.00045509069501929386
# Final distance 0.0018246029256940464
# Final simulation: 21
# Time taken: 9.509838819503784
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16895073321691825
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003542241884621374
# Final distance 0.028654474789982128
# Final simulation: 4
# Time taken: 1.4518201351165771
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16260760507662675
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.03007322076536112
# Final distance 0.04409539683418388
# Final simulation: 3
# Time taken: 1.0172691345214844
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18600945578103134
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005519088201152182
# Final distance 0.09093399173568319
# Final simulation: 2
# Time taken: 0.4892871379852295
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07778341749177672
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008243915217822695
# Final distance 0.039922596937410695
# Final simulation: 2
# Time taken: 0.5066452026367188
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06484676947034486
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.008014533554547287
# Final distance 0.06484676947034486
# Final simulation: 1
# Time taken: 0.0011816024780273438
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08881633220555811
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02106041150156516
# Final distance 0.06908832530390059
# Final simulation: 2
# Time taken: 0.48692846298217773
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06693080593030794
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.013774471035468305
# Final distance 0.027060692403944733
# Final simulation: 3
# Time taken: 0.9544506072998047
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09345214569803682
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004145255125397684
# Final distance 0.010843722822453357
# Final simulation: 7
# Time taken: 2.615387439727783
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04490484486362701
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.028586088450537117
# Final distance 0.017750107629942686
# Final simulation: 2
# Time taken: 0.5226836204528809
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05418581996653761
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0066372956221601165
# Final distance 0.051566411574972874
# Final simulation: 2
# Time taken: 0.49718546867370605
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 96
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17046630500653515
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02108010140644063
# Final distance 0.03833273591100817
# Final simulation: 3
# Time taken: 0.9387094974517822
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04519745281235727
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0021817986883314686
# Final distance 0.007444924605241264
# Final simulation: 4
# Time taken: 1.4793179035186768
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 94
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1382349458793466
# Best robustness -0.0003969066730778843
# Final distance 0.0019377896303931468
# Final simulation: 7
# Time taken: 3.2721893787384033
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07140284659963594
# Best robustness 0.0005083608595481091
# Final distance 0.005432804648350848
# Final simulation: 51
# Time taken: 21.617421865463257
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0640027108622577
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00954102746610478
# Final distance 0.001905800283615513
# Final simulation: 7
# Time taken: 2.4569199085235596
# idx **** 100
# 8.89
# -0.007896567960815788
# 51
# 183.33790000000005

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='SinglePendulum')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
# dataObject.setLowerBound([0.8, 0.9])
# dataObject.setUpperBound([1.2, 1.2])
# dataObject.setStepSize(0.02)
lowerBound = [1.3, -1.2]
upperBound = [1.5, -1.0]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.6, 0.8]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
#     print(ref_traj[60], ref_traj[80])
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_SinglePendulum.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7074248989394984
# Best robustness -0.010699242511400975
# Final distance 0.0019678762053140604
# Final simulation: 7
# Time taken: 1.6646332740783691
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07695705567752814
# Best robustness -0.003515424530929012
# Final distance 0.0019086026188390745
# Final simulation: 6
# Time taken: 1.5332257747650146
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12347233463819697
# Best robustness 0.006205061115924004
# Final distance 0.01672180054223054
# Final simulation: 51
# Time taken: 14.19591212272644
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0901968135218116
# Best robustness -0.009387286988989496
# Final distance 0.0018586986745713712
# Final simulation: 10
# Time taken: 2.680025815963745
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6686694705332757
# Best robustness -0.05712802513727455
# Final distance 0.0012851313395130586
# Final simulation: 4
# Time taken: 0.8609836101531982
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 69
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.021756050745801843
# Best robustness -0.041482813787809825
# Final distance 0.001273944510807989
# Final simulation: 4
# Time taken: 1.0582153797149658
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.046697777195440424
# Best robustness -0.0149323623658284
# Final distance 0.0009061769472568847
# Final simulation: 6
# Time taken: 1.5065035820007324
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.28267543938518014
# Best robustness 0.000673572552881696
# Final distance 0.001623493946773163
# Final simulation: 10
# Time taken: 2.6589713096618652
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.052775279763020586
# Best robustness -0.016205337264521447
# Final distance 0.0013621827525123755
# Final simulation: 8
# Time taken: 2.23893141746521
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.188532744557504
# Best robustness -0.016411382057676116
# Final distance 0.0017583325245631343
# Final simulation: 6
# Time taken: 1.5669691562652588
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.27389905360121075
# Best robustness -0.014432614759169349
# Final distance 0.0013964976258276438
# Final simulation: 6
# Time taken: 1.5096287727355957
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0774098571839789
# Best robustness -0.0045207115808985066
# Final distance 0.001802861826723146
# Final simulation: 10
# Time taken: 3.0231871604919434
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 61
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.25392126492305706
# Best robustness -0.046610205960248896
# Final distance 0.0015573868109671203
# Final simulation: 9
# Time taken: 2.454524040222168
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2604379225504101
# Best robustness -0.04030182492081047
# Final distance 0.0011563340652535287
# Final simulation: 6
# Time taken: 1.6066222190856934
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6876209472219005
# Best robustness -0.024291141133871763
# Final distance 0.0015720908667858165
# Final simulation: 9
# Time taken: 2.465939521789551
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5256340947244541
# Best robustness 0.0010704627047946058
# Final distance 0.0015859130994453855
# Final simulation: 10
# Time taken: 3.041890859603882
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6246185590382518
# Best robustness -0.008280078009833103
# Final distance 0.001176315739726271
# Final simulation: 7
# Time taken: 2.147470712661743
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5782437593679763
# Best robustness -0.05845836823016537
# Final distance 0.0017328192201981963
# Final simulation: 15
# Time taken: 5.6902830600738525
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.32333665118396177
# Best robustness -0.032108884504622015
# Final distance 0.0016147213492494234
# Final simulation: 10
# Time taken: 3.470561981201172
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04140213356491756
# Best robustness -0.051774688649432576
# Final distance 0.0015772187961865885
# Final simulation: 6
# Time taken: 1.8696763515472412
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10070109372201998
# Best robustness -0.02877481894808631
# Final distance 0.0011238080450470581
# Final simulation: 4
# Time taken: 1.2517218589782715
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.41112493217101886
# Best robustness -0.001148591463994375
# Final distance 0.0016292543542488023
# Final simulation: 7
# Time taken: 2.2678372859954834
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03888935659888765
# Best robustness 0.0006422058035276956
# Final distance 0.0010690130007787971
# Final simulation: 8
# Time taken: 2.6119110584259033
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.080445721972797
# Best robustness -0.007441405040323534
# Final distance 0.001986500490861045
# Final simulation: 10
# Time taken: 3.265303134918213
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.496281801432357
# Best robustness -0.0058847477637020695
# Final distance 0.0015383387511298714
# Final simulation: 7
# Time taken: 1.9449162483215332
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.580799128827541
# Best robustness -0.00032090173731313953
# Final distance 0.0007934332268785995
# Final simulation: 24
# Time taken: 8.298649787902832
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08087285113958612
# Best robustness -0.016038026547591233
# Final distance 0.0015438126707347974
# Final simulation: 6
# Time taken: 1.598839282989502
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.36151181388502696
# Best robustness -0.007960695553518304
# Final distance 0.0016771657063136974
# Final simulation: 4
# Time taken: 1.0078907012939453
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13383738289512565
# Best robustness 0.0007501922023220864
# Final distance 0.0016214307169618632
# Final simulation: 9
# Time taken: 2.619123697280884
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.8593666964386595
# Best robustness -0.04146653058300798
# Final distance 0.0019351508542105268
# Final simulation: 7
# Time taken: 2.1333370208740234
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.273973763606953
# Best robustness -0.00192887973741529
# Final distance 0.0018247101047985943
# Final simulation: 11
# Time taken: 3.6342430114746094
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7251362718712878
# Best robustness -0.0283282024787872
# Final distance 0.0010615832668057262
# Final simulation: 9
# Time taken: 2.6762139797210693
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5972313635616735
# Best robustness 0.0006306505865905088
# Final distance 0.0014835606653934301
# Final simulation: 10
# Time taken: 3.0490481853485107
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3770144254339778
# Best robustness -0.03801696580552849
# Final distance 0.0018421930059834297
# Final simulation: 15
# Time taken: 4.644259452819824
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.027227013885108578
# Best robustness -0.015526371604567935
# Final distance 0.0014789697527316367
# Final simulation: 7
# Time taken: 2.113823413848877
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.43296152567033247
# Best robustness -0.04103630926996371
# Final distance 0.0016493975168124372
# Final simulation: 10
# Time taken: 3.3741729259490967
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19126915687180773
# Best robustness -0.0025984559191576384
# Final distance 0.0012500141349208794
# Final simulation: 9
# Time taken: 3.0164759159088135
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6728810467174283
# Best robustness -0.03469742881424165
# Final distance 0.0010411951951196162
# Final simulation: 7
# Time taken: 2.0009989738464355
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7509061190610256
# Best robustness -0.032298699065832936
# Final distance 0.0015530241958801809
# Final simulation: 28
# Time taken: 9.885176181793213
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03007687925145838
# Best robustness -0.058393695403832435
# Final distance 0.0012046129337359977
# Final simulation: 8
# Time taken: 2.418097734451294
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1289251605870238
# Best robustness -0.0007508055724991802
# Final distance 0.0018927931745326288
# Final simulation: 47
# Time taken: 17.85708999633789
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4697512387394003
# Best robustness -0.06880149704660643
# Final distance 0.001434839812602758
# Final simulation: 15
# Time taken: 5.430500030517578
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.534699576883518
# Best robustness -0.06324194132091199
# Final distance 0.001026419954447051
# Final simulation: 6
# Time taken: 1.8032598495483398
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7840842236487443
# Best robustness -0.053737850170658685
# Final distance 0.0015806823076930578
# Final simulation: 18
# Time taken: 5.836005210876465
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.524369821827685
# Best robustness -0.003962373284971843
# Final distance 0.0008547535654645441
# Final simulation: 9
# Time taken: 2.840658187866211
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10684125625800596
# Best robustness -0.0020356774361816043
# Final distance 0.001510971146139999
# Final simulation: 19
# Time taken: 7.072161674499512
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.8147515640308919
# Best robustness -0.047664350989787385
# Final distance 0.0019423400795214598
# Final simulation: 10
# Time taken: 3.038811445236206
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3860899128384101
# Best robustness -0.010127540483406028
# Final distance 0.001222361634572234
# Final simulation: 10
# Time taken: 3.4174649715423584
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 61
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6170860278770393
# Best robustness -0.013592647354639276
# Final distance 0.0008508098622326726
# Final simulation: 11
# Time taken: 4.371139764785767
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7416026972698578
# Best robustness -0.0015550632025591593
# Final distance 0.0016643715750812307
# Final simulation: 10
# Time taken: 3.53302001953125
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5735409122679851
# Best robustness 0.0016844392044570444
# Final distance 0.008970818795781415
# Final simulation: 51
# Time taken: 16.79140543937683
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22066569054266277
# Best robustness -0.008749260740619658
# Final distance 0.0017153038536024806
# Final simulation: 3
# Time taken: 0.7450788021087646
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7770668841477559
# Best robustness 0.001476224662690262
# Final distance 0.0019491861516577986
# Final simulation: 9
# Time taken: 2.6955509185791016
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.39585149559925253
# Best robustness 0.0015590440366547442
# Final distance 0.0029604813400454506
# Final simulation: 51
# Time taken: 17.13912606239319
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2895066894414512
# Best robustness 0.0019318117969238102
# Final distance 0.0013852858748728185
# Final simulation: 9
# Time taken: 2.778886079788208
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.8480214111541023
# Best robustness -0.00881063916087621
# Final distance 0.0013269885600880086
# Final simulation: 9
# Time taken: 3.3302533626556396
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1060874971654638
# Best robustness 0.0014591763034794702
# Final distance 0.0017705998673626152
# Final simulation: 5
# Time taken: 1.7165942192077637
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2845117085699944
# Best robustness -0.011676173348333263
# Final distance 0.0015129599170196281
# Final simulation: 10
# Time taken: 3.467022657394409
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4457885397559515
# Best robustness -0.010569258121896796
# Final distance 0.0011152127494689595
# Final simulation: 6
# Time taken: 1.9839887619018555
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7803982728190949
# Best robustness -0.00018488334949395835
# Final distance 0.0018463086256522226
# Final simulation: 9
# Time taken: 3.10888409614563
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1648491695063419
# Best robustness -0.04434390763409457
# Final distance 0.0016200430887276546
# Final simulation: 10
# Time taken: 3.163299560546875
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6669527460644096
# Best robustness -0.006514244866020702
# Final distance 0.0013920107933108865
# Final simulation: 8
# Time taken: 2.7910029888153076
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.332057027932693
# Best robustness -0.009099780610509756
# Final distance 0.0011492502988388448
# Final simulation: 7
# Time taken: 2.0879781246185303
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07523922635195288
# Best robustness -0.0004013866438956626
# Final distance 0.0018259583822293126
# Final simulation: 17
# Time taken: 5.531454086303711
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06621081714801627
# Best robustness -0.05201280466593361
# Final distance 0.0014466099822255123
# Final simulation: 7
# Time taken: 1.9279255867004395
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08671338727947722
# Best robustness -0.016754965501646124
# Final distance 0.0014302022814888413
# Final simulation: 9
# Time taken: 2.716538429260254
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5264435803616335
# Best robustness 0.0009489192251335155
# Final distance 0.0009884473254506507
# Final simulation: 20
# Time taken: 6.762860059738159
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5136900064280914
# Best robustness -0.061670008361025985
# Final distance 0.0011456579649000865
# Final simulation: 12
# Time taken: 3.790506362915039
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09947051077679188
# Best robustness -0.012639437861705405
# Final distance 0.001542933579959465
# Final simulation: 10
# Time taken: 3.255866765975952
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 69
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14107586179478973
# Best robustness -0.013637492370896398
# Final distance 0.001714980015099931
# Final simulation: 5
# Time taken: 1.3673632144927979
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4361157769946458
# Best robustness -0.03799385465286442
# Final distance 0.006839463779320755
# Final simulation: 51
# Time taken: 16.422935485839844
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6134484433711116
# Best robustness -0.01296528305093303
# Final distance 0.0008874956114923814
# Final simulation: 16
# Time taken: 5.392001390457153
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7607037934990875
# Best robustness -0.011828644784698916
# Final distance 0.0008232216663055525
# Final simulation: 8
# Time taken: 2.523185968399048
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10134637942607047
# Best robustness -0.014741058791909678
# Final distance 0.001686666193258888
# Final simulation: 20
# Time taken: 6.8196728229522705
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 62
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.007562621306170467
# Best robustness -0.02579429892862617
# Final distance 0.0010453392894305754
# Final simulation: 4
# Time taken: 1.1518819332122803
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.027980752535661933
# Best robustness -0.009671219238815754
# Final distance 0.0012872336576662102
# Final simulation: 6
# Time taken: 1.9145750999450684
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06041701893251181
# Best robustness -0.05994211609682676
# Final distance 0.000995426587002266
# Final simulation: 6
# Time taken: 2.1053552627563477
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7857069902682325
# Best robustness -0.0480593495846493
# Final distance 0.001582108282784827
# Final simulation: 10
# Time taken: 3.278714656829834
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09063869344081148
# Best robustness -0.04435659688467908
# Final distance 0.003293302272272112
# Final simulation: 51
# Time taken: 17.63674807548523
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4694370507756122
# Best robustness -0.03580515749550539
# Final distance 0.006190159424529264
# Final simulation: 51
# Time taken: 16.958866119384766
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 62
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2515392003794208
# Best robustness 0.0005470096702452354
# Final distance 0.0017284222797872531
# Final simulation: 4
# Time taken: 1.0174293518066406
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3371356139354896
# Best robustness -0.02000435532565481
# Final distance 0.0008437632028080246
# Final simulation: 8
# Time taken: 2.365551710128784
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.047817937968351674
# Best robustness -0.003605099350697083
# Final distance 0.001365870125616
# Final simulation: 3
# Time taken: 0.7546472549438477
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 61
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.006646389381078632
# Best robustness -0.0038295784377213593
# Final distance 0.0013993136593630229
# Final simulation: 3
# Time taken: 0.6961195468902588
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.006299748866330287
# Best robustness -0.0035214049670704295
# Final distance 0.001613191409671077
# Final simulation: 5
# Time taken: 1.3530895709991455
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2605402803480069
# Best robustness -0.004923167573739118
# Final distance 0.0012594818252214084
# Final simulation: 9
# Time taken: 2.5758838653564453
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.30818652199027413
# Best robustness -0.03454395358481177
# Final distance 0.0013361145277784952
# Final simulation: 27
# Time taken: 8.791410684585571
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.37420737665726267
# Best robustness 0.0009247254719275677
# Final distance 0.0005716919320108311
# Final simulation: 27
# Time taken: 8.427618265151978
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4146749037097009
# Best robustness 0.0004475002962979202
# Final distance 0.001530513688069414
# Final simulation: 6
# Time taken: 1.5644659996032715
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 66
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03339174241016616
# Best robustness -0.013872004778874736
# Final distance 0.0014536227293972422
# Final simulation: 8
# Time taken: 2.3274118900299072
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 61
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5317059756164504
# Best robustness -0.022472183277137958
# Final distance 0.0015721106720148308
# Final simulation: 10
# Time taken: 2.7671093940734863
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.059806327048522887
# Best robustness -0.001865354058582236
# Final distance 0.0012488698557620228
# Final simulation: 9
# Time taken: 2.651949405670166
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.8419273745535049
# Best robustness -0.047958647206957083
# Final distance 0.001447785048270221
# Final simulation: 18
# Time taken: 5.512205600738525
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15670846452744194
# Best robustness -0.05976456819232179
# Final distance 0.0019240423722825498
# Final simulation: 9
# Time taken: 2.395054578781128
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 62
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1315064474061983
# Best robustness -0.07032900567153044
# Final distance 0.0014051385060796244
# Final simulation: 30
# Time taken: 8.910788536071777
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 62
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22862777130659936
# Best robustness -0.034185777748863
# Final distance 0.0013433904513175795
# Final simulation: 26
# Time taken: 8.127222776412964
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.41291890527129294
# Best robustness -0.05917103755457731
# Final distance 0.0015593925738124914
# Final simulation: 19
# Time taken: 5.208410263061523
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.356252934303036
# Best robustness -0.055249114971543056
# Final distance 0.0028725348072527147
# Final simulation: 51
# Time taken: 13.540298461914062
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14274052580565977
# Best robustness -0.0695678049365096
# Final distance 0.005392571211615553
# Final simulation: 51
# Time taken: 14.082218647003174
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05388087297019192
# Best robustness -0.01573874265187092
# Final distance 0.0014365072007180041
# Final simulation: 5
# Time taken: 1.1978464126586914
# idx **** 100
# 13.73
# -0.02135743492393637
# 51
# 166.13709999999995

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC4')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(100)
# dataObject.setLowerBound([0.3, 0.3, 0.3])
# dataObject.setUpperBound([0.6, 0.6, 0.6])
# dataObject.setStepSize(0.02)
dataObject.setStepSize(0.04)
lowerBound = [0.7, -0.1, -0.9]
upperBound = [0.8, 0.0, -0.8]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.7, 0.9]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
#     print(ref_traj[70], ref_traj[80])
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.001, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))

# dataObject.setLowerBound([0.3, 0.3, 0.3])
# dataObject.setUpperBound([0.7, 0.7, 0.7])
# 30.28
# -0.0025459865153509846

# 27.08
# -0.002204494115805341
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC4.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [17, 18, 19, 20, 21]
# 20
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12571866816150118
# Best robustness -0.005032939549303284
# Final distance 0.000988095857031152
# Final simulation: 32
# Time taken: 28.836780548095703
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [17, 18, 19, 20, 21]
# 20
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09758206686517876
# Best robustness -0.006080332778006831
# Final distance 0.0006348502403342184
# Final simulation: 30
# Time taken: 27.236449003219604
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [17, 18, 19, 20, 21]
# 17
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5529049339974396
# Best robustness -0.03113962495386432
# Final distance 0.00065776009269
# Final simulation: 10
# Time taken: 8.703398942947388
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [17, 18, 19, 20, 21]
# 17
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5073807846359857
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fa4243d0a57b> in <module>
#      36     dests = dest
#      37     evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.001,
# ---> 38                         correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
#      39     f_sims = evalObject.getFSimulations()
#      40     min_dist = evalObject.getFDistance()
#
# ~/Research/NExG/core/evaluation_isen.py in reachDestInvSen(self, dests, d_time_steps, threshold, correction_steps, scaling_factors, i_state)
#     376                                                      threshold=threshold,  model_v=trained_model, correction_steps=steps,
#     377                                                      scaling_factor=s_factor, sims_bound=self.sims_bound,
# --> 378                                                      dynamics=self.dynamics)
#     379                         print("Time taken: " + str(time.time() - start_time))
#     380
#
# ~/Research/NExG/core/evaluation_isen.py in reachDestInvNonBaseline(self, ref_traj, paths, d_time_step, threshold, model_v, correction_steps, sims_bound, scaling_factor, rand_area, dynamics)
#     552                 sims_count = sims_count + 1
#     553
# --> 554                 new_traj = self.data_object.generateTrajectories(r_states=[x_vals[len(x_vals) - 1]])[0]
#     555                 x_val = new_traj[0]
#     556                 xp_val = new_traj[d_time_step]
#
# ~/Research/NExG/configuration-setup/configuration.py in generateTrajectories(self, scaling, samples, r_states, dump_i_states)
#     184                 dnn_controller_obj = DnnController(dnn_cntrl_fname, self.dimensions)
#     185                 plant = Plant(self.dynamics, dnn_controller_obj, dnn_transform_obj, self.steps)
# --> 186                 plant.dnn_controllers[0].parseDNNYML(self.dynamics)
#     187         elif self.dynamics is 'CartPoleLinControl':
#     188             plant = nonNNPlant('CartPoleLinControl')
#
# ~/Research/NExG/configuration-setup/nnControllerHybridSystems.py in parseDNNYML(self, dynamics)
#      19         # print("Parsing DNN YML file.")
#      20         yaml_f = open(self.dnn_file, 'r')
# ---> 21         yml_obj = yaml.load(yaml_f)
#      22         acts = yml_obj.get('activations')
#      23         offsets = yml_obj.get('offsets')
#
# /usr/lib/python3/dist-packages/yaml/__init__.py in load(stream, Loader)
#      70     loader = Loader(stream)
#      71     try:
# ---> 72         return loader.get_single_data()
#      73     finally:
#      74         loader.dispose()
#
# /usr/lib/python3/dist-packages/yaml/constructor.py in get_single_data(self)
#      33     def get_single_data(self):
#      34         # Ensure that the stream contains a single document and construct it.
# ---> 35         node = self.get_single_node()
#      36         if node is not None:
#      37             return self.construct_document(node)
#
# /usr/lib/python3/dist-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     109         index = 0
#     110         while not self.check_event(SequenceEndEvent):
# --> 111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#     113         end_event = self.get_event()
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# /usr/lib/python3/dist-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     108             self.anchors[anchor] = node
#     109         index = 0
# --> 110         while not self.check_event(SequenceEndEvent):
#     111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#
# /usr/lib/python3/dist-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# /usr/lib/python3/dist-packages/yaml/parser.py in parse_flow_sequence_entry(self, first)
#     484                             "expected ',' or ']', but got %r" % token.id, token.start_mark)
#     485
# --> 486             if self.check_token(KeyToken):
#     487                 token = self.peek_token()
#     488                 event = MappingStartEvent(None, None, True,
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in check_token(self, *choices)
#     114         # Check if the next token is one of the given types.
#     115         while self.need_more_tokens():
# --> 116             self.fetch_more_tokens()
#     117         if self.tokens:
#     118             if not choices:
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in fetch_more_tokens(self)
#     157
#     158         # Remove obsolete possible simple keys.
# --> 159         self.stale_possible_simple_keys()
#     160
#     161         # Compare the current indentation and column. It may add some tokens
#
# /usr/lib/python3/dist-packages/yaml/scanner.py in stale_possible_simple_keys(self)
#     281         # Disabling this procedure will allow simple keys of any length and
#     282         # height (may cause problems if indentation is broken though).
# --> 283         for level in list(self.possible_simple_keys):
#     284             key = self.possible_simple_keys[level]
#     285             if key.line != self.line  \
#
# KeyboardInterrupt:

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC4')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(30)
# dataObject.setLowerBound([0.3, 0.3, 0.3])
# dataObject.setUpperBound([0.6, 0.6, 0.6])
dataObject.setStepSize(0.05)
lowerBound = [0.7, -0.1, -0.9]
upperBound = [0.8, 0.0, -0.8]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.7, 0.9]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
#     ref_traj = dataObject.generateTrajectories(r_states=[[0.327013581183063, 0.411575684475361, 0.302279409447952]])[0]
#     print(ref_traj)
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))

# for 0.6 * external states
# 32.88
# -0.006182414672606448
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC4.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3456809650614082
# /home/manishg/Research/NExG/core/evaluation_isen.py:543: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Best robustness 0.007658121303618989
# Final distance 0.004800960851310762
# Final simulation: 51
# Time taken: 32.965545654296875
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06374813910961
# Best robustness -0.009934772457379877
# Final distance 0.0019680468375950565
# Final simulation: 21
# Time taken: 13.083438634872437
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6228341103287244
# Best robustness 0.008562939876352482
# Final distance 0.004880642104657754
# Final simulation: 51
# Time taken: 30.58647894859314
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13847170433555278
# Best robustness 0.013282306951795442
# Final distance 0.016429678407384005
# Final simulation: 51
# Time taken: 31.65341329574585
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4546873755783523
# Best robustness 0.0016800954083913133
# Final distance 0.001507407643248816
# Final simulation: 14
# Time taken: 8.188221454620361
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4251985038391916
# Best robustness 0.009577707850917605
# Final distance 0.0017819672239046435
# Final simulation: 27
# Time taken: 16.29276204109192
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14365664278641085
# Best robustness -0.004871494313336664
# Final distance 0.0018936674169561486
# Final simulation: 29
# Time taken: 17.97621512413025
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10013292875030373
# Best robustness 0.008539353070308509
# Final distance 0.0019009215662179428
# Final simulation: 10
# Time taken: 5.581278085708618
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1567990870654472
# Best robustness 0.000517026527319997
# Final distance 0.008902077086875572
# Final simulation: 51
# Time taken: 31.615986585617065
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09519424058711641
# Best robustness 0.0030807454555625835
# Final distance 0.001769334652782562
# Final simulation: 10
# Time taken: 5.730170726776123
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.44546680307935416
# Best robustness 0.012368302440944556
# Final distance 0.0010625407572847324
# Final simulation: 13
# Time taken: 7.5041985511779785
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05949511312829381
# Best robustness 0.006894862960293127
# Final distance 0.05949511312829381
# Final simulation: 51
# Time taken: 31.506227254867554
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0898745899736371
# Best robustness 0.003722627301753656
# Final distance 0.0016881596059487036
# Final simulation: 7
# Time taken: 3.8296124935150146
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3811802282025247
# Best robustness 0.026361652642295313
# Final distance 0.0018535227552250952
# Final simulation: 7
# Time taken: 3.771456480026245
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.42097412977259463
# Best robustness 0.0009608462278398733
# Final distance 0.0013109197110208178
# Final simulation: 13
# Time taken: 7.470986843109131
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23034276528891345
# Best robustness 0.003782150724630253
# Final distance 0.011474934438475309
# Final simulation: 51
# Time taken: 31.383974075317383
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03902209118892897
# Best robustness 0.007996488588069228
# Final distance 0.005203440462654897
# Final simulation: 51
# Time taken: 31.053178548812866
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4061972828490705
# Best robustness 0.002552670283788472
# Final distance 0.02276281591272963
# Final simulation: 51
# Time taken: 31.14643621444702
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.43710160774017853
# Best robustness 0.00897719791899898
# Final distance 0.046771294053081426
# Final simulation: 51
# Time taken: 30.876523733139038
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2116840674299418
# Best robustness 0.007927769157449145
# Final distance 0.0019203700762040637
# Final simulation: 14
# Time taken: 8.309274911880493
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4726602233990308
# Best robustness 0.004974659970974571
# Final distance 0.01842963379143101
# Final simulation: 51
# Time taken: 32.29230451583862
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07249932346661106
# Best robustness 0.017831876088334475
# Final distance 0.0015250177045471561
# Final simulation: 9
# Time taken: 5.204903602600098
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4161726538565444
# Best robustness 0.00920304744797723
# Final distance 0.07325233660720343
# Final simulation: 51
# Time taken: 30.590163469314575
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.21120118325579718
# Best robustness 2.92045080297898e-05
# Final distance 0.0010304438053263824
# Final simulation: 8
# Time taken: 4.262143850326538
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3835355432523623
# Best robustness 0.003928043234758544
# Final distance 0.01133606109389368
# Final simulation: 51
# Time taken: 31.08402395248413
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16884476896963407
# Best robustness 0.01155152020117578
# Final distance 0.02682644371564453
# Final simulation: 51
# Time taken: 30.93179154396057
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.058457362296424495
# Best robustness 0.009342541863625556
# Final distance 0.0015603444909905136
# Final simulation: 5
# Time taken: 2.4539008140563965
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.26659972601443577
# Best robustness 0.0049539432652829785
# Final distance 0.023781902319597314
# Final simulation: 51
# Time taken: 31.682116508483887
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13370409602971578
# Best robustness 0.0014835758209043037
# Final distance 0.0018075447741335517
# Final simulation: 7
# Time taken: 3.623164415359497
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07522519374653794
# Best robustness -0.0031779683204733867
# Final distance 0.0016462431563811987
# Final simulation: 6
# Time taken: 3.2019717693328857
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.403893209607493
# Best robustness 0.0017682068291767772
# Final distance 0.0038412947743076084
# Final simulation: 51
# Time taken: 30.84723997116089
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49381349669632735
# Best robustness 0.004323968554156399
# Final distance 0.0014503352688180423
# Final simulation: 11
# Time taken: 6.4093616008758545
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4083983551669042
# Best robustness 0.01391003941249791
# Final distance 0.0010033993614828028
# Final simulation: 20
# Time taken: 11.64958381652832
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5592320907389278
# Best robustness 0.005727320966125715
# Final distance 0.007289230137977176
# Final simulation: 51
# Time taken: 30.629369258880615
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.47639009149543754
# Best robustness 0.008214096979410961
# Final distance 0.004128159147001309
# Final simulation: 51
# Time taken: 31.30109477043152
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14685484759119724
# Best robustness 0.0036340303239882354
# Final distance 0.0018033025352902235
# Final simulation: 16
# Time taken: 9.450307846069336
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1430238251150518
# Best robustness 0.00842201476069393
# Final distance 0.10748572013499777
# Final simulation: 51
# Time taken: 31.129924297332764
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10906211065174799
# Best robustness 0.010295762559589503
# Final distance 0.0010782267277111403
# Final simulation: 7
# Time taken: 3.743110179901123
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.31105721123592833
# Best robustness 0.018220086348097797
# Final distance 0.001292507162637463
# Final simulation: 41
# Time taken: 25.090725660324097
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5148421450914608
# Best robustness 0.008320272429863662
# Final distance 0.006245505153901846
# Final simulation: 51
# Time taken: 30.33454155921936
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2972401011180824
# Best robustness 0.0017486586628825407
# Final distance 0.001424212593603242
# Final simulation: 10
# Time taken: 5.633770227432251
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.31315031280997135
# Best robustness -0.003797527981434401
# Final distance 0.0018495604039658472
# Final simulation: 8
# Time taken: 4.581746816635132
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.39094734096468353
# Best robustness 0.0036877061671818367
# Final distance 0.03383857119311777
# Final simulation: 51
# Time taken: 31.341230154037476
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.46341436532253416
# Best robustness 0.004027344915989439
# Final distance 0.0014714001635664845
# Final simulation: 9
# Time taken: 5.056481838226318
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4737508311874042
# Best robustness 0.016040313133650872
# Final distance 0.0022090168970230833
# Final simulation: 51
# Time taken: 31.226062297821045
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.304944718611759
# Best robustness -0.00937350867667906
# Final distance 0.001830474275432362
# Final simulation: 9
# Time taken: 5.187227487564087
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4172702112457978
# Best robustness 0.011346462566590554
# Final distance 0.001259782372537248
# Final simulation: 29
# Time taken: 17.703307628631592
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19339404585872086
# Best robustness 0.005449276607008002
# Final distance 0.0011852134456490466
# Final simulation: 17
# Time taken: 9.997275590896606
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33349241861071105
# Best robustness 0.00046313800849214024
# Final distance 0.0013000425698117182
# Final simulation: 28
# Time taken: 16.707650184631348
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1730503778726206
# Best robustness 0.004770610291734645
# Final distance 0.0014407719658076988
# Final simulation: 7
# Time taken: 4.003731727600098
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19372695761040712
# Best robustness 0.003754569663830143
# Final distance 0.08104674034222895
# Final simulation: 51
# Time taken: 32.04114508628845
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19630935064239274
# Best robustness 0.02278022439547952
# Final distance 0.0017745477216098726
# Final simulation: 7
# Time taken: 3.65344500541687
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3466778465607073
# Best robustness 0.00021489882605165572
# Final distance 0.0017214176709086063
# Final simulation: 18
# Time taken: 10.431981801986694
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4752093311666569
# Best robustness 0.0013490744539952464
# Final distance 0.0019345488529983119
# Final simulation: 9
# Time taken: 5.08999228477478
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4734577750869859
# Best robustness 0.00807490107776232
# Final distance 0.0014746368230309159
# Final simulation: 16
# Time taken: 9.465951681137085
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6075945191232301
# Best robustness 0.008561106368812132
# Final distance 0.0013146875445757358
# Final simulation: 45
# Time taken: 28.154205083847046
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3129700357008939
# Best robustness 0.004585322101491459
# Final distance 0.021733556674143718
# Final simulation: 51
# Time taken: 30.97062611579895
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4317893266894945
# Best robustness 0.00320155283731427
# Final distance 0.0016722864662967985
# Final simulation: 7
# Time taken: 3.777893543243408
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16234863920822096
# Best robustness 0.029677339992618127
# Final distance 0.00152020142504893
# Final simulation: 7
# Time taken: 3.794734477996826
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3180816542930645
# Best robustness -0.002915886284931405
# Final distance 0.0013576960577122723
# Final simulation: 8
# Time taken: 4.473130702972412
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06611003857235243
# Best robustness -0.010346185665895881
# Final distance 0.010852585838266971
# Final simulation: 51
# Time taken: 31.45371723175049
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.21551914871988276
# Best robustness 0.0012487290281612126
# Final distance 0.013804233509426646
# Final simulation: 51
# Time taken: 30.73742365837097
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.42865384529370193
# Best robustness 0.0016443672949720822
# Final distance 0.005871082324356216
# Final simulation: 51
# Time taken: 30.678645849227905
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.052715951956118945
# Best robustness 0.02541712821603273
# Final distance 0.0016401441632701139
# Final simulation: 8
# Time taken: 4.578501224517822
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4430712032941944
# Best robustness 0.0025854341676805337
# Final distance 0.005456145140853518
# Final simulation: 51
# Time taken: 31.962860345840454
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17059913331639803
# Best robustness 0.007131609075892423
# Final distance 0.00835714961456064
# Final simulation: 51
# Time taken: 33.383498668670654
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1638579242517846
# Best robustness 0.002639320910826304
# Final distance 0.004738832956835997
# Final simulation: 51
# Time taken: 33.21449065208435
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4020599395301037
# Best robustness 0.003462294031402413
# Final distance 0.008671542711361264
# Final simulation: 51
# Time taken: 32.43732714653015
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.362929066438228
# Best robustness 0.018859671331827327
# Final distance 0.0019567150577237454
# Final simulation: 11
# Time taken: 6.444208145141602
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23241429650679113
# Best robustness 0.006127046382164325
# Final distance 0.001565814706752589
# Final simulation: 8
# Time taken: 4.586058616638184
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3327993897657477
# Best robustness 0.010413317011173207
# Final distance 0.0009188836204114369
# Final simulation: 11
# Time taken: 6.124925374984741
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3740256437188525
# Best robustness 0.003710396332098193
# Final distance 0.0016563371119715988
# Final simulation: 8
# Time taken: 4.298141717910767
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.28743930168263704
# Best robustness 0.0011266639226255037
# Final distance 0.008539581302709775
# Final simulation: 51
# Time taken: 31.371607065200806
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5289429123882913
# Best robustness 0.0014210615626646383
# Final distance 0.01742185032792793
# Final simulation: 51
# Time taken: 31.91666030883789
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14678821839552963
# Best robustness 0.010824819826241838
# Final distance 0.034770217317675794
# Final simulation: 51
# Time taken: 31.14025640487671
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33921853682380354
# Best robustness 0.010141789382628663
# Final distance 0.020301425522195174
# Final simulation: 51
# Time taken: 31.25106978416443
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.35185105983756415
# Best robustness 0.023995094868114523
# Final distance 0.0014517679859430816
# Final simulation: 9
# Time taken: 5.1038830280303955
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23523783829102557
# Best robustness 0.015522896884751412
# Final distance 0.001143663630287037
# Final simulation: 9
# Time taken: 5.037935733795166
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08365722277453387
# Best robustness 0.005793021147071522
# Final distance 0.0017369806620750159
# Final simulation: 13
# Time taken: 7.62778902053833
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13499151216374505
# Best robustness 0.005168653590089001
# Final distance 0.00136895187568395
# Final simulation: 6
# Time taken: 3.0406692028045654
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07658016130692279
# Best robustness 0.020040187185238464
# Final distance 0.028347193765936113
# Final simulation: 51
# Time taken: 31.740900993347168
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.644963376802447
# Best robustness 0.0067167115645218045
# Final distance 0.0013923241336057926
# Final simulation: 36
# Time taken: 22.17003345489502
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02765299755491316
# Best robustness 0.012711942401430896
# Final distance 0.011672419872799605
# Final simulation: 51
# Time taken: 30.40169095993042
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2683952614586419
# Best robustness 0.015670520501987584
# Final distance 0.01747508034031022
# Final simulation: 51
# Time taken: 30.74214792251587
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3547990986196787
# Best robustness 0.010694008148895762
# Final distance 0.0019533001854280876
# Final simulation: 15
# Time taken: 8.799720764160156
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33980178786046616
# Best robustness 0.0036544322354404857
# Final distance 0.0014702902738099044
# Final simulation: 37
# Time taken: 22.43855094909668
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3335003776142828
# Best robustness -0.006009048275026478
# Final distance 0.0013886556352578066
# Final simulation: 8
# Time taken: 4.282192945480347
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10632725672337492
# Best robustness 0.008840523392340238
# Final distance 0.0029005521398713374
# Final simulation: 51
# Time taken: 32.065857887268066
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 15
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22764447107098482
# Best robustness 0.00630261518230046
# Final distance 0.0022227393177112914
# Final simulation: 51
# Time taken: 30.851712942123413
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33152097974259503
# Best robustness -0.004554556531671863
# Final distance 0.0017749183736422854
# Final simulation: 11
# Time taken: 6.3111796379089355
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2955312858118657
# Best robustness 0.015715853885855724
# Final distance 0.13265056229273064
# Final simulation: 51
# Time taken: 30.721927165985107
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12251074699514514
# Best robustness 0.01357177520074243
# Final distance 0.0016107837756431124
# Final simulation: 12
# Time taken: 6.812469482421875
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3160459278018831
# Best robustness 0.0014348850282847048
# Final distance 0.0017308532580630038
# Final simulation: 24
# Time taken: 14.851654052734375
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5582184050131814
# Best robustness 0.01273951240692428
# Final distance 0.007502283764525095
# Final simulation: 51
# Time taken: 30.431397676467896
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6422169805661135
# Best robustness 0.002620556557612619
# Final distance 0.010087365988210016
# Final simulation: 51
# Time taken: 31.018442153930664
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 14
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15845825112527695
# Best robustness 0.01441378569523688
# Final distance 0.0015976585133524637
# Final simulation: 7
# Time taken: 3.828367233276367
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07554004068219304
# Best robustness 0.02493266102397879
# Final distance 0.0015984495681920373
# Final simulation: 7
# Time taken: 3.8098058700561523
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 13
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2769655130161499
# Best robustness 0.01044371314581316
# Final distance 0.001859594143091454
# Final simulation: 44
# Time taken: 26.868826150894165
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13483710787976383
# Best robustness 0.005218517329260375
# Final distance 0.0013805976465618229
# Final simulation: 46
# Time taken: 28.701778888702393
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC4_RBF_1_512_ReLU.h5
# [13, 14, 15, 16, 17]
# 16
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.26073216527540877
# Best robustness 0.0032773124291783726
# Final distance 0.012558683804725324
# Final simulation: 51
# Time taken: 32.306419134140015
# idx **** 100
# 30.52
# 0.007015614561005104
# 51
# 384.2896

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC4')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
lowerBound = [0.7, -0.1, -0.9]
upperBound = [0.8, 0.0, -0.8]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [0.7, 0.9]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0


r_state = [0.329562422667942, 0.369785866549328, 0.537411688660051]

r_state = [0.384903434222889, 0.306248810042829, 0.575016334813959]

r_state = [0.321561910264900, 0.384960602889500, 0.481071956331271]

ref_traj = dataObject.generateTrajectories(r_states=[r_state])[0]

for t_idx in range(int(stl_time_interval[0]/dataObject.getStepSize()), int(stl_time_interval[1]/dataObject.getStepSize())):
#     print(t_idx)
    print(ref_traj[t_idx])
# dest = evalObject.generateRandomUnsafeStates(1)
# dests = dest
# evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
#                         correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC4.txt
# [ 0.66628844  0.09047147 -0.90418646]
# [ 0.67124616  0.08151857 -0.90632379]
# [ 0.67613173  0.07254639 -0.90804384]
# [ 0.68094125  0.06355905 -0.90935671]
# [ 0.68567097  0.05456058 -0.91027231]
# [ 0.69031722  0.0455549  -0.91080037]
# [ 0.69487648  0.03654584 -0.91095043]
# [ 0.69934533  0.02753712 -0.91073182]
# [ 0.70372047  0.0185324  -0.9101537 ]
# [ 0.70799874  0.00953522 -0.90922506]
# [ 7.12177086e-01  5.49036160e-04 -9.07954838e-01]
# [ 0.71625259 -0.00842277 -0.90635203]
# [ 0.72022246 -0.01737692 -0.90442502]
# [ 0.72408403 -0.02631022 -0.90218205]
# [ 0.72783475 -0.03521954 -0.89963125]
# [ 0.73147222 -0.04410184 -0.89678056]
# [ 0.73499413 -0.05295418 -0.89363779]
# [ 0.73839832 -0.06177365 -0.89021057]
# [ 0.74168274 -0.07055746 -0.88650644]
# [ 0.74484548 -0.07930288 -0.88253279]

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC5')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
# dataObject.setSteps(100)
dataObject.setLowerBound([0.2, 0.2, 0.2])
dataObject.setUpperBound([0.6, 0.6, 0.6])
# dataObject.setStepSize(0.02)
lowerBound = [0.0, -0.1, 0.0]
upperBound = [0.1, 0.0, 0.1]
evalObject.setUnsafeSet([lowerBound, upperBound])
stl_time_interval = [1.0, 1.2]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
#     print(ref_traj[100], ref_traj[120])
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulationsCount()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC5.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12026519803864551
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05243063638410195
# Final simulation: 2
# Time taken: 0.556666374206543
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10397108556998523
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.0948129892559953
# Final simulation: 2
# Time taken: 0.7007589340209961
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06528579408086324
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.002114303377587612
# Final distance 0.010439807343675797
# Final simulation: 4
# Time taken: 1.702409267425537
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09290766479811774
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08127993523683474
# Final simulation: 2
# Time taken: 0.6345272064208984
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07922883886064751
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07346095401975902
# Final simulation: 2
# Time taken: 0.6098601818084717
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 105
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05115096127209229
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05115096127209229
# Final simulation: 2
# Time taken: 0.5916550159454346
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0850609037742449
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.0716286118255341
# Final simulation: 2
# Time taken: 0.579118013381958
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06696481313226613
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.009730243689597757
# Final simulation: 5
# Time taken: 2.3097262382507324
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11680622746154724
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05528418863306042
# Final simulation: 2
# Time taken: 0.7515342235565186
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09830748705201206
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08540821546479382
# Final simulation: 2
# Time taken: 0.6079087257385254
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06523664582678529
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01827707173875763
# Final distance 0.03249221796900173
# Final simulation: 2
# Time taken: 0.753659725189209
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05670833293480303
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.019008023856512027
# Final distance 0.056113032019862286
# Final simulation: 5
# Time taken: 2.382794141769409
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09252798252680912
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.030039113158432378
# Final simulation: 3
# Time taken: 1.1291134357452393
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05995741624309793
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05995741624309793
# Final simulation: 2
# Time taken: 0.7173399925231934
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 113
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06515977656115206
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006468716342677608
# Final distance 0.023698990653058027
# Final simulation: 3
# Time taken: 1.228463888168335
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 103
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04551658474649768
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.040493902774761836
# Final simulation: 2
# Time taken: 0.6229825019836426
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08120575097674695
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.03908597742439686
# Final simulation: 2
# Time taken: 0.6577997207641602
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12193021082692194
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06896111515141161
# Final simulation: 2
# Time taken: 0.6692473888397217
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10016787013632984
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08352627127340269
# Final simulation: 2
# Time taken: 0.6201696395874023
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 109
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10621727799271778
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06985121038737288
# Final simulation: 2
# Time taken: 0.5900909900665283
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11129166026152511
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08480829694100515
# Final simulation: 2
# Time taken: 0.5931386947631836
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09645368437966541
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.007255953993341604
# Final distance 0.034564758056528345
# Final simulation: 2
# Time taken: 0.5873210430145264
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10395506078737364
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.10308147918979442
# Final simulation: 2
# Time taken: 0.7068438529968262
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08839955632257333
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08839955632257333
# Final simulation: 2
# Time taken: 0.5546391010284424
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06348986928235302
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06348986928235302
# Final simulation: 2
# Time taken: 0.7387840747833252
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 106
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08469805457239366
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.04680100055074499
# Final simulation: 2
# Time taken: 0.6245086193084717
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09883955246906659
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08850832773302639
# Final simulation: 2
# Time taken: 0.597001314163208
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03554346370759348
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0037429936471239655
# Final distance 0.03554346370759348
# Final simulation: 1
# Time taken: 0.0002384185791015625
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03254213531461919
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.011587319493080644
# Final distance 0.03254213531461919
# Final simulation: 2
# Time taken: 0.6342861652374268
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08625932789492943
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08231799123348886
# Final simulation: 2
# Time taken: 0.7128098011016846
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 106
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.057398999867058355
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.015434831204618842
# Final distance 0.057398999867058355
# Final simulation: 2
# Time taken: 0.5875804424285889
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.030677677526142897
# Best robustness -0.0018997314868801352
# Final distance 0.0014961828372586931
# Final simulation: 10
# Time taken: 5.349155902862549
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12951011866598555
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.09666384020035276
# Final simulation: 2
# Time taken: 0.5417497158050537
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06034846338201499
# Best robustness -0.0007129625561632519
# Final distance 0.0029510905335058094
# Final simulation: 51
# Time taken: 26.771063804626465
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05631017545196469
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01680730696413435
# Final distance 0.044938099554635444
# Final simulation: 2
# Time taken: 0.5938897132873535
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12644553013007048
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.007306667458239827
# Final distance 0.07341312609196955
# Final simulation: 2
# Time taken: 0.545074462890625
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08828699527301784
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004342848347679564
# Final distance 0.012114228726968594
# Final simulation: 6
# Time taken: 2.935783624649048
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04391474955909967
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.04391474955909967
# Final simulation: 2
# Time taken: 0.5622012615203857
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 100
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05542700529009865
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.020980486374783752
# Final distance 0.05542700529009865
# Final simulation: 2
# Time taken: 0.5833878517150879
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1163293099277293
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.0836084958728079
# Final simulation: 2
# Time taken: 0.555262565612793
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11064715516550598
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07244574242233263
# Final simulation: 2
# Time taken: 0.5562396049499512
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06120562450683171
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05574771831802268
# Final simulation: 4
# Time taken: 1.683035135269165
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07744004871283881
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004882387559773171
# Final distance 0.03064121646436356
# Final simulation: 3
# Time taken: 1.1232976913452148
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10417149754513633
# Best robustness 0.0012295701938301873
# Final distance 0.001629932683719012
# Final simulation: 13
# Time taken: 7.109863042831421
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1192340778712297
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.0891544102463242
# Final simulation: 2
# Time taken: 0.5603525638580322
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 100
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04993810802293387
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0011638490475312001
# Final distance 0.024238964221428537
# Final simulation: 3
# Time taken: 1.0302062034606934
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08463608116040702
# Best robustness -0.0011676049792024995
# Final distance 0.0019517676126305239
# Final simulation: 9
# Time taken: 4.387108564376831
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04888570980038793
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.002915354891366512
# Final distance 0.04888570980038793
# Final simulation: 1
# Time taken: 0.0001933574676513672
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11788688606135056
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07804962568445387
# Final simulation: 2
# Time taken: 0.5341377258300781
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0998801521183444
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08232111901571329
# Final simulation: 2
# Time taken: 0.5307378768920898
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09472099447328759
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08612520787623099
# Final simulation: 2
# Time taken: 0.529609203338623
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13081204026862928
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07021365955492229
# Final simulation: 2
# Time taken: 0.5210781097412109
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03543450565735615
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004771964599767184
# Final distance 0.03543450565735615
# Final simulation: 2
# Time taken: 0.6975572109222412
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1297677050448444
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.1017812468761936
# Final simulation: 2
# Time taken: 0.5302221775054932
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05964255209185356
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05964255209185356
# Final simulation: 2
# Time taken: 0.5527148246765137
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12358804631009707
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.09218893783507384
# Final simulation: 2
# Time taken: 0.5525827407836914
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10668466819589509
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0019610564607376807
# Final distance 0.05439483182538111
# Final simulation: 3
# Time taken: 1.072655200958252
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0733473103046532
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06332692777064178
# Final simulation: 2
# Time taken: 0.5360069274902344
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 100
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.054529591200521935
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0096963510029688
# Final distance 0.054529591200521935
# Final simulation: 1
# Time taken: 0.00019168853759765625
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07290019765953024
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06539117652176708
# Final simulation: 2
# Time taken: 0.5908710956573486
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11727704497050338
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.049416903685749185
# Final simulation: 2
# Time taken: 0.5796000957489014
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.044795933925970366
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.044795933925970366
# Final simulation: 2
# Time taken: 0.5200076103210449
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 102
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06560737001965501
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06560737001965501
# Final simulation: 2
# Time taken: 0.673182487487793
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06556386191424675
# Best robustness 0.00019814826141739683
# Final distance 0.0015996143007549076
# Final simulation: 11
# Time taken: 5.631944894790649
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07780792938992626
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07780792938992626
# Final simulation: 2
# Time taken: 0.5372705459594727
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07303574853240143
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.007260653706142119
# Final distance 0.038957679089668844
# Final simulation: 3
# Time taken: 1.1138036251068115
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.043685870840622275
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.004995616366567366
# Final distance 0.043685870840622275
# Final simulation: 1
# Time taken: 0.0007352828979492188
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04625268169099522
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.04625268169099522
# Final simulation: 2
# Time taken: 0.568803071975708
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07816366987999197
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06758150770690144
# Final simulation: 2
# Time taken: 0.5783071517944336
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 104
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08003531027684636
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0204575604170534
# Final distance 0.06415314298995368
# Final simulation: 2
# Time taken: 0.5696291923522949
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10413734512405991
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05312425356385496
# Final simulation: 2
# Time taken: 0.5677356719970703
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1160653555818238
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07812892884665484
# Final simulation: 3
# Time taken: 1.2890799045562744
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07915735086711898
# Best robustness 0.0006401306010856561
# Final distance 0.011853787601546584
# Final simulation: 51
# Time taken: 27.656949996948242
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13351766345583088
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0029608854859349636
# Final distance 0.026468510526842577
# Final simulation: 4
# Time taken: 1.5451056957244873
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06203853438422595
# Best robustness -0.00018283796484486192
# Final distance 0.014300758780206849
# Final simulation: 51
# Time taken: 24.04933738708496
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07195572393194578
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05649587859685819
# Final simulation: 2
# Time taken: 0.5013689994812012
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10259024687114364
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004729912086036486
# Final distance 0.018840976613283055
# Final simulation: 3
# Time taken: 1.0884242057800293
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1702617982684935
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08113611594832996
# Final simulation: 2
# Time taken: 0.5061383247375488
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09228911237957607
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06363785012375023
# Final simulation: 2
# Time taken: 0.4851222038269043
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10810007176891495
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08987626121554695
# Final simulation: 2
# Time taken: 0.5262484550476074
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0378380680609695
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0009176786089303869
# Final distance 0.0378380680609695
# Final simulation: 5
# Time taken: 1.9547052383422852
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 114
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0417865942492537
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022073089439612753
# Final distance 0.0417865942492537
# Final simulation: 2
# Time taken: 0.4751167297363281
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08768901941253318
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.04857506095411115
# Final simulation: 2
# Time taken: 0.4713747501373291
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04197407652060224
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0161554212460521
# Final distance 0.04197407652060224
# Final simulation: 3
# Time taken: 0.9618604183197021
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05453992268668358
# Best robustness -0.00080954779165128
# Final distance 0.0015450590422255526
# Final simulation: 9
# Time taken: 3.7659120559692383
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.011237547158792213
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001304131075355236
# Final distance 0.0085514282240011
# Final simulation: 2
# Time taken: 0.6009838581085205
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03063592768328993
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.017714948404133825
# Final simulation: 2
# Time taken: 0.496859073638916
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10618909412546737
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.09236797705242591
# Final simulation: 2
# Time taken: 0.5072464942932129
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13659150260567174
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.1123493011902993
# Final simulation: 2
# Time taken: 0.5186212062835693
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.012056892431777983
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0029406602592833148
# Final distance 0.006922293915953433
# Final simulation: 3
# Time taken: 0.9128360748291016
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12508991430988933
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006494748927476418
# Final distance 0.07870836201165943
# Final simulation: 3
# Time taken: 0.9811041355133057
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 110
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07114862767442479
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0026778209358890998
# Final distance 0.049296965861574144
# Final simulation: 2
# Time taken: 0.5459210872650146
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03859612736480997
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0055458936047429325
# Final distance 0.03859612736480997
# Final simulation: 1
# Time taken: 0.00021696090698242188
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0976303219097005
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07211741488458608
# Final simulation: 4
# Time taken: 1.409543514251709
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 117
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06792159097605087
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06792159097605087
# Final simulation: 2
# Time taken: 0.4694364070892334
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14240087765950915
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05189051062728312
# Final simulation: 2
# Time taken: 0.46935462951660156
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.015365634841520644
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0012828549156636282
# Final distance 0.015365634841520644
# Final simulation: 2
# Time taken: 0.4736819267272949
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06581985320119385
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0059329229195454886
# Final distance 0.04693293072906123
# Final simulation: 2
# Time taken: 0.6477015018463135
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 115
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0901796676046593
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.008144030707850955
# Final distance 0.0901796676046593
# Final simulation: 1
# Time taken: 0.0003032684326171875
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09810411415335317
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07924604239015166
# Final simulation: 2
# Time taken: 0.5169453620910645
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13361134966527827
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.08755575620300765
# Final simulation: 2
# Time taken: 0.4725971221923828
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07514505054262588
# Best robustness 0.0005238858932350237
# Final distance 0.0016819935164215966
# Final simulation: 9
# Time taken: 3.77793025970459
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 111
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05365912898195161
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009399407575706134
# Final distance 0.03595386112772825
# Final simulation: 6
# Time taken: 2.380654811859131
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 106
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07598952592438835
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.012275842603658133
# Final distance 0.07598952592438835
# Final simulation: 1
# Time taken: 0.00032591819763183594
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08224976319602026
# Best robustness 0.0007268785847859838
# Final distance 0.04858935538354149
# Final simulation: 51
# Time taken: 25.775532722473145
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 100
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06645944677421704
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0018576118152796653
# Final distance 0.061550969905173676
# Final simulation: 2
# Time taken: 0.6551423072814941
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10566973929235163
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07599066935676156
# Final simulation: 3
# Time taken: 1.046877384185791
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07201846492995502
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07201846492995502
# Final simulation: 2
# Time taken: 0.5277626514434814
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11209485012750785
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06036797299187984
# Final simulation: 2
# Time taken: 0.5495767593383789
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11478524573991424
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.02473413255733513
# Final simulation: 3
# Time taken: 1.073108196258545
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07319599130712585
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0030400450009297085
# Final distance 0.06026243829304034
# Final simulation: 2
# Time taken: 0.6150593757629395
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10965160749528206
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009926994864762687
# Final distance 0.04912640137928027
# Final simulation: 2
# Time taken: 0.5112245082855225
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0887630743392547
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.05085616221910697
# Final simulation: 2
# Time taken: 0.5139570236206055
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03247710262126429
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0039005880433544277
# Final distance 0.03247710262126429
# Final simulation: 2
# Time taken: 0.4801769256591797
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10248295640691595
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.06682009539844848
# Final simulation: 2
# Time taken: 0.4709789752960205
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09632652900758645
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0029474135328840076
# Final distance 0.057825676463224424
# Final simulation: 2
# Time taken: 0.4711785316467285
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 102
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07037804924604184
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.07037804924604184
# Final simulation: 2
# Time taken: 0.5471718311309814
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07671016066679269
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.050151458086236306
# Final simulation: 2
# Time taken: 0.5453581809997559
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.018783893502035534
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.016238746352418024
# Final distance 0.018783893502035534
# Final simulation: 1
# Time taken: 0.00019931793212890625
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10260569246620546
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.10094663499970949
# Final simulation: 2
# Time taken: 0.4982271194458008
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.060855743416687036
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005777379556325665
# Final distance 0.020837832685819707
# Final simulation: 6
# Time taken: 2.628366708755493
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0227953665624413
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0018026961533515766
# Final distance 0.015777641284003063
# Final simulation: 2
# Time taken: 0.5078482627868652
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09957336734233796
# Best robustness 0.0005768708956777725
# Final distance 0.01929036844409638
# Final simulation: 51
# Time taken: 24.772884845733643
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 107
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04771545336140016
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.013280772878768526
# Final distance 0.02977095640449526
# Final simulation: 3
# Time taken: 1.1064691543579102
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07147341125074556
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004365633503205534
# Final distance 0.07147341125074556
# Final simulation: 3
# Time taken: 1.0097315311431885
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06063597612788828
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009401636406328906
# Final distance 0.03822057463429378
# Final simulation: 2
# Time taken: 0.5449848175048828
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1293701428297721
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.013501229793110447
# Final distance 0.07563962163255582
# Final simulation: 2
# Time taken: 0.5011904239654541
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 105
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.028804762776918586
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.011930926352969324
# Final distance 0.028804762776918586
# Final simulation: 1
# Time taken: 0.0001823902130126953
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11795217065903334
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.001333873231183627
# Final distance 0.09933510945106755
# Final simulation: 2
# Time taken: 0.5030624866485596
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC5_RBF_1_512_ReLU.h5
# 118
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12466284023308273
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003033398937088668
# Final distance 0.056583660212628395
# Final simulation: 2
# Time taken: 0.5062110424041748
# idx **** 100
# 5.35
# -0.0031441122351847555
# 51
# 113.92749999999998
