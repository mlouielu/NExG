# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from set_coverage import CoverageInvSen

coverageObject = CoverageInvSen(dynamics='OtherBenchC1')

coverageObject.setSimsBound(40)
coverageObject.setDataObject()

# d_time_steps=[37, 53, 71, 95]
coverageObject.coverage_init_set(d_time_steps=[53], partitions=7)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# 148
#  **** idx **** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 53
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 0.01181023907727231
# Starting distance is very less
# Final distance 0.01181023907727231
# Final relative distance 1.0
# Min relative distance: 1.0
# Min simulation: 1
# Final simulation: 1
# Time taken: 0.00024127960205078125
#  **** idx **** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 53
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 0.023684069721132527
# Final distance 0.0022254886180415063
# Final relative distance 0.09396563361979023
# Min relative distance: 0.09396563361979023
# Min simulation: 4
# Final simulation: 4
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from set_coverage import CoverageInvSen

coverageObject = CoverageInvSen(dynamics='OtherBenchC1')

coverageObject.setSimsBound(40)
coverageObject.setDataObject()

coverageObject.coverage_reach_set(d_time_steps=[53], threshold=0.004, samples=200, rect=False)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [ 0.49430016 -1.17238854]
# [ 0.4561444  -1.11467842]
# [ 0.34414488 -0.80067785]
# [ 0.5941287  -0.61425828]
# [ 0.80877055 -0.79571773]
# [ 0.74229523 -1.01572237]
# [ 0.71399722 -1.0896372 ]
# [ 0.62516771 -1.25184643]
# [3 2 1 0 7 6 5 4]
#  ******* idx ******* 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 53
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 0.2518683964796005
# Final distance 0.0033548401373719857
# Final relative distance 0.013319813776809838
# Min relative distance: 0.013319813776809838
# Min simulation: 9
# Final simulation: 9
# Time taken: 2.348459243774414
#  ******* idx ******* 1
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from set_coverage import CoverageInvSen

coverageObject = CoverageInvSen(dynamics='OtherBenchC1')
    
coverageObject.setSimsBound(40)
coverageObject.setDataObject()

coverageObject.coverage_reach_set(d_time_steps=[53], threshold=0.004, samples=200, rect=True)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# [ 0.49430016 -1.17238854]
# [ 0.4561444  -1.11467842]
# [ 0.34414488 -0.80067785]
# [ 0.5941287  -0.61425828]
# [ 0.80877055 -0.79571773]
# [ 0.74229523 -1.01572237]
# [ 0.71399722 -1.0896372 ]
# [ 0.62516771 -1.25184643]
#  ******* idx ******* 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 53
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 0.35385831884671504
# Final distance 0.0037020214467187937
# Final relative distance 0.010461874850884718
# Min relative distance: 0.010461874850884718
# Min simulation: 9
# Final simulation: 9
# Time taken: 2.3179187774658203
#  ******* idx ******* 1
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from set_coverage import CoverageInvSen

coverageObject = CoverageInvSen(dynamics='OtherBenchC2')

coverageObject.setSimsBound(40)
coverageObject.setDataObject()

coverageObject.coverage_reach_set(d_time_steps=[130], threshold=0.004, samples=200, rect=False)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# [ 1.34118621 -0.54348539]
# [ 0.81591649 -0.3421186 ]
# [ 1.02294636 -0.10112954]
# [ 1.13985735 -0.16726828]
# [ 1.33094091 -0.27878553]
# [ 1.69464524 -0.3616647 ]
# [ 1.65767739 -0.46166836]
# [ 1.65022044 -0.46506357]
# [2 1 0 7 6 5]
#  ******* idx ******* 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 130
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 0.6472537106759688
# Final distance 0.0033388067849389963
# Final relative distance 0.005158420461509699
# Min relative distance: 0.005158420461509699
# Min simulation: 8
# Final simulation: 8
# Time taken: 4.538637638092041
#  ******* idx ******* 1
# ...

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from set_coverage import CoverageInvSen

coverageObject = CoverageInvSen(dynamics='OtherBenchC2')

coverageObject.setSimsBound(40)
coverageObject.setDataObject()

coverageObject.coverage_reach_set(d_time_steps=[140], threshold=0.004, samples=200, rect=True)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# [ 1.4073414  -0.56207502]
# [ 0.79455012 -0.42869178]
# [ 0.98799    -0.19836093]
# [ 1.06773241 -0.22513765]
# [ 1.2577651  -0.35633314]
# [ 1.51285416 -0.44846099]
# [ 1.53775765 -0.54736861]
# [ 1.6392873  -0.52594049]
#  ******* idx ******* 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 140
# Norm status: True
# True inv sen: None
# ***** path idx 0 s_factor 0.05 correction steps 10
# Starting distance: 0.22073085052134855
# Final distance 0.003084698091668894
# Final relative distance 0.013974929577732722
# Min relative distance: 0.013974929577732722
# Min simulation: 10
# Final simulation: 10
# Time taken: 5.461929082870483
#  ******* idx ******* 1
# ...
