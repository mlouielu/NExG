# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC1')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
# dataObject.setStepSize(0.02)
lowerBound = [0.2, -1.0]
upperBound = [0.4, -0.8]
evalObject.setUnsafeSet(lowerBound, upperBound)
stl_time_interval = [0.7, 0.9]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16774472558870468
# /home/manishg/Research/NExG/core/evaluation_isen.py:541: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Best robustness -0.04709556620205135
# Final distance 0.0007255977969211622
# Final simulation: 8
# Time taken: 2.503622055053711
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18142696759716023
# Best robustness -0.001239355688496091
# Final distance 0.0007677596263504398
# Final simulation: 19
# Time taken: 5.791244268417358
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.005442556262139787
# Best robustness -0.017260708371341082
# Final distance 0.00044432162346400565
# Final simulation: 6
# Time taken: 1.6763734817504883
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1933864935956099
# Best robustness -0.005612597591809154
# Final distance 0.0009425254212324224
# Final simulation: 22
# Time taken: 7.121562957763672
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2726236536920338
# Best robustness -0.0018638564290819337
# Final distance 0.0008048803820142602
# Final simulation: 17
# Time taken: 5.60892915725708
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0947159288548011
# Best robustness -0.009822968485478367
# Final distance 0.003082036975818117
# Final simulation: 51
# Time taken: 19.2279212474823
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17969062433321
# Best robustness 0.005676126724109998
# Final distance 0.0006965567594932822
# Final simulation: 7
# Time taken: 2.947484254837036
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 82
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06271698302469712
# Best robustness -0.00015691636770603923
# Final distance 0.0007461456374853521
# Final simulation: 15
# Time taken: 6.791506290435791
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1337247182456681
# Best robustness 0.0027641022629502077
# Final distance 0.0005575914463044179
# Final simulation: 8
# Time taken: 2.816758871078491
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09529232085753735
# Best robustness -0.02047174023227416
# Final distance 0.0006381233600056932
# Final simulation: 13
# Time taken: 5.8732123374938965
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 86
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.020376446525663918
# Best robustness 0.009530377764895182
# Final distance 0.002454456043565247
# Final simulation: 51
# Time taken: 24.2326238155365
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 82
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.008120940087814313
# Best robustness -0.03332349960023373
# Final distance 0.0008064162929063722
# Final simulation: 9
# Time taken: 3.554588794708252
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025606904349764245
# Best robustness 0.010772656210451315
# Final distance 0.0006675856888628328
# Final simulation: 8
# Time taken: 3.5752084255218506
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06211587482706782
# Best robustness -0.0011243847916088123
# Final distance 0.0008107038247584649
# Final simulation: 26
# Time taken: 11.97262716293335
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05087058488960631
# Best robustness -0.014305039567822697
# Final distance 0.0006007526682130118
# Final simulation: 11
# Time taken: 4.688082456588745
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13184843177389519
# Best robustness -0.010572370020628163
# Final distance 0.009012692563362226
# Final simulation: 51
# Time taken: 20.34287738800049
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2504956555831184
# Best robustness -0.04739596157585724
# Final distance 0.0009880570144232877
# Final simulation: 8
# Time taken: 2.919647216796875
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22861006722905775
# Best robustness -0.01779112290733942
# Final distance 0.0007040677861283905
# Final simulation: 14
# Time taken: 5.322181463241577
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12333745430931728
# Best robustness -0.006928131940900861
# Final distance 0.000914848334049861
# Final simulation: 11
# Time taken: 4.20319128036499
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15121002440725997
# Best robustness 0.004065111993308612
# Final distance 0.0006403127247327873
# Final simulation: 4
# Time taken: 1.284364938735962
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.24850494718429006
# Best robustness -0.026628172323539756
# Final distance 0.0006769778016111182
# Final simulation: 8
# Time taken: 3.220918655395508
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 86
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07689136327736013
# Best robustness -0.006016757562954389
# Final distance 0.0007690229738317077
# Final simulation: 14
# Time taken: 5.610330104827881
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13444434570328662
# Best robustness 0.004421348800254632
# Final distance 0.0006190441327926264
# Final simulation: 10
# Time taken: 3.6771225929260254
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.014645941201609329
# Best robustness -0.012518888932635419
# Final distance 0.0009907191104285011
# Final simulation: 7
# Time taken: 2.5556893348693848
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19381629850237697
# Best robustness -0.0023556806939638575
# Final distance 0.0006143748826916667
# Final simulation: 10
# Time taken: 4.234385967254639
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 76
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.030276301352593397
# Best robustness 0.00014467340683288477
# Final distance 0.0009048018425971733
# Final simulation: 11
# Time taken: 4.748461484909058
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06275830628193284
# Best robustness -0.013295344288686728
# Final distance 0.0007781032525936237
# Final simulation: 8
# Time taken: 3.138617753982544
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.00863572465180538
# Best robustness -0.004416384688729513
# Final distance 0.0008177459684035854
# Final simulation: 6
# Time taken: 2.1440467834472656
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.021338222354008823
# Best robustness 0.0018518111155464423
# Final distance 0.00076419017031985
# Final simulation: 5
# Time taken: 1.7967956066131592
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 86
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025573496087290044
# Best robustness -0.03708605535155407
# Final distance 0.0007677986630021117
# Final simulation: 17
# Time taken: 7.767566204071045
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06293094449782649
# Best robustness 0.00437390103233587
# Final distance 0.0007818659324702096
# Final simulation: 9
# Time taken: 3.602842330932617
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12837481016803923
# Best robustness 0.002705011116201639
# Final distance 0.0009862258000133998
# Final simulation: 11
# Time taken: 4.646909475326538
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14848327425524271
# Best robustness -0.003927486439299521
# Final distance 0.0005373352111843297
# Final simulation: 13
# Time taken: 6.1261889934539795
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.032247753661689034
# Best robustness -0.03128002098685245
# Final distance 0.0005551425606905014
# Final simulation: 10
# Time taken: 4.050132513046265
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11572109585331258
# Best robustness -0.007308527959894229
# Final distance 0.0004635686851747475
# Final simulation: 7
# Time taken: 2.6785688400268555
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.030750179678692504
# Best robustness -0.001416876308419912
# Final distance 0.00043752807741196417
# Final simulation: 9
# Time taken: 3.4668490886688232
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09337842214879286
# Best robustness -0.010299809960309658
# Final distance 0.0008106466923422579
# Final simulation: 15
# Time taken: 6.093563079833984
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.008674076454442731
# Best robustness 0.007318256472405915
# Final distance 0.00044430852142822756
# Final simulation: 7
# Time taken: 2.433795213699341
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07247747949630474
# Best robustness 0.009854138747165675
# Final distance 0.0006559513703559799
# Final simulation: 10
# Time taken: 4.13046932220459
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15922868737897447
# Best robustness -0.009721032837726018
# Final distance 0.0012607514126435698
# Final simulation: 51
# Time taken: 20.818598985671997
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 87
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.051376054912891565
# Best robustness 0.005700250587712008
# Final distance 0.0005292518576483213
# Final simulation: 10
# Time taken: 4.101752996444702
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13872945044604296
# Best robustness -0.016369473884275565
# Final distance 0.0006610377292024704
# Final simulation: 11
# Time taken: 4.525828838348389
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.041176990926035224
# Best robustness 0.009530377764895182
# Final distance 0.002966124925607238
# Final simulation: 51
# Time taken: 22.70779061317444
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10316259950275034
# Best robustness 0.0017355808365832615
# Final distance 0.0008139069754947492
# Final simulation: 7
# Time taken: 2.7924461364746094
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1350964856966448
# Best robustness -0.009730492062482943
# Final distance 0.0007897304097283545
# Final simulation: 20
# Time taken: 8.000341653823853
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2479171515259474
# Best robustness -0.06458971155744109
# Final distance 0.0005455965943467542
# Final simulation: 11
# Time taken: 4.574244260787964
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09936501418004542
# Best robustness -0.008054009652556704
# Final distance 0.0008842768339432666
# Final simulation: 43
# Time taken: 18.86385202407837
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.21535282314619408
# Best robustness 0.008018263642775803
# Final distance 0.0004890299279176076
# Final simulation: 14
# Time taken: 6.974270820617676
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07140680439286598
# Best robustness -0.0008072067646892056
# Final distance 0.0009537550796342994
# Final simulation: 18
# Time taken: 8.55444598197937
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2393637405371889
# Best robustness -0.008121969548909314
# Final distance 0.0006510113301348656
# Final simulation: 14
# Time taken: 5.784836769104004
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.037182318301887674
# Best robustness 0.0015357438973037651
# Final distance 0.005595791434962174
# Final simulation: 51
# Time taken: 24.713815450668335
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2878052157925644
# Best robustness -0.004956922609114789
# Final distance 0.00518365888756379
# Final simulation: 51
# Time taken: 20.051045179367065
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 82
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02106876507797016
# Best robustness -0.012789074330718075
# Final distance 0.0008212474367604635
# Final simulation: 4
# Time taken: 1.3906431198120117
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.01503320550831528
# Best robustness -0.013453267595419538
# Final distance 0.0007802797225727709
# Final simulation: 8
# Time taken: 3.0256309509277344
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 82
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.01512666501977899
# Best robustness -0.0007373859696702123
# Final distance 0.0007617002301356654
# Final simulation: 9
# Time taken: 3.397991418838501
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 82
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025548181283927097
# Best robustness -0.003137095536610013
# Final distance 0.0003805560697112959
# Final simulation: 9
# Time taken: 3.3539175987243652
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16427437055132108
# Best robustness -0.007165705900689989
# Final distance 0.0008722943449008902
# Final simulation: 9
# Time taken: 3.1364896297454834
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11519496380856045
# Best robustness 0.00153187726946713
# Final distance 0.0008517315065450845
# Final simulation: 7
# Time taken: 2.534372568130493
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23309408348986238
# Best robustness -0.01452799194527099
# Final distance 0.0005688206323642708
# Final simulation: 10
# Time taken: 3.6807971000671387
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0928759771044129
# Best robustness -0.0003797904215511738
# Final distance 0.0008657450443008713
# Final simulation: 37
# Time taken: 14.179579019546509
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08535705744801789
# Best robustness -0.008887581461039684
# Final distance 0.0005866431381524941
# Final simulation: 10
# Time taken: 3.6910014152526855
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1686993206140001
# Best robustness -0.0023491465939753375
# Final distance 0.0007167827781242888
# Final simulation: 11
# Time taken: 4.2552783489227295
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0702533565478962
# Best robustness -0.0054705021815698585
# Final distance 0.0004155088294777018
# Final simulation: 9
# Time taken: 3.2762115001678467
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14041083936495719
# Best robustness -0.008587672628442178
# Final distance 0.0005849657922717531
# Final simulation: 13
# Time taken: 5.0678839683532715
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2824834247966438
# Best robustness -0.005344760858644548
# Final distance 0.0006767999735340789
# Final simulation: 12
# Time taken: 4.819371700286865
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 87
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03611508102887386
# Best robustness 0.006116589524468641
# Final distance 0.011019022102579892
# Final simulation: 51
# Time taken: 22.576524019241333
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.055002192635348855
# Best robustness -0.002956009260887127
# Final distance 0.003990733414368557
# Final simulation: 51
# Time taken: 21.803603649139404
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1089906946109098
# Best robustness -0.011873865666196415
# Final distance 0.0004711781199910092
# Final simulation: 8
# Time taken: 3.1596405506134033
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 85
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04753372726861496
# Best robustness 0.00950904435709321
# Final distance 0.0006684749969312295
# Final simulation: 14
# Time taken: 5.827301502227783
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.035207145830698186
# Best robustness 0.007862221521454216
# Final distance 0.0004930975710206837
# Final simulation: 13
# Time taken: 5.424077033996582
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 86
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09318898535103165
# Best robustness 0.012506640541031566
# Final distance 0.0006611993160032388
# Final simulation: 17
# Time taken: 6.832148551940918
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04323240202949047
# Best robustness 0.009530377764895182
# Final distance 0.005158456361602829
# Final simulation: 51
# Time taken: 24.102984189987183
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09174740898441672
# Best robustness -0.00801973835676012
# Final distance 0.000746672993328256
# Final simulation: 12
# Time taken: 4.892124652862549
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3154267725665728
# Best robustness -0.016337634537726964
# Final distance 0.00023775388062649281
# Final simulation: 8
# Time taken: 3.2974350452423096
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 82
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08627395914830334
# Best robustness 0.009530377764895182
# Final distance 0.0047284848938209875
# Final simulation: 51
# Time taken: 23.700587511062622
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23253919595005507
# Best robustness 0.0001669937040030267
# Final distance 0.021105419784484845
# Final simulation: 51
# Time taken: 23.576837301254272
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07352841121925224
# Best robustness -0.020440674235638
# Final distance 0.0005365295920775903
# Final simulation: 12
# Time taken: 5.270705223083496
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03134379743552633
# Best robustness -0.0009383968290853084
# Final distance 0.00046475979322889655
# Final simulation: 9
# Time taken: 3.4576985836029053
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 86
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.007449742332050631
# Best robustness -0.007740995347792323
# Final distance 0.0005652004831379383
# Final simulation: 7
# Time taken: 2.5390493869781494
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10304953289482792
# Best robustness -0.03865307611650093
# Final distance 0.0005132238885914494
# Final simulation: 14
# Time taken: 5.710629463195801
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08373241737224107
# Best robustness -0.008657379917918928
# Final distance 0.0005572106899811259
# Final simulation: 7
# Time taken: 2.70517897605896
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11403288873119778
# Best robustness 0.0035642496720244
# Final distance 0.0007945234945394189
# Final simulation: 10
# Time taken: 4.270403146743774
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12289900932808025
# Best robustness -0.005727546578622178
# Final distance 0.0008143538734332412
# Final simulation: 8
# Time taken: 3.0690789222717285
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02331411841092065
# Best robustness -0.03809740792832317
# Final distance 0.0008466430047724178
# Final simulation: 9
# Time taken: 3.6902685165405273
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10885374481306577
# Best robustness -0.007453577926842869
# Final distance 0.0006770987444385441
# Final simulation: 3
# Time taken: 0.9203989505767822
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05587954007593204
# Best robustness -0.005931882297397273
# Final distance 0.0008974447972641149
# Final simulation: 9
# Time taken: 4.369847536087036
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11860354761168673
# Best robustness -0.02051759325150071
# Final distance 0.0006421439393185349
# Final simulation: 11
# Time taken: 4.878181457519531
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.016471832391350572
# Best robustness 0.0011172001345525762
# Final distance 0.0007311488332481231
# Final simulation: 7
# Time taken: 2.8130712509155273
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 85
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05015119786294638
# Best robustness 0.00514444996628044
# Final distance 0.01084908842641258
# Final simulation: 51
# Time taken: 23.076661586761475
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.042274012582095975
# Best robustness -0.013655234823248819
# Final distance 0.0006457511746914856
# Final simulation: 10
# Time taken: 4.819680690765381
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.052189037434182906
# Best robustness -0.013085006607541527
# Final distance 0.0008180181776298797
# Final simulation: 9
# Time taken: 3.6760096549987793
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 86
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05554981113699149
# Best robustness -0.034336975880374876
# Final distance 0.0005365481924011688
# Final simulation: 8
# Time taken: 3.013105869293213
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 87
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.027077317042653405
# Best robustness 0.0007475610353361861
# Final distance 0.0009589447073253643
# Final simulation: 9
# Time taken: 3.3629038333892822
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 79
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11401153587964073
# Best robustness -0.01616128651228832
# Final distance 0.0007897809931280272
# Final simulation: 8
# Time taken: 2.998547077178955
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14775804154528274
# Best robustness -0.06596217130164139
# Final distance 0.000890098516842218
# Final simulation: 8
# Time taken: 2.947657585144043
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15936648768263412
# Best robustness -0.01669148260638864
# Final distance 0.0007438198704705663
# Final simulation: 9
# Time taken: 3.1333179473876953
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12510746146057025
# Best robustness -0.008249151750607475
# Final distance 0.0009796558581315464
# Final simulation: 10
# Time taken: 3.3194265365600586
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.20177498628680715
# Best robustness -0.0053878605441828875
# Final distance 0.0008802011248186022
# Final simulation: 30
# Time taken: 10.619498252868652
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07066185892227483
# Best robustness -0.00317289377220098
# Final distance 0.003113900636312834
# Final simulation: 51
# Time taken: 17.483312606811523
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# 88
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.241165718071578
# Best robustness 0.0033518296659876823
# Final distance 0.0008250670362031816
# Final simulation: 9
# Time taken: 3.2046315670013428
# idx **** 100
# 16.91
# -0.008060657163627152
# 51
# 222.96190000000007

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC2')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(100)
# dataObject.setLowerBound([0.8, 0.9])
# dataObject.setUpperBound([1.2, 1.2])
# dataObject.setStepSize(0.02)
lowerBound = [1.5, 0.4]
upperBound = [1.7, 0.6]
evalObject.setUnsafeSet(lowerBound, upperBound)
stl_time_interval = [0.6, 0.8]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
#     print(ref_traj[60], ref_traj[70])
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22461033459634455
# Best robustness 0.09472815316679095
# Final distance 0.0007247869318031567
# Final simulation: 4
# Time taken: 2.2929329872131348
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.43220844431681454
# Best robustness -0.003696119890719274
# Final distance 0.0004188998774643634
# Final simulation: 7
# Time taken: 4.783484697341919
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.647820775819485
# Best robustness 0.0534733054637897
# Final distance 0.0008215982247817478
# Final simulation: 13
# Time taken: 9.24162483215332
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6958089654948395
# Best robustness -0.024946530612852236
# Final distance 0.0009699891580805005
# Final simulation: 13
# Time taken: 10.306266784667969
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5439533568308006
# Best robustness 0.07590861666203841
# Final distance 0.0004529802941922291
# Final simulation: 6
# Time taken: 3.947591781616211
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.34999540718904326
# Best robustness -0.044477447585783314
# Final distance 0.0005041205030860551
# Final simulation: 7
# Time taken: 4.679936170578003
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0864460598783086
# Best robustness -0.08259092193208828
# Final distance 0.0005108897080274132
# Final simulation: 6
# Time taken: 3.8529341220855713
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6347483150453674
# Best robustness -0.054615965478908124
# Final distance 0.0005840356565272053
# Final simulation: 8
# Time taken: 5.344974517822266
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7319750006877218
# Best robustness -0.10850671899866016
# Final distance 0.005388146554779827
# Final simulation: 51
# Time taken: 40.22212862968445
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5814451833847992
# Best robustness 0.03903629489366278
# Final distance 0.0033459598099507435
# Final simulation: 51
# Time taken: 37.12480401992798
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18451842070927826
# Best robustness -0.01087305909472791
# Final distance 0.0006237808572993955
# Final simulation: 2
# Time taken: 0.7101399898529053
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 68
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05558876810673369
# Best robustness -0.09731603620771834
# Final distance 0.0006823347992754306
# Final simulation: 5
# Time taken: 2.796116828918457
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.47976807414963163
# Best robustness -0.11970221489960853
# Final distance 0.0004643263538866983
# Final simulation: 16
# Time taken: 11.021673679351807
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.044151318625619676
# Best robustness -0.0016692031809055763
# Final distance 0.0009021850312898481
# Final simulation: 8
# Time taken: 5.039637327194214
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6610754264994875
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.022845417671157997
# Final distance 0.009897197551456386
# Final simulation: 6
# Time taken: 3.581174612045288
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6207178714102656
# Best robustness -0.08663157459921111
# Final distance 0.0005776080767145703
# Final simulation: 8
# Time taken: 4.883925437927246
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4792911099642631
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02156961100244259
# Final distance 0.003210834268414564
# Final simulation: 8
# Time taken: 5.0990283489227295
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.8040621296746853
# Best robustness 0.03405095976360473
# Final distance 0.003248179618716018
# Final simulation: 51
# Time taken: 33.634586811065674
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12711689443147975
# Best robustness -0.11929790724704165
# Final distance 0.006482417403481803
# Final simulation: 51
# Time taken: 36.547306299209595
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5233192713799929
# Best robustness -0.049893881888005476
# Final distance 0.0005773235338172117
# Final simulation: 5
# Time taken: 2.7773566246032715
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49704278982206523
# Best robustness -0.13012640209907833
# Final distance 0.006390779561991053
# Final simulation: 51
# Time taken: 36.336668729782104
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3382656483385256
# Best robustness -0.13218437776507175
# Final distance 0.000887218335327862
# Final simulation: 5
# Time taken: 3.0548815727233887
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5824360093802179
# Best robustness -0.06687500958868697
# Final distance 0.000821233640893675
# Final simulation: 22
# Time taken: 15.531546831130981
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.693699367046185
# Best robustness -0.09409024960389312
# Final distance 0.0008740536130750695
# Final simulation: 8
# Time taken: 4.564332008361816
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 69
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2471441946879952
# Best robustness -0.08822234478430979
# Final distance 0.0009913957762537227
# Final simulation: 5
# Time taken: 2.8993582725524902
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5192357451335029
# Best robustness -0.13508865867123548
# Final distance 0.000848477851479428
# Final simulation: 28
# Time taken: 17.690562963485718
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6472049184372977
# Best robustness 0.03489967245861614
# Final distance 0.0037344632258074894
# Final simulation: 51
# Time taken: 30.539298057556152
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3928139019095667
# Best robustness 0.10983743773646082
# Final distance 0.0006139501163320802
# Final simulation: 6
# Time taken: 3.1094157695770264
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4954842001530387
# Best robustness -0.09747690527022967
# Final distance 0.0005462669856443706
# Final simulation: 8
# Time taken: 4.181648254394531
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05287862879887888
# Best robustness -0.0027627362327065086
# Final distance 0.0009258627735003445
# Final simulation: 8
# Time taken: 4.46254825592041
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6558059013508886
# Best robustness -0.03655068912647763
# Final distance 0.0028447141088236566
# Final simulation: 51
# Time taken: 32.70912837982178
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08411860876159497
# Best robustness -0.07197250805367505
# Final distance 0.00041314770929007686
# Final simulation: 6
# Time taken: 3.2364401817321777
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 62
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.706066684943531
# Best robustness -0.009974116957646828
# Final distance 0.0009582040449747308
# Final simulation: 8
# Time taken: 4.323352813720703
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0922020068082079
# Best robustness -0.04056427246072658
# Final distance 0.0006979169582224399
# Final simulation: 6
# Time taken: 3.251579999923706
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5269370907213295
# Best robustness -0.107800303465585
# Final distance 0.00046417348523178625
# Final simulation: 7
# Time taken: 3.673603057861328
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16728720427393803
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.013642970473311755
# Final distance 0.07826138163567194
# Final simulation: 2
# Time taken: 0.6954641342163086
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.265280341067706
# Best robustness -0.05791268038251096
# Final distance 0.0005995034829864584
# Final simulation: 6
# Time taken: 3.0959296226501465
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49600300288733573
# Best robustness -0.11915722409158808
# Final distance 0.0009579232700537563
# Final simulation: 47
# Time taken: 30.51996159553528
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.184185017446509
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02490548366750045
# Final distance 0.02025846089464317
# Final simulation: 4
# Time taken: 2.054861307144165
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6454715784909123
# Best robustness -0.003956879354963139
# Final distance 0.0044734676664474815
# Final simulation: 51
# Time taken: 30.622596979141235
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5677658955739849
# Best robustness -0.06447797212369544
# Final distance 0.0007262408729895613
# Final simulation: 12
# Time taken: 6.850387334823608
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18181547430922124
# Best robustness -0.021671801867408136
# Final distance 0.0009132390079808534
# Final simulation: 11
# Time taken: 6.699826717376709
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3842778051859846
# Best robustness 0.12325083370024581
# Final distance 0.0005436745091456491
# Final simulation: 7
# Time taken: 3.728896379470825
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3333699681913092
# Best robustness -0.021300325609208026
# Final distance 0.0006945122658457204
# Final simulation: 8
# Time taken: 4.509762525558472
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5923627871309131
# Best robustness -0.07579197502960466
# Final distance 0.005994977506723294
# Final simulation: 51
# Time taken: 32.89271688461304
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 64
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11546952187100032
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02335851783959142
# Final distance 0.019218943071792543
# Final simulation: 4
# Time taken: 1.8947811126708984
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33214188762296937
# Best robustness -0.11903449942938493
# Final distance 0.0038028262705659456
# Final simulation: 51
# Time taken: 32.43810749053955
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4368199536589475
# Best robustness -0.09896124382842941
# Final distance 0.0008899982001257262
# Final simulation: 16
# Time taken: 9.698956727981567
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12746856106211943
# Best robustness -0.04675855536591844
# Final distance 0.0004611664380223739
# Final simulation: 7
# Time taken: 4.061619997024536
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 66
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13641688358838502
# Best robustness -0.017721261073528227
# Final distance 0.0004544232866545118
# Final simulation: 7
# Time taken: 3.7128102779388428
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.229614399554775
# Best robustness -0.10008582757474466
# Final distance 0.0007104965137348482
# Final simulation: 8
# Time taken: 4.449572324752808
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5026857238401138
# Best robustness -0.044959305124249394
# Final distance 0.0024688696441036865
# Final simulation: 51
# Time taken: 32.60349225997925
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5620129050628859
# Best robustness -0.03564751170122926
# Final distance 0.0009776808929509758
# Final simulation: 9
# Time taken: 4.946789503097534
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.49619427205124533
# Best robustness -0.11904990711198432
# Final distance 0.009862317192097542
# Final simulation: 51
# Time taken: 32.68194270133972
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0899771856614716
# Best robustness -0.014124896815191024
# Final distance 0.0003455312680212333
# Final simulation: 6
# Time taken: 3.063939094543457
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5782630100246031
# Best robustness -0.07745846426997094
# Final distance 0.0009604154082144118
# Final simulation: 23
# Time taken: 14.066909790039062
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5625796779328084
# Best robustness 0.04371470177765058
# Final distance 0.0009973096860484954
# Final simulation: 18
# Time taken: 10.889032363891602
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.27805106112051275
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.015439712213430545
# Final distance 0.04576862746090644
# Final simulation: 3
# Time taken: 1.3443012237548828
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6616478287550431
# Best robustness 0.036765068895244446
# Final distance 0.0024348187958603
# Final simulation: 51
# Time taken: 35.66187119483948
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.40077470061537246
# Best robustness -0.048144996212233226
# Final distance 0.0007935693675667759
# Final simulation: 8
# Time taken: 5.8430681228637695
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19635558102443434
# Best robustness -0.025036709226801346
# Final distance 0.0006975213159968014
# Final simulation: 7
# Time taken: 4.792281866073608
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 68
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3550928596837683
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.022981800873663638
# Final distance 0.07801878691221809
# Final simulation: 3
# Time taken: 1.4931681156158447
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7353705874364287
# Best robustness -0.03226712291778344
# Final distance 0.0008366743325555625
# Final simulation: 17
# Time taken: 12.520212411880493
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 65
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18850203743679708
# Best robustness -0.13058848362704722
# Final distance 0.000633392410657332
# Final simulation: 7
# Time taken: 4.109492540359497
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 76
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2633860474071303
# Best robustness -0.039467253184522044
# Final distance 0.000960982915814459
# Final simulation: 7
# Time taken: 4.374598026275635
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6541994403854741
# Best robustness 0.0975323565709203
# Final distance 0.0005425918202839539
# Final simulation: 5
# Time taken: 2.813122272491455
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 65
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6702232227656733
# Best robustness 0.08155337487698877
# Final distance 0.0008104894135077437
# Final simulation: 5
# Time taken: 2.783621072769165
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 70
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03433673103423121
# Best robustness -0.09350728232242234
# Final distance 0.00043119791161526025
# Final simulation: 6
# Time taken: 3.6808652877807617
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0490829365848922
# Best robustness -0.06209416561255221
# Final distance 0.0009675366988480981
# Final simulation: 5
# Time taken: 2.759600877761841
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 63
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7525069319646036
# Best robustness -0.09312983220601723
# Final distance 0.0006281700165348138
# Final simulation: 8
# Time taken: 4.7293219566345215
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 74
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.33834531408255547
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.015825191926848392
# Final distance 0.04234491549809552
# Final simulation: 3
# Time taken: 1.472224473953247
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.3144430679999767
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012923580881931351
# Final distance 0.05168053984906436
# Final simulation: 3
# Time taken: 1.4940910339355469
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 71
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5018095612009391
# Best robustness -0.0968313422097451
# Final distance 0.0009691838726173845
# Final simulation: 13
# Time taken: 8.731405019760132
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 68
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0759778450257736
# Best robustness -0.07666527854604066
# Final distance 0.0006709000395203501
# Final simulation: 6
# Time taken: 3.510136842727661
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.141447709124226
# Best robustness 0.09542303556770726
# Final distance 0.00041270015841453534
# Final simulation: 7
# Time taken: 3.9106264114379883
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.39039664291511506
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02209452285836444
# Final distance 0.023319420465786056
# Final simulation: 4
# Time taken: 2.1324386596679688
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5576735584666683
# Best robustness -0.0193496217631276
# Final distance 0.0004575294733435078
# Final simulation: 9
# Time taken: 6.159406423568726
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 77
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.36405740386790447
# Best robustness -0.10831900201888339
# Final distance 0.0027708128333531826
# Final simulation: 51
# Time taken: 36.652971029281616
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5076246444570285
# Best robustness 0.03978144204987977
# Final distance 0.0009970636168735467
# Final simulation: 49
# Time taken: 34.63167119026184
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6333722685181356
# Best robustness -0.08890305980161184
# Final distance 0.0006858116311908591
# Final simulation: 8
# Time taken: 5.036271095275879
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6329772236669502
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02096950825674715
# Final distance 0.0076112533252882305
# Final simulation: 6
# Time taken: 3.4460744857788086
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7294982768398738
# Best robustness -0.013402502641657543
# Final distance 0.0006249753103571621
# Final simulation: 10
# Time taken: 6.41058611869812
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.28179941195616315
# Best robustness 0.038329388225834427
# Final distance 0.0009057170596830218
# Final simulation: 35
# Time taken: 24.702070236206055
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 69
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2550719542028251
# Best robustness -0.10272890499962861
# Final distance 0.000820775542446627
# Final simulation: 7
# Time taken: 4.145915269851685
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12824426172914147
# Best robustness -0.04009420997809199
# Final distance 0.0006703465468082877
# Final simulation: 11
# Time taken: 6.5953850746154785
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5369175855308703
# Best robustness -0.12639082776155003
# Final distance 0.0005557835506738553
# Final simulation: 9
# Time taken: 5.432371139526367
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5668971240804722
# Best robustness -0.07693912678757098
# Final distance 0.0004883721827915317
# Final simulation: 18
# Time taken: 12.722583770751953
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6292218865467121
# Best robustness -0.0558279693902316
# Final distance 0.0015784880658275223
# Final simulation: 51
# Time taken: 36.113173484802246
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 72
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.38259581233822193
# Best robustness 0.039232081811941155
# Final distance 0.003381463867907533
# Final simulation: 51
# Time taken: 35.500675439834595
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 73
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5793516834901506
# Best robustness -0.056669102939236216
# Final distance 0.0006924081934645127
# Final simulation: 26
# Time taken: 17.78741192817688
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6139816937255321
# Best robustness -0.07605430841699001
# Final distance 0.0008090845310864801
# Final simulation: 14
# Time taken: 9.142950296401978
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.30247568427532906
# Best robustness 0.07682857042263747
# Final distance 0.0007181742387182871
# Final simulation: 6
# Time taken: 3.329213857650757
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.30636512181625164
# Best robustness -0.1122832461095773
# Final distance 0.0009038680421782246
# Final simulation: 7
# Time taken: 3.8021080493927
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5706366736781344
# Best robustness -0.0772720541832953
# Final distance 0.0008292533978955729
# Final simulation: 18
# Time taken: 11.51743745803833
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 67
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.35884452739675565
# Best robustness -0.09944547562784345
# Final distance 0.0009007772668137978
# Final simulation: 10
# Time taken: 6.178282737731934
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 75
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5471761147890665
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.010126211140791375
# Final distance 0.040035310055219646
# Final simulation: 4
# Time taken: 2.136366367340088
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.7191329564966347
# Best robustness -0.041994649541764795
# Final distance 0.0008749876989947805
# Final simulation: 15
# Time taken: 8.908132791519165
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4892777160724204
# Best robustness -0.04694147669688076
# Final distance 0.00046018838387496544
# Final simulation: 8
# Time taken: 4.284894943237305
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5778357913778117
# Best robustness -0.0964680723768373
# Final distance 0.0027756323551150126
# Final simulation: 51
# Time taken: 33.88246154785156
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.6569723702584678
# Best robustness 0.03972375903402248
# Final distance 0.0009294620851639497
# Final simulation: 10
# Time taken: 6.142517328262329
# idx **** 100
# 16.98
# -0.0386540603927685
# 51
# 295.3796

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='OtherBenchC3')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
# dataObject.setLowerBound([0.8, 0.9])
# dataObject.setUpperBound([1.2, 1.2])
# dataObject.setStepSize(0.02)
lowerBound = [0.4, -0.1]
upperBound = [0.5, 0.0]
evalObject.setUnsafeSet(lowerBound, upperBound)
stl_time_interval = [0.8, 1.0]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_OtherBenchC3.txt
# Run *** 0
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09456084099068186
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006984921867503574
# Final distance 0.0025399784854707366
# Final simulation: 45
# Time taken: 17.996691703796387
# idx **** 1
# Run *** 1
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06930325321994454
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01620435254747956
# Final distance 0.04400606614071274
# Final simulation: 2
# Time taken: 0.5005872249603271
# idx **** 2
# Run *** 2
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06052594803312805
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0077059182590241025
# Final distance 0.031276419814663274
# Final simulation: 2
# Time taken: 0.4966392517089844
# idx **** 3
# Run *** 3
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16954342616603968
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0024370890508520733
# Final distance 0.025688163122562287
# Final simulation: 4
# Time taken: 1.278397560119629
# idx **** 4
# Run *** 4
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1814855954761662
# /home/manishg/Research/NExG/core/evaluation_isen.py:541: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Best robustness -0.0004546903331698218
# Final distance 0.001265768304545376
# Final simulation: 6
# Time taken: 2.2804512977600098
# idx **** 5
# Run *** 5
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 84
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09848950311898022
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008267260863451049
# Final distance 0.024910323436376933
# Final simulation: 3
# Time taken: 0.9630887508392334
# idx **** 6
# Run *** 6
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08895017655499832
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003348610323974587
# Final distance 0.052843199603369855
# Final simulation: 2
# Time taken: 0.5089569091796875
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 96
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02814774217951417
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.01576066971102258
# Final distance 0.02814774217951417
# Final simulation: 1
# Time taken: 0.0006532669067382812
# idx **** 7
# Run *** 7
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08489552422079459
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00901940833216471
# Final distance 0.016980821681802236
# Final simulation: 4
# Time taken: 1.4543938636779785
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.028519969039369694
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.014018690999413164
# Final distance 0.028519969039369694
# Final simulation: 1
# Time taken: 0.000431060791015625
# idx **** 8
# Run *** 8
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.22887222844433128
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008051165893844078
# Final distance 0.03256324638649448
# Final simulation: 4
# Time taken: 1.348879098892212
# idx **** 9
# Run *** 9
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10710694642505561
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006340277131102883
# Final distance 0.05474540100136303
# Final simulation: 2
# Time taken: 0.5046596527099609
# idx **** 10
# Run *** 10
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10409081523460675
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009627489203939611
# Final distance 0.001253839542002405
# Final simulation: 35
# Time taken: 14.32499098777771
# idx **** 11
# Run *** 11
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.016602098205822077
# Best robustness -0.00012342446244162364
# Final distance 0.0018372761595451042
# Final simulation: 6
# Time taken: 2.249478340148926
# idx **** 12
# Run *** 12
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08738915877531059
# Best robustness 0.00025264122478098816
# Final distance 0.009868062820499656
# Final simulation: 51
# Time taken: 22.928701162338257
# idx **** 13
# Run *** 13
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17192954538359695
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022295403464475416
# Final distance 0.028014679454543216
# Final simulation: 4
# Time taken: 1.74088454246521
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06560711303277376
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.00477156456565786
# Final distance 0.06560711303277376
# Final simulation: 1
# Time taken: 0.0005402565002441406
# idx **** 14
# Run *** 14
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07697020219353205
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.002145219834162382
# Final distance 0.005515998002441673
# Final simulation: 3
# Time taken: 1.188849687576294
# idx **** 15
# Run *** 15
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08010854647430822
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005594629618011266
# Final distance 0.008590276733739941
# Final simulation: 3
# Time taken: 1.060124158859253
# idx **** 16
# Run *** 16
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10358254577691652
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.032390947477842116
# Final distance 0.04981053949836975
# Final simulation: 2
# Time taken: 0.5648143291473389
# idx **** 17
# Run *** 17
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.20408883117401308
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02116612068931777
# Final distance 0.09890638275053124
# Final simulation: 2
# Time taken: 0.5506467819213867
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.018012461108924366
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.010959099724041152
# Final distance 0.018012461108924366
# Final simulation: 1
# Time taken: 0.00038743019104003906
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03401713623391208
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.008418897956424698
# Final distance 0.03401713623391208
# Final simulation: 1
# Time taken: 0.0004642009735107422
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 97
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04987311850163596
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.013136458057507239
# Final distance 0.04987311850163596
# Final simulation: 1
# Time taken: 0.0004942417144775391
# idx **** 18
# Run *** 18
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10169586608009198
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008949319626149532
# Final distance 0.024412106312764633
# Final simulation: 4
# Time taken: 1.5672194957733154
# idx **** 19
# Run *** 19
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09257617412890008
# Best robustness -0.00041723060942389307
# Final distance 0.0013843054530460418
# Final simulation: 7
# Time taken: 3.1356167793273926
# idx **** 20
# Run *** 20
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06566798331479587
# Best robustness -0.001613733222567137
# Final distance 0.0019897136863460847
# Final simulation: 12
# Time taken: 6.17474102973938
# idx **** 21
# Run *** 21
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2093227738972525
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0038624483270321376
# Final distance 0.0297136892537599
# Final simulation: 4
# Time taken: 1.5059807300567627
# idx **** 22
# Run *** 22
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 91
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07737382674118239
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01843351473454631
# Final distance 0.03968595509868462
# Final simulation: 2
# Time taken: 0.5760142803192139
# idx **** 23
# Run *** 23
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16668585299541933
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.029785712590143953
# Final distance 0.04046734558517513
# Final simulation: 3
# Time taken: 1.247863531112671
# idx **** 24
# Run *** 24
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17116981992691788
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004615213729420516
# Final distance 0.005263849699029132
# Final simulation: 7
# Time taken: 2.840481758117676
# idx **** 25
# Run *** 25
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18324510112507367
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0054870209660053265
# Final distance 0.0415735208631162
# Final simulation: 3
# Time taken: 1.0316531658172607
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.050469346762475054
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.023306235937455344
# Final distance 0.050469346762475054
# Final simulation: 1
# Time taken: 0.0003218650817871094
# idx **** 26
# Run *** 26
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05339319963830435
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.017890227186365612
# Final distance 0.04000450137923142
# Final simulation: 2
# Time taken: 0.5092048645019531
# idx **** 27
# Run *** 27
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07914546638899478
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02818240640628483
# Final distance 0.045717495546141095
# Final simulation: 2
# Time taken: 0.5086209774017334
# idx **** 28
# Run *** 28
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05198995263085619
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.016354056077946544
# Final distance 0.02894875263309997
# Final simulation: 2
# Time taken: 0.5969829559326172
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.02999358992777881
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.024059610334054016
# Final distance 0.02999358992777881
# Final simulation: 1
# Time taken: 0.0003616809844970703
# idx **** 29
# Run *** 29
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11050594874535521
# Best robustness -0.007558545178251908
# Final distance 0.0013091759465005872
# Final simulation: 7
# Time taken: 2.660322904586792
# idx **** 30
# Run *** 30
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1009123483428285
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0051887681482319864
# Final distance 0.011900191491462852
# Final simulation: 4
# Time taken: 1.3273415565490723
# idx **** 31
# Run *** 31
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18347369380953163
# Best robustness -0.0008716762574951294
# Final distance 0.14088075449168427
# Final simulation: 51
# Time taken: 22.13171648979187
# idx **** 32
# Run *** 32
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08176767028037987
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0019821570737813747
# Final distance 0.01475019958813588
# Final simulation: 4
# Time taken: 1.9517521858215332
# idx **** 33
# Run *** 33
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.19793175641366034
# Best robustness -0.0010363396665648422
# Final distance 0.0012412146942057474
# Final simulation: 4
# Time taken: 2.2405738830566406
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06950292298105348
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.010307201907854478
# Final distance 0.06950292298105348
# Final simulation: 1
# Time taken: 0.0005466938018798828
# idx **** 34
# Run *** 34
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07940586364743295
# Best robustness -0.00015126268705861756
# Final distance 0.001488194778668707
# Final simulation: 6
# Time taken: 3.0407984256744385
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.032676412836001575
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.027767381370624882
# Final distance 0.032676412836001575
# Final simulation: 1
# Time taken: 0.0004055500030517578
# idx **** 35
# Run *** 35
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08178065835442377
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005515439526413757
# Final distance 0.022083739988631345
# Final simulation: 3
# Time taken: 1.2295300960540771
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04712432860018518
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.02910183693407237
# Final distance 0.04712432860018518
# Final simulation: 1
# Time taken: 0.0017879009246826172
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07458129186716125
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0031068656215660602
# Final distance 0.07458129186716125
# Final simulation: 1
# Time taken: 0.0032172203063964844
# idx **** 36
# Run *** 36
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 97
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08473296360592773
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009061480402370621
# Final distance 0.030441640623941862
# Final simulation: 2
# Time taken: 0.78359055519104
# idx **** 37
# Run *** 37
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 97
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07068583073857475
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022197446873178876
# Final distance 0.025002468103849138
# Final simulation: 4
# Time taken: 1.798241376876831
# idx **** 38
# Run *** 38
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12312940111631118
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01319425601102845
# Final distance 0.05421269162654949
# Final simulation: 2
# Time taken: 0.5887396335601807
# idx **** 39
# Run *** 39
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05973744343660291
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009094218951472036
# Final distance 0.0045204124640486915
# Final simulation: 5
# Time taken: 2.184969663619995
# idx **** 40
# Run *** 40
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09951064273591846
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0020429820708586723
# Final distance 0.0017441613392346453
# Final simulation: 7
# Time taken: 3.108445167541504
# idx **** 41
# Run *** 41
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2621262483707347
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012784626425415696
# Final distance 0.04519879754895276
# Final simulation: 4
# Time taken: 1.5485613346099854
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05880557439138721
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.010523430527174131
# Final distance 0.05880557439138721
# Final simulation: 1
# Time taken: 0.0011239051818847656
# idx **** 42
# Run *** 42
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10884660136785343
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02391912315150113
# Final distance 0.01673142631049842
# Final simulation: 3
# Time taken: 1.0461413860321045
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07590088199527921
# Best robustness -1.7144622625081454e-05
# Final distance 0.07590088199527921
# Final simulation: 51
# Time taken: 24.061709880828857
# idx **** 43
# Run *** 43
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.13443773424587852
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01677178345361349
# Final distance 0.0728931173381376
# Final simulation: 2
# Time taken: 0.8559391498565674
# idx **** 44
# Run *** 44
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11433602167160402
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0132374498677987
# Final distance 0.05896697032009437
# Final simulation: 2
# Time taken: 0.5795748233795166
# idx **** 45
# Run *** 45
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.025322663613242598
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00795161036507741
# Final distance 0.015585586532051054
# Final simulation: 2
# Time taken: 0.5974948406219482
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.058223489118285766
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.02346788428481153
# Final distance 0.058223489118285766
# Final simulation: 1
# Time taken: 0.0010068416595458984
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05545058495822358
# Best robustness -0.0015386159181017128
# Final distance 0.05545058495822358
# Final simulation: 51
# Time taken: 23.580123901367188
# idx **** 46
# Run *** 46
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05358930681816606
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003574488364586348
# Final distance 0.034446768122892095
# Final simulation: 2
# Time taken: 0.569007158279419
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04859122650327726
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.01601289198589756
# Final distance 0.04859122650327726
# Final simulation: 1
# Time taken: 0.0010113716125488281
# idx **** 47
# Run *** 47
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1503494891992797
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.014421258622679744
# Final distance 0.0811384709851857
# Final simulation: 2
# Time taken: 0.5419127941131592
# idx **** 48
# Run *** 48
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 84
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0498706724324181
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0022865384441848355
# Final distance 0.004881736528953731
# Final simulation: 6
# Time taken: 2.3903491497039795
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04903843847058803
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.02117511276143158
# Final distance 0.04903843847058803
# Final simulation: 1
# Time taken: 0.0004112720489501953
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0697506873563942
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.0060942460401485765
# Final distance 0.0697506873563942
# Final simulation: 1
# Time taken: 0.00039768218994140625
# idx **** 49
# Run *** 49
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14828645792372572
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0014973541956856962
# Final distance 0.01816814244331487
# Final simulation: 4
# Time taken: 1.4410679340362549
# idx **** 50
# Run *** 50
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1368811546113374
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.01469442666890134
# Final distance 0.031814121003163644
# Final simulation: 3
# Time taken: 0.9361164569854736
# idx **** 51
# Run *** 51
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04952189997623377
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02290275147470744
# Final distance 0.022455857472360348
# Final simulation: 2
# Time taken: 0.5350508689880371
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.029472507828888918
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.007331250791742338
# Final distance 0.029472507828888918
# Final simulation: 1
# Time taken: 0.00046634674072265625
# idx **** 52
# Run *** 52
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.03111772631073746
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0018102591692186224
# Final distance 0.01612634174089922
# Final simulation: 3
# Time taken: 0.9775595664978027
# idx **** 53
# Run *** 53
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16973934841845892
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006366010044073644
# Final distance 0.08507344164283498
# Final simulation: 2
# Time taken: 0.5573499202728271
# idx **** 54
# Run *** 54
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08505305397164326
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.010748453277859137
# Final distance 0.012673007381576031
# Final simulation: 8
# Time taken: 3.4445130825042725
# idx **** 55
# Run *** 55
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.038417899882629405
# Best robustness -0.003975863370345247
# Final distance 0.007116890928207264
# Final simulation: 51
# Time taken: 21.937832355499268
# idx **** 56
# Run *** 56
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16640575722942608
# Best robustness -0.0013974411675961693
# Final distance 0.0013318840889369847
# Final simulation: 7
# Time taken: 3.0124704837799072
# idx **** 57
# Run *** 57
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16554412532373
# Best robustness 0.000367638704489764
# Final distance 0.011123345810419384
# Final simulation: 51
# Time taken: 22.56090235710144
# idx **** 58
# Run *** 58
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04709047767004519
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005416471814290669
# Final distance 0.005920151575456411
# Final simulation: 5
# Time taken: 2.222367286682129
# idx **** 59
# Run *** 59
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10687448091793118
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0019412956673864577
# Final distance 0.006086690529145336
# Final simulation: 4
# Time taken: 1.7956395149230957
# idx **** 60
# Run *** 60
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.25071258928088397
# Best robustness -0.007071307983338187
# Final distance 0.009426384899958897
# Final simulation: 51
# Time taken: 25.944141149520874
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08338531003846922
# Best robustness 0.003652823316838626
# Final distance 0.08338531003846922
# Final simulation: 51
# Time taken: 22.914196252822876
# idx **** 61
# Run *** 61
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1541608178503802
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004584728113847822
# Final distance 0.024729690120710787
# Final simulation: 4
# Time taken: 1.4104654788970947
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06630954392145816
# Best robustness 0.0005247868408426839
# Final distance 0.06630954392145816
# Final simulation: 51
# Time taken: 24.16951560974121
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07824374781182866
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.010234046919044027
# Final distance 0.07824374781182866
# Final simulation: 2
# Time taken: 0.545393705368042
# idx **** 62
# Run *** 62
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06127197174174673
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006155586592115476
# Final distance 0.009597696702881684
# Final simulation: 4
# Time taken: 1.5198118686676025
# idx **** 63
# Run *** 63
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16015444662523715
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005345048805730834
# Final distance 0.05018364145570334
# Final simulation: 3
# Time taken: 1.0202438831329346
# idx **** 64
# Run *** 64
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07577136196534681
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0076577213976889436
# Final distance 0.04331212948034328
# Final simulation: 2
# Time taken: 0.5670151710510254
# idx **** 65
# Run *** 65
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.29974071296533983
# Best robustness -0.003894053451706762
# Final distance 0.0114735475238743
# Final simulation: 51
# Time taken: 24.225963830947876
# idx **** 66
# Run *** 66
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08928320793180995
# Best robustness -0.001537058872568317
# Final distance 0.0011588748430859028
# Final simulation: 22
# Time taken: 10.498046398162842
# idx **** 67
# Run *** 67
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.23194247830083706
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012260425880533814
# Final distance 0.02997774761633071
# Final simulation: 3
# Time taken: 1.316389560699463
# idx **** 68
# Run *** 68
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15077647992740056
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006019007746940679
# Final distance 0.013010566881251837
# Final simulation: 5
# Time taken: 2.031141996383667
# idx **** 69
# Run *** 69
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08279493164555952
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.011515119263019534
# Final distance 0.04546696496777701
# Final simulation: 2
# Time taken: 0.5737977027893066
# idx **** 70
# Run *** 70
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.10080670828428567
# Best robustness -0.0007041864752680965
# Final distance 0.001700242748869572
# Final simulation: 7
# Time taken: 3.128965139389038
# idx **** 71
# Run *** 71
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04690159810799112
# Best robustness -0.0007294483828883536
# Final distance 0.0014798205567977398
# Final simulation: 9
# Time taken: 4.143861293792725
# idx **** 72
# Run *** 72
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.044207023199736004
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005477621590678994
# Final distance 0.002804878220243857
# Final simulation: 5
# Time taken: 2.058316230773926
# idx **** 73
# Run *** 73
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.034794545437330134
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009352633866334836
# Final distance 0.028808086228496715
# Final simulation: 3
# Time taken: 0.9985933303833008
# idx **** 74
# Run *** 74
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 81
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08852967052659237
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004102387239368279
# Final distance 0.0029375472811199034
# Final simulation: 6
# Time taken: 2.6556649208068848
# idx **** 75
# Run *** 75
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.14498211870307245
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00910177753007409
# Final distance 0.002969246903401671
# Final simulation: 43
# Time taken: 19.34007453918457
# idx **** 76
# Run *** 76
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 96
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15474890801680324
# Best robustness -0.0003077288821298771
# Final distance 0.0013164893204314714
# Final simulation: 12
# Time taken: 5.268112421035767
# idx **** 77
# Run *** 77
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.034146048755207443
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0026082438201984674
# Final distance 0.0015876595822408258
# Final simulation: 3
# Time taken: 1.0354397296905518
# idx **** 78
# Run *** 78
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0699052223840304
# Best robustness -0.0008490934338298839
# Final distance 0.0013609024762787703
# Final simulation: 10
# Time taken: 4.164350271224976
# idx **** 79
# Run *** 79
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.026413536798294345
# Best robustness 0.00043667991606111123
# Final distance 0.0019614566014782247
# Final simulation: 7
# Time taken: 3.091791868209839
# idx **** 80
# Run *** 80
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1964380385599035
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005453364859537169
# Final distance 0.004328293739161586
# Final simulation: 8
# Time taken: 3.0834500789642334
# idx **** 81
# Run *** 81
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1781024107630231
# Best robustness -0.004758574184177917
# Final distance 0.0010253820027017486
# Final simulation: 9
# Time taken: 4.154749870300293
# idx **** 82
# Run *** 82
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 80
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.040111162597199566
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.006586823687909617
# Final distance 0.025197366318712142
# Final simulation: 2
# Time taken: 0.5368177890777588
# idx **** 83
# Run *** 83
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06647819286976936
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.009949380102814785
# Final distance 0.00628357972026347
# Final simulation: 3
# Time taken: 0.9986493587493896
# idx **** 84
# Run *** 84
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.12751714044187373
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008667855974316614
# Final distance 0.01172802722579646
# Final simulation: 5
# Time taken: 1.8243494033813477
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 93
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05946328756124348
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.03140873609336553
# Final distance 0.05946328756124348
# Final simulation: 1
# Time taken: 0.0008313655853271484
# idx **** 85
# Run *** 85
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.15203590196283384
# Best robustness -0.00045509069501929386
# Final distance 0.0018246029256940464
# Final simulation: 21
# Time taken: 9.509838819503784
# idx **** 86
# Run *** 86
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 83
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16895073321691825
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.003542241884621374
# Final distance 0.028654474789982128
# Final simulation: 4
# Time taken: 1.4518201351165771
# idx **** 87
# Run *** 87
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.16260760507662675
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.03007322076536112
# Final distance 0.04409539683418388
# Final simulation: 3
# Time taken: 1.0172691345214844
# idx **** 88
# Run *** 88
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.18600945578103134
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.005519088201152182
# Final distance 0.09093399173568319
# Final simulation: 2
# Time taken: 0.4892871379852295
# idx **** 89
# Run *** 89
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07778341749177672
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.008243915217822695
# Final distance 0.039922596937410695
# Final simulation: 2
# Time taken: 0.5066452026367188
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06484676947034486
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.008014533554547287
# Final distance 0.06484676947034486
# Final simulation: 1
# Time taken: 0.0011816024780273438
# idx **** 90
# Run *** 90
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.08881633220555811
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02106041150156516
# Final distance 0.06908832530390059
# Final simulation: 2
# Time taken: 0.48692846298217773
# idx **** 91
# Run *** 91
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.06693080593030794
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.013774471035468305
# Final distance 0.027060692403944733
# Final simulation: 3
# Time taken: 0.9544506072998047
# idx **** 92
# Run *** 92
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.09345214569803682
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.004145255125397684
# Final distance 0.010843722822453357
# Final simulation: 7
# Time taken: 2.615387439727783
# idx **** 93
# Run *** 93
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04490484486362701
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.028586088450537117
# Final distance 0.017750107629942686
# Final simulation: 2
# Time taken: 0.5226836204528809
# idx **** 94
# Run *** 94
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05418581996653761
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0066372956221601165
# Final distance 0.051566411574972874
# Final simulation: 2
# Time taken: 0.49718546867370605
# idx **** 95
# Run *** 95
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 96
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.17046630500653515
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.02108010140644063
# Final distance 0.03833273591100817
# Final simulation: 3
# Time taken: 0.9387094974517822
# idx **** 96
# Run *** 96
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 89
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.04519745281235727
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.0021817986883314686
# Final distance 0.007444924605241264
# Final simulation: 4
# Time taken: 1.4793179035186768
# idx **** 97
# Run *** 97
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 94
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.1382349458793466
# Best robustness -0.0003969066730778843
# Final distance 0.0019377896303931468
# Final simulation: 7
# Time taken: 3.2721893787384033
# idx **** 98
# Run *** 98
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07140284659963594
# Best robustness 0.0005083608595481091
# Final distance 0.005432804648350848
# Final simulation: 51
# Time taken: 21.617421865463257
# idx **** 99
# Run *** 99
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_OtherBenchC3_RBF_1_512_ReLU.h5
# 98
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0640027108622577
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.00954102746610478
# Final distance 0.001905800283615513
# Final simulation: 7
# Time taken: 2.4569199085235596
# idx **** 100
# 8.89
# -0.007896567960815788
# 51
# 183.33790000000005

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen import EvaluationInvSen

evalObject = EvaluationInvSen(dynamics='SinglePendulum')
evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(120)
# dataObject.setLowerBound([0.8, 0.9])
# dataObject.setUpperBound([1.2, 1.2])
# dataObject.setStepSize(0.02)
lowerBound = [1.1, -1.0]
evalObject.setUnsafeSet(lowerBound, upperBound)
stl_time_interval = [0.6, 0.8]

f_simulations = []
min_dists = []
max_iter = 100
idx = 0
while idx < max_iter:
    print("Run *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    print(ref_traj[60], ref_traj[80])
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002, 
                        correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations.append(f_sims)
        min_dists.append(min_dist)
        idx = idx + 1
    print("idx **** " + str(idx))

print(np.sum(f_simulations)/(max_iter))
print(np.sum(min_dists)/(max_iter))
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/dconfigs_inv/d_object_SinglePendulum.txt
# Run *** 0
# [ 1.38669023 -1.07239775] [ 1.17995662 -0.9826416 ]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.11831511513858473
# Best robustness -0.006741971774000044
# Final distance 0.0014793525871608533
# Final simulation: 7
# Time taken: 1.6555681228637695
# idx **** 1
# Run *** 1
# [ 1.33752075 -0.93752027] [ 1.152161   -0.90110139]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.0593420345053231
#  Trajectory found
# Found the time step ****
#  Trajectory found
# Best robustness -0.012492166691995266
# Final distance 0.004797379717782531
# Final simulation: 4
# Time taken: 0.8365919589996338
# idx **** 2
# Run *** 2
# [ 0.8265224  -0.51639831] [ 0.72391742 -0.50408254]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.5417102760044192
# Best robustness -0.0478033785133789
# Final distance 0.001971859907425356
# Final simulation: 6
# Time taken: 1.307908058166504
# idx **** 3
# Run *** 3
# [ 1.10190737 -0.64539303] [ 0.96999151 -0.66165423]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.2498202546512909
# Best robustness -0.025252002763214598
# Final distance 0.0014107821855375618
# Final simulation: 10
# Time taken: 2.3807904720306396
# idx **** 4
# Run *** 4
# [ 1.25865167 -0.81455124] [ 1.09500022 -0.80795031]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 76
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.07759752124518554
#  Trajectory found
# *********** Initial sample falsified ************
#  Trajectory found
# Best robustness -0.016445684293573626
# Final distance 0.07759752124518554
# Final simulation: 1
# Time taken: 0.00033164024353027344
# idx **** 4
# Run *** 4
# [ 0.9175792  -0.52679278] [ 0.81033479 -0.53726831]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 60
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.4777993048520138
# Best robustness -0.012927938090916635
# Final distance 0.0017741686570234589
# Final simulation: 7
# Time taken: 1.6649322509765625
# idx **** 5
# Run *** 5
# [ 1.41256762 -1.00050252] [ 1.21437318 -0.9637576 ]
# /home/manishg/Research/NExG//eval-emsoft/eval-gr/models/model_vp_2_v_SinglePendulum_RBF_1_512_ReLU.h5
# 78
# ***** path idx 0 s_factor 0.2 correction steps 5
# Starting distance: 0.05847843784559516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a202525e2fdf> in <module>
#      35     dests = dest
#      36     evalObject.reachDestInvSen(dests=dests, d_time_steps=stl_time_interval, threshold=0.002,
# ---> 37                         correction_steps = [5], scaling_factors=[0.2], i_state=[ref_traj[0]])
#      38     f_sims = evalObject.getFSimulations()
#      39     min_dist = evalObject.getFDistance()
#
# ~/Research/NExG/core/evaluation_isen.py in reachDestInvSen(self, dests, d_time_steps, threshold, correction_steps, scaling_factors, i_state)
#     375                                                      threshold=threshold,  model_v=trained_model, correction_steps=steps,
#     376                                                      scaling_factor=s_factor, sims_bound=self.sims_bound,
# --> 377                                                      dynamics=self.dynamics)
#     378                         print("Time taken: " + str(time.time() - start_time))
#     379
#
# ~/Research/NExG/core/evaluation_isen.py in reachDestInvNonBaseline(self, ref_traj, paths, d_time_step, threshold, model_v, correction_steps, sims_bound, scaling_factor, rand_area, dynamics)
#     528                 while step < correction_steps:
#     529                     data_point = self.data_object.createDataPoint(x_val, xp_val, v_val, vp_val_normalized, t_val)
# --> 530                     predicted_v = self.evalModel(input=data_point, eval_var='v', model=model_v)
#     531                     predicted_v_scaled = [val * scaling_factor * vp_norm for val in predicted_v]
#     532                     new_init_state = [self.check_for_bounds(x_val + predicted_v_scaled)]
#
# ~/Research/NExG/core/evaluation.py in evalModel(self, input, eval_var, model)
#     120             xp_vp_t_pair = xp_vp_t_pair + [input[4]]
#     121             xp_vp_t_pair = np.asarray([xp_vp_t_pair], dtype=np.float64)
# --> 122             predicted_v = model.predict(xp_vp_t_pair)
#     123             predicted_v = predicted_v.flatten()
#     124             output = predicted_v
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     695     self._concrete_stateful_fn = (
#     696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 697             *args, **kwds))
#     698
#     699     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     967                     recursive=True,
#     968                     optional_features=autograph_options,
# --> 969                     user_requested=True,
#     970                 ))
#     971           except Exception as e:  # pylint:disable=broad-except
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     594     try:
#     595       if kwargs is not None:
# --> 596         result = converted_f(*effective_args, **kwargs)
#     597       else:
#     598         result = converted_f(*effective_args)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in tf__predict_function(iterator)
#      14                 try:
#      15                     do_return = True
# ---> 16                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      17                 except:
#      18                     do_return = False
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     530
#     531   if not options.user_requested and conversion.is_whitelisted(f):
# --> 532     return _call_unconverted(f, args, kwargs, options)
#     533
#     534   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     338   if kwargs is not None:
#     339     return f(*args, **kwargs)
# --> 340   return f(*args)
#     341
#     342
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in step_function(model, iterator)
#    1450
#    1451       data = next(iterator)
# -> 1452       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1453       outputs = reduce_per_replica(
#    1454           outputs, self.distribute_strategy, reduction='concat')
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1209       fn = autograph.tf_convert(
#    1210           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1211       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1212
#    1213   # TODO(b/151224785): Remove deprecated alias.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2583       kwargs = {}
#    2584     with self._container_strategy().scope():
# -> 2585       return self._call_for_each_replica(fn, args, kwargs)
#    2586
#    2587   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    2943         self._container_strategy(),
#    2944         replica_id_in_sync_group=constant_op.constant(0, dtypes.int32)):
# -> 2945       return fn(*args, **kwargs)
#    2946
#    2947   def _reduce_to(self, reduce_op, value, destinations, experimental_hints):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     253       try:
#     254         with conversion_ctx:
# --> 255           return converted_call(f, args, kwargs, options=options)
#     256       except Exception as e:  # pylint:disable=broad-except
#     257         if hasattr(e, 'ag_error_metadata'):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     530
#     531   if not options.user_requested and conversion.is_whitelisted(f):
# --> 532     return _call_unconverted(f, args, kwargs, options)
#     533
#     534   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337
#     338   if kwargs is not None:
# --> 339     return f(*args, **kwargs)
#     340   return f(*args)
#     341
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in run_step(data)
#    1443
#    1444       def run_step(data):
# -> 1445         outputs = model.predict_step(data)
#    1446         # Ensure counter is updated only if `test_step` succeeds.
#    1447         with ops.control_dependencies(_minimum_control_deps(outputs)):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict_step(self, data)
#    1416     data = data_adapter.expand_1d(data)
#    1417     x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 1418     return self(x, training=False)
#    1419
#    1420   def make_predict_function(self):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     370       if not self.built:
#     371         self._init_graph_network(self.inputs, self.outputs)
# --> 372       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     373
#     374     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     384     """
#     385     return self._run_internal_graph(
# --> 386         inputs, training=training, mask=mask)
#     387
#     388   def compute_output_shape(self, input_shape):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     506
#     507         args, kwargs = node.map_arguments(tensor_dict)
# --> 508         outputs = node.layer(*args, **kwargs)
#     509
#     510         # Update tensor_dict.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/normalization.py in call(self, inputs, training)
#     862     outputs = nn.batch_normalization(inputs, _broadcast(mean),
#     863                                      _broadcast(variance), offset, scale,
# --> 864                                      self.epsilon)
#     865     if inputs_dtype in (dtypes.float16, dtypes.bfloat16):
#     866       outputs = math_ops.cast(outputs, inputs_dtype)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py in batch_normalization(x, mean, variance, offset, scale, variance_epsilon, name)
#    1534   """
#    1535   with ops.name_scope(name, "batchnorm", [x, mean, variance, scale, offset]):
# -> 1536     inv = math_ops.rsqrt(variance + variance_epsilon)
#    1537     if scale is not None:
#    1538       inv *= scale
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _run_op(a, *args, **kwargs)
#    1072     def _run_op(a, *args, **kwargs):
#    1073       # pylint: disable=protected-access
# -> 1074       return tensor_oper(a.value(), *args, **kwargs)
#    1075
#    1076     functools.update_wrapper(_run_op, tensor_oper)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1123     with ops.name_scope(None, op_name, [x, y]) as name:
#    1124       try:
# -> 1125         return func(x, y, name=name)
#    1126       except (TypeError, ValueError) as e:
#    1127         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in _add_dispatch(x, y, name)
#    1445     return gen_math_ops.add(x, y, name=name)
#    1446   else:
# -> 1447     return gen_math_ops.add_v2(x, y, name=name)
#    1448
#    1449
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in add_v2(x, y, name)
#     494   # Add nodes to the TensorFlow graph.
#     495   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# --> 496         "AddV2", x=x, y=y, name=name)
#     497   _result = _outputs[:]
#     498   if _execute.must_record_gradient():
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     742       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     743                                  name=scope, input_types=input_types,
# --> 744                                  attrs=attr_protos, op_def=op_def)
#     745
#     746     # `outputs` is returned as a separate return value so that the output
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     591     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     592         op_type, inputs, dtypes, input_types, name, attrs, op_def,
# --> 593         compute_device)
#     594
#     595   def capture(self, tensor, name=None, shape=None):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3484           original_op=self._default_original_op,
#    3485           op_def=op_def)
# -> 3486       self._create_op_helper(ret, compute_device=compute_device)
#    3487     return ret
#    3488
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/lock_util.py in __exit__(***failed resolving arguments***)
#     125
#     126     def __exit__(self, type_arg, value_arg, traceback_arg):
# --> 127       del type_arg, value_arg, traceback_arg
#     128       self._lock.release(self._group_id)
#
# KeyboardInterrupt:
