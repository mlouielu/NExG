# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen_nongr import EvaluationInvSenNonGr

evalObject = EvaluationInvSenNonGr(dynamics='OtherBenchC1')

evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()

dataObject.setLowerBound([0.5, 0.5])
dataObject.setUpperBound([1.5, 1.5])
lowerBound = [0.3, -1.1]
upperBound = [0.35, -1.05]
evalObject.setUnsafeSet(lowerBound, upperBound)
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_steps = [70, 80]

max_iter = 500
f_simulations = np.zeros(max_iter)
min_dists = np.zeros(max_iter)
idx = 0
while idx < max_iter:
    print("Idx *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    print(dests)
    evalObject.reachDestInvSen(dests=dests, d_time_steps=time_steps, threshold=0.0, correction_steps=[1],
                            scaling_factors=[1], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations[idx] = f_sims
        min_dists[idx] = min_dist
        idx = idx + 1
    else:
        print("** either f_iter is 1 or rel_dist is 1.0 **")
# print(f_iterations, min_rel_dists)
print(np.sum(f_simulations)/max_iter)
print(np.sum(min_dists)/max_iter)
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# Idx *** 0
# [[0.3413540171528233, -1.0776388873881981]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0758439938934388
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3ee8103ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Best robustness -0.00458916476327903
# Final simulation: 2
# Time taken: 0.46616077423095703
# Idx *** 1
# [[0.305237368476344, -1.0942886362151818]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10661628091413523
# Best robustness -0.021829878277274117
# Final simulation: 2
# Time taken: 0.4758419990539551
# Idx *** 2
# [[0.31423795526207327, -1.0716954059922332]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.17660461183750745
# Best robustness -0.024497579087842447
# Final simulation: 2
# Time taken: 0.4868500232696533
# Idx *** 3
# [[0.3338157122273576, -1.0506827313450215]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20880264664424317
# Best robustness -0.021295015564102904
# Final simulation: 2
# Time taken: 0.4628431797027588
# Idx *** 4
# [[0.3098182088709338, -1.0957972127864506]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.25367580673252194
# Best robustness -0.03559282719316903
# Final simulation: 2
# Time taken: 0.4949626922607422
# Idx *** 5
# [[0.340825175998509, -1.0563122319426579]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.14155995682700687
# Best robustness -0.012526182387791851
# Final simulation: 2
# Time taken: 0.7489168643951416
# Idx *** 6
# [[0.3402902631559075, -1.0823768500752842]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09030741513914867
# Best robustness -0.006741558475574894
# Final simulation: 2
# Time taken: 0.6206390857696533
# Idx *** 7
# [[0.31313739095592136, -1.0927646152512291]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.05389674895017466
# Best robustness -0.026740100098033293
# Final simulation: 2
# Time taken: 0.5930399894714355
# Idx *** 8
# [[0.308441101489209, -1.052452310275479]]
# 76
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.007684214118512977
# *********** Initial sample falsified ************
# Best robustness -0.00339782593310034
# Final simulation: 1
# Time taken: 0.0001735687255859375
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 8
# [[0.3483567214623132, -1.0975565134170906]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.015281402229843357
# *********** Initial sample falsified ************
# Best robustness -0.02727027348296923
# Final simulation: 1
# Time taken: 0.00021195411682128906
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 8
# [[0.30140411808993606, -1.0662617142471174]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11738912247802
# Best robustness -0.03287241185505119
# Final simulation: 2
# Time taken: 0.6831111907958984
# Idx *** 9
# [[0.3061566630733921, -1.0655841492283897]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11334955597759902
# Best robustness -0.010372166922053339
# Final simulation: 2
# Time taken: 0.6326253414154053
# Idx *** 10
# [[0.3338430487400282, -1.0574932666583912]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.012402863210766599
# *********** Initial sample falsified ************
# Best robustness -0.0014633753715933562
# Final simulation: 1
# Time taken: 0.00019931793212890625
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 10
# [[0.3233014774503881, -1.084282765768751]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2371464667181612
# Best robustness -0.032330285551716076
# Final simulation: 2
# Time taken: 0.6109483242034912
# Idx *** 11
# [[0.3030673223236773, -1.0861244300627397]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1479992935019689
# Best robustness -0.030140910890057604
# Final simulation: 2
# Time taken: 0.6197729110717773
# Idx *** 12
# [[0.30114458773152, -1.0950089456908423]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0699783892688808
# Best robustness -0.030244984524757823
# Final simulation: 2
# Time taken: 0.7453045845031738
# Idx *** 13
# [[0.3083023877598458, -1.0833922130737985]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02548366350522931
# *********** Initial sample falsified ************
# Best robustness -0.0052235376686770585
# Final simulation: 1
# Time taken: 0.00019097328186035156
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 13
# [[0.31369919691312714, -1.084059215798209]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08237271632715708
# Best robustness -0.015349954381342068
# Final simulation: 2
# Time taken: 0.7625925540924072
# Idx *** 14
# [[0.3037877716694417, -1.0910237378808374]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.18418184683994113
# Best robustness -0.03205890830073893
# Final simulation: 2
# Time taken: 0.6707186698913574
# Idx *** 15
# [[0.3462298135570504, -1.0888623481220583]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04777462125785908
# Best robustness -0.0034368409303825453
# Final simulation: 3
# Time taken: 1.1551685333251953
# Idx *** 16
# [[0.30127022310088025, -1.0684428899935352]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11452054790759379
# Best robustness -0.024140256534070703
# Final simulation: 2
# Time taken: 0.6666057109832764
# Idx *** 17
# [[0.3328956717739475, -1.0738039313738457]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1636462725496947
# Best robustness -0.023154501251668513
# Final simulation: 2
# Time taken: 0.6329083442687988
# Idx *** 18
# [[0.3003727549692873, -1.0798650008456034]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09340775406412284
# Best robustness -0.028745554217590508
# Final simulation: 2
# Time taken: 0.8678441047668457
# Idx *** 19
# [[0.31226623256979136, -1.0579009036972171]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0043721572842893444
# *********** Initial sample falsified ************
# Best robustness -0.023408788409645442
# Final simulation: 1
# Time taken: 0.0004429817199707031
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 19
# [[0.31027927128967914, -1.0673173832261715]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.003326177276558579
# *********** Initial sample falsified ************
# Best robustness -0.032066926522780426
# Final simulation: 1
# Time taken: 0.00020837783813476562
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 19
# [[0.3298349744911108, -1.0901561977985068]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09661427540640191
# Best robustness -0.027607399200146265
# Final simulation: 2
# Time taken: 0.7244820594787598
# Idx *** 20
# [[0.30343115667618936, -1.0961245926915941]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09510573614462406
# Best robustness -0.01986501779804528
# Final simulation: 2
# Time taken: 0.6680614948272705
# Idx *** 21
# [[0.3386008493495685, -1.0716474130701927]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10720092782245298
# Best robustness -0.018299009888929185
# Final simulation: 2
# Time taken: 1.0534813404083252
# Idx *** 22
# [[0.32085027649591047, -1.0932425000610313]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.14393638020854502
# Best robustness -0.017006132186324463
# Final simulation: 2
# Time taken: 0.6295921802520752
# Idx *** 23
# [[0.30225883252294705, -1.0687556572885888]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07749911781447127
# Best robustness -0.03210425660048011
# Final simulation: 2
# Time taken: 0.6448974609375
# Idx *** 24
# [[0.3053402026570799, -1.068009330661602]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0875324321209896
# Best robustness -0.013391666540771285
# Final simulation: 2
# Time taken: 0.8672125339508057
# Idx *** 25
# [[0.3020569277197527, -1.077154861091592]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12794594661513853
# Best robustness -0.022198477706872832
# Final simulation: 2
# Time taken: 0.7007148265838623
# Idx *** 26
# [[0.3183008123272934, -1.079538353866034]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.19633844024276156
# Best robustness -0.013322852476797098
# Final simulation: 2
# Time taken: 0.8382458686828613
# Idx *** 27
# [[0.33859608311383516, -1.075555039779839]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.05848218159627451
# Best robustness -0.002359127818191975
# Final simulation: 2
# Time taken: 0.7470436096191406
# Idx *** 28
# [[0.3104430486611591, -1.0525725564675268]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.011323203701251706
# Best robustness -0.003163520999349023
# Final simulation: 2
# Time taken: 0.794517993927002
# Idx *** 29
# [[0.3010489880628747, -1.0790377290914868]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.18680972443748536
# Best robustness -0.014877131940778165
# Final simulation: 2
# Time taken: 0.7816455364227295
# Idx *** 30
# [[0.30666053814492283, -1.0795095774534391]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02480131318301441
# *********** Initial sample falsified ************
# Best robustness -0.0032037698059465547
# Final simulation: 1
# Time taken: 0.0001971721649169922
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 30
# [[0.3464395918685132, -1.0716633268674611]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.016648508226744015
# *********** Initial sample falsified ************
# Best robustness -0.006355371247256381
# Final simulation: 1
# Time taken: 0.00036025047302246094
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 30
# [[0.3147744990302561, -1.088780824147285]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.048003385257144836
# *********** Initial sample falsified ************
# Best robustness -0.002616082284603638
# Final simulation: 1
# Time taken: 0.00041484832763671875
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 30
# [[0.343175571416036, -1.0603806674678373]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09180844545489272
# Best robustness -0.011500079568527388
# Final simulation: 2
# Time taken: 0.8186962604522705
# Idx *** 31
# [[0.3112252693600787, -1.0701349181423934]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.018444146270854
# *********** Initial sample falsified ************
# Best robustness -0.010164072595184148
# Final simulation: 1
# Time taken: 0.00037384033203125
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 31
# [[0.32286629402786826, -1.0899291407849125]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09286597835924645
# Best robustness -0.01264403991378682
# Final simulation: 2
# Time taken: 0.9857766628265381
# Idx *** 32
# [[0.34954487686202323, -1.0601033377247153]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2572657427961916
# Best robustness -0.0145992872568243
# Final simulation: 2
# Time taken: 1.275987148284912
# Idx *** 33
# [[0.30503244808582025, -1.0953043252437387]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07463850780046424
# Best robustness -0.032970273069651945
# Final simulation: 2
# Time taken: 0.9099581241607666
# Idx *** 34
# [[0.33759381271730793, -1.0907087844153223]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20917609462844575
# Best robustness -0.024105043019680972
# Final simulation: 2
# Time taken: 0.9125511646270752
# Idx *** 35
# [[0.3368368929286698, -1.0549609503590287]]
# 76
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.00734919262392807
# *********** Initial sample falsified ************
# Best robustness -0.005937440055167942
# Final simulation: 1
# Time taken: 0.0001842975616455078
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 35
# [[0.3414258643020754, -1.0545822894885146]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06314046493214395
# Best robustness -0.01878364650349873
# Final simulation: 2
# Time taken: 0.6348109245300293
# Idx *** 36
# [[0.34643436958420554, -1.075896051080911]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.01928492206477402
# *********** Initial sample falsified ************
# Best robustness -0.020238233190466748
# Final simulation: 1
# Time taken: 0.00022649765014648438
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 36
# [[0.309801448806794, -1.0763380660168176]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02091053846107924
# *********** Initial sample falsified ************
# Best robustness -0.008407233354672528
# Final simulation: 1
# Time taken: 0.0001499652862548828
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 36
# [[0.34505477528848316, -1.0844549376389658]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.18232085226667166
# Best robustness -0.010607803743029665
# Final simulation: 5
# Time taken: 2.657029151916504
# Idx *** 37
# [[0.3150155650318842, -1.065506113385509]]
# 76
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0036107242034878833
# *********** Initial sample falsified ************
# Best robustness -0.012412623875249773
# Final simulation: 1
# Time taken: 0.0004267692565917969
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 37
# [[0.3171491456213635, -1.0623993880413547]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.19232229825308744
# Best robustness -0.0075066245767729245
# Final simulation: 2
# Time taken: 0.8294038772583008
# Idx *** 38
# [[0.30464777763572437, -1.0503188960150558]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.17074411420382812
# Best robustness -0.006108804218520836
# Final simulation: 2
# Time taken: 1.0444972515106201
# Idx *** 39
# [[0.34577018097439866, -1.0627582104305702]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.021337207100391692
# *********** Initial sample falsified ************
# Best robustness -0.01209786188115547
# Final simulation: 1
# Time taken: 0.00031113624572753906
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 39
# [[0.3414676108229377, -1.0964601807912557]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12455918983876037
# Best robustness -0.017709479090390223
# Final simulation: 2
# Time taken: 0.6965973377227783
# Idx *** 40
# [[0.33821863104353256, -1.052643922287291]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.024633643443841214
# *********** Initial sample falsified ************
# Best robustness -0.012429452410670894
# Final simulation: 1
# Time taken: 0.00020551681518554688
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 40
# [[0.30912844000203976, -1.0785939437073504]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10549179140888079
# Best robustness -0.023089991256549425
# Final simulation: 2
# Time taken: 0.7483470439910889
# Idx *** 41
# [[0.3184766177643324, -1.055119194702222]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.037068855231143664
# *********** Initial sample falsified ************
# Best robustness -0.01720948887873336
# Final simulation: 1
# Time taken: 0.00018715858459472656
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 41
# [[0.33882126128787193, -1.0507748403185648]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.043565037332513955
# *********** Initial sample falsified ************
# Best robustness -0.007149700698924899
# Final simulation: 1
# Time taken: 0.0002167224884033203
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 41
# [[0.3308379755690139, -1.095598606987541]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.01027010133764738
# *********** Initial sample falsified ************
# Best robustness -0.029419495395717088
# Final simulation: 1
# Time taken: 0.0002903938293457031
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 41
# [[0.33876118971366265, -1.0955182357149618]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.012265922001732234
# *********** Initial sample falsified ************
# Best robustness -0.009127346379127932
# Final simulation: 1
# Time taken: 0.00018167495727539062
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 41
# [[0.3393865362229271, -1.0776600736927164]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06082062841206145
# Best robustness -0.007636782383575569
# Final simulation: 2
# Time taken: 0.6144919395446777
# Idx *** 42
# [[0.30292995059209593, -1.096252438660472]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10086454676748402
# Best robustness -0.023815523099076863
# Final simulation: 2
# Time taken: 0.6349060535430908
# Idx *** 43
# [[0.3444755993989643, -1.0991162479468777]]
# 74
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06831164798476926
# Best robustness -0.00991207708252978
# Final simulation: 2
# Time taken: 0.6719472408294678
# Idx *** 44
# [[0.3493104920826747, -1.082283060382955]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08993088725539797
# Best robustness -0.00832021899292118
# Final simulation: 2
# Time taken: 0.7811849117279053
# Idx *** 45
# [[0.349427321356958, -1.0748289809799325]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06584557590062766
# Best robustness -0.0034216014882296197
# Final simulation: 2
# Time taken: 0.7403717041015625
# Idx *** 46
# [[0.32963336705134694, -1.0873602729395233]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.00024920818650753777
# *********** Initial sample falsified ************
# Best robustness -0.020157802896472454
# Final simulation: 1
# Time taken: 0.000202178955078125
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 46
# [[0.3022220546294655, -1.0764234242683601]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1536358133736249
# Best robustness -0.028124881942335977
# Final simulation: 2
# Time taken: 0.6814596652984619
# Idx *** 47
# [[0.3188810302935765, -1.0842148890632475]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08820826383894351
# Best robustness -0.008343405000713178
# Final simulation: 2
# Time taken: 0.7500820159912109
# Idx *** 48
# [[0.34233923633068075, -1.0990581378927577]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.3907240555008025
# Best robustness -0.02924656964573885
# Final simulation: 2
# Time taken: 0.6920077800750732
# Idx *** 49
# [[0.32489966322919367, -1.0770121058387931]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.30503510580485604
# Best robustness -0.03286347628535857
# Final simulation: 2
# Time taken: 0.796877384185791
# Idx *** 50
# [[0.3208423623463829, -1.0920281021257676]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.14543635030475743
# Best robustness -0.003813596399284691
# Final simulation: 2
# Time taken: 0.8671407699584961
# Idx *** 51
# [[0.3344182893546381, -1.0589114211914223]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.110190560730944
# Best robustness -0.010102381513326764
# Final simulation: 2
# Time taken: 0.7084217071533203
# Idx *** 52
# [[0.3070173335792128, -1.058299956444803]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.32970875729147014
# Best robustness -0.0325612669713462
# Final simulation: 2
# Time taken: 0.7021424770355225
# Idx *** 53
# [[0.333911076504582, -1.0958492824760335]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.018751094768802035
# *********** Initial sample falsified ************
# Best robustness -0.003049175085332756
# Final simulation: 1
# Time taken: 0.0001926422119140625
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 53
# [[0.3032337008272275, -1.0918295064267287]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10493303310726575
# Best robustness -0.02343606271350357
# Final simulation: 2
# Time taken: 0.7636299133300781
# Idx *** 54
# [[0.3219737855520733, -1.073747514858756]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04748032875160688
# Best robustness -0.0026623118696594283
# Final simulation: 2
# Time taken: 0.8188996315002441
# Idx *** 55
# [[0.3224325491249262, -1.0654071275573747]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08228640962897882
# Best robustness -0.004552413558252477
# Final simulation: 2
# Time taken: 0.7926466464996338
# Idx *** 56
# [[0.3096582366321307, -1.0851064977027751]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09840809572595115
# Best robustness -0.0193319947858428
# Final simulation: 2
# Time taken: 0.5714178085327148
# Idx *** 57
# [[0.34165068799573733, -1.0596071512544918]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06238845347241849
# Best robustness -0.0046403949874037065
# Final simulation: 2
# Time taken: 0.5653917789459229
# Idx *** 58
# [[0.31059213503308286, -1.0739671939266786]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.031047470019552013
# *********** Initial sample falsified ************
# Best robustness -0.007810857316006892
# Final simulation: 1
# Time taken: 0.0002727508544921875
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 58
# [[0.32044214705967544, -1.0512742673619182]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.21248234565330118
# Best robustness -0.012956053337268514
# Final simulation: 2
# Time taken: 0.7072792053222656
# Idx *** 59
# [[0.3175933310882732, -1.0964765287602911]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06753640813799852
# Best robustness -0.017392060419779642
# Final simulation: 2
# Time taken: 1.0835926532745361
# Idx *** 60
# [[0.34138378891219123, -1.0657278388086215]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.14404124893061676
# Best robustness -0.01911190738957158
# Final simulation: 2
# Time taken: 0.6931097507476807
# Idx *** 61
# [[0.30480557339616615, -1.0776848542345945]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.45457582489903375
# Best robustness -0.03700675234710582
# Final simulation: 2
# Time taken: 0.6021413803100586
# Idx *** 62
# [[0.3432744049160959, -1.081280954937571]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07595314463112719
# Best robustness -0.004513376919450807
# Final simulation: 2
# Time taken: 0.5869574546813965
# Idx *** 63
# [[0.3006452471597737, -1.0886074239893182]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07477844575248403
# Best robustness -0.024575621841578132
# Final simulation: 2
# Time taken: 0.6874656677246094
# Idx *** 64
# [[0.33389271788445685, -1.0837303097093136]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11479604833880522
# Best robustness -0.02196483844455832
# Final simulation: 2
# Time taken: 0.5753564834594727
# Idx *** 65
# [[0.3461982724948085, -1.0509633898894426]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.14638932517232942
# Best robustness -0.005593998988896565
# Final simulation: 2
# Time taken: 0.7102928161621094
# Idx *** 66
# [[0.30385106658937727, -1.052014137072423]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.13202921076788124
# Best robustness -0.027710249524109054
# Final simulation: 2
# Time taken: 0.6625397205352783
# Idx *** 67
# [[0.3436776721719588, -1.0714780576798957]]
# 74
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08937002681401926
# Best robustness -0.0030007589119559475
# Final simulation: 2
# Time taken: 0.6087534427642822
# Idx *** 68
# [[0.34687996525763437, -1.0709457626362398]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.007608135985117352
# *********** Initial sample falsified ************
# Best robustness -0.008298645059502119
# Final simulation: 1
# Time taken: 0.0003795623779296875
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 68
# [[0.30123391980124087, -1.0913925654620118]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10916657377538336
# Best robustness -0.019945629412819077
# Final simulation: 2
# Time taken: 0.5504848957061768
# Idx *** 69
# [[0.3458977007522024, -1.0721490499899378]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.13400818925539776
# Best robustness -0.004292242030396132
# Final simulation: 2
# Time taken: 0.6339426040649414
# Idx *** 70
# [[0.32799511971996975, -1.0719149898721543]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.019209979756258884
# *********** Initial sample falsified ************
# Best robustness -0.003316376365299911
# Final simulation: 1
# Time taken: 0.00024509429931640625
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 70
# [[0.3347948185399607, -1.0827414759876195]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07219491947658067
# Best robustness -0.011654293778908753
# Final simulation: 2
# Time taken: 0.8139879703521729
# Idx *** 71
# [[0.3351802621490604, -1.0887871127329627]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.00528533618384827
# *********** Initial sample falsified ************
# Best robustness -0.01806201608245739
# Final simulation: 1
# Time taken: 0.00019407272338867188
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 71
# [[0.3377949706733367, -1.0998141880281016]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.020566942260733415
# *********** Initial sample falsified ************
# Best robustness -0.00012648719177243972
# Final simulation: 1
# Time taken: 0.00018548965454101562
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 71
# [[0.31532259035764737, -1.09980895106216]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10368432989627611
# Best robustness -0.021260099878947836
# Final simulation: 2
# Time taken: 0.5456142425537109
# Idx *** 72
# [[0.3107286649227269, -1.0833965120550468]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11665635679287764
# Best robustness -0.01073968268604697
# Final simulation: 2
# Time taken: 1.0029819011688232
# Idx *** 73
# [[0.34776999552407184, -1.0691120279812034]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.132018097175897
# Best robustness -0.008997575842559113
# Final simulation: 2
# Time taken: 0.9802734851837158
# Idx *** 74
# [[0.3205159153007773, -1.0682890709867199]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1870366127094146
# Best robustness -0.013596975687399537
# Final simulation: 2
# Time taken: 0.6964612007141113
# Idx *** 75
# [[0.3028515145702877, -1.083471168996459]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0693239345354567
# Best robustness -0.025592972142122417
# Final simulation: 2
# Time taken: 1.0442044734954834
# Idx *** 76
# [[0.34702057224894634, -1.0538308651127621]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.025711397366361122
# Best robustness -0.0005535972527632715
# Final simulation: 2
# Time taken: 0.6768178939819336
# Idx *** 77
# [[0.34118990831255736, -1.0907784375604095]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.4074873952868779
# Best robustness -0.03145527443357127
# Final simulation: 2
# Time taken: 0.6514987945556641
# Idx *** 78
# [[0.34959712954285643, -1.0827536921409489]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.03156732121408156
# *********** Initial sample falsified ************
# Best robustness -0.015230835674487075
# Final simulation: 1
# Time taken: 0.00025653839111328125
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 78
# [[0.3363791389357942, -1.0576976967095317]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04214133916987557
# Best robustness -0.0075522564478262555
# Final simulation: 2
# Time taken: 0.6667540073394775
# Idx *** 79
# [[0.33344579950153896, -1.0712869239320921]]
# 76
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08259479141953974
# Best robustness -0.008048099768179773
# Final simulation: 2
# Time taken: 0.9881570339202881
# Idx *** 80
# [[0.3484225015424026, -1.0584159007603013]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.01880422892256264
# Best robustness -6.145239787447299e-05
# Final simulation: 2
# Time taken: 0.7287702560424805
# Idx *** 81
# [[0.31436136653349966, -1.0679653216351614]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08339934546050576
# Best robustness -0.0028355263681237863
# Final simulation: 2
# Time taken: 0.6823341846466064
# Idx *** 82
# [[0.3215856230274698, -1.0930204764437816]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1299078924745278
# Best robustness -0.02206597281870154
# Final simulation: 2
# Time taken: 0.6342160701751709
# Idx *** 83
# [[0.3185981306997553, -1.0686455743675072]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.026180116994636904
# *********** Initial sample falsified ************
# Best robustness -0.003299351462921818
# Final simulation: 1
# Time taken: 0.0003104209899902344
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 83
# [[0.3018085154179445, -1.0544814275626626]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.3768452090004716
# Best robustness -0.033539409139693444
# Final simulation: 2
# Time taken: 0.76283860206604
# Idx *** 84
# [[0.3460563484814531, -1.0651589693070704]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08466455579214345
# Best robustness -0.0010137428842597607
# Final simulation: 2
# Time taken: 0.7347979545593262
# Idx *** 85
# [[0.33510772787274884, -1.050157435527813]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.133652260887263
# Best robustness -0.01006987091217848
# Final simulation: 3
# Time taken: 1.409869909286499
# Idx *** 86
# [[0.3250145078443491, -1.0660520644117384]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09369114506533668
# Best robustness -0.011596379788356925
# Final simulation: 3
# Time taken: 1.5953543186187744
# Idx *** 87
# [[0.30759548300423245, -1.0888056918976325]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12923499193737203
# Best robustness -0.00627677312823266
# Final simulation: 2
# Time taken: 0.8308899402618408
# Idx *** 88
# [[0.3419478995060996, -1.0592939518900413]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.059650339368691456
# Best robustness -0.0018665297122212876
# Final simulation: 2
# Time taken: 0.8023574352264404
# Idx *** 89
# [[0.3125984345561184, -1.071720443303761]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04839880911705508
# Best robustness -0.0005173752550922117
# Final simulation: 2
# Time taken: 0.7257130146026611
# Idx *** 90
# [[0.31204637216834474, -1.0828194812710619]]
# 74
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04020622634648693
# *********** Initial sample falsified ************
# Best robustness -0.004443477688171715
# Final simulation: 1
# Time taken: 0.00026345252990722656
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 90
# [[0.31398831625336543, -1.085463786650622]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.009021107642720226
# *********** Initial sample falsified ************
# Best robustness -0.01635154534237232
# Final simulation: 1
# Time taken: 0.0002346038818359375
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 90
# [[0.31932921085384786, -1.0593042641400974]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.17945842814304114
# Best robustness -0.020264621737217214
# Final simulation: 2
# Time taken: 0.594135046005249
# Idx *** 91
# [[0.30669790441242223, -1.061232935992317]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07260051963982642
# Best robustness -0.013284186772968776
# Final simulation: 2
# Time taken: 0.6200854778289795
# Idx *** 92
# [[0.3052991335265429, -1.0608769477231232]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.27105683410248166
# Best robustness -0.032797842442679914
# Final simulation: 2
# Time taken: 0.9114720821380615
# Idx *** 93
# [[0.34321071547489584, -1.0811088183957136]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02050101867671016
# *********** Initial sample falsified ************
# Best robustness -0.019130991704353395
# Final simulation: 1
# Time taken: 0.00035643577575683594
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 93
# [[0.3413560039639438, -1.069039286890299]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07713629202868674
# Best robustness -0.009547288105186513
# Final simulation: 2
# Time taken: 0.6850061416625977
# Idx *** 94
# [[0.34385442450235604, -1.062805739388629]]
# 78
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07340508482776868
# Best robustness -0.0030206557080139085
# Final simulation: 3
# Time taken: 1.4401450157165527
# Idx *** 95
# [[0.3011667581649532, -1.0965043726914796]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12903415399988868
# Best robustness -0.006528934662031305
# Final simulation: 2
# Time taken: 0.6193890571594238
# Idx *** 96
# [[0.3113685792680869, -1.053591037151503]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12965988875529683
# Best robustness -0.020266057923273684
# Final simulation: 2
# Time taken: 0.631657600402832
# Idx *** 97
# [[0.3119423133383785, -1.069187544802951]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ...
# Starting distance: 0.05428971569994871
# Best robustness -0.0058089428667067455
# Final simulation: 2
# Time taken: 0.48328137397766113
# Idx *** 464
# [[0.31996768266465536, -1.0933128747541805]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12021326973745475
# Best robustness -0.0295730788166349
# Final simulation: 2
# Time taken: 0.4758107662200928
# Idx *** 465
# [[0.30284426210325044, -1.0648521233509778]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06178800227056448
# Best robustness -0.023769099538372973
# Final simulation: 2
# Time taken: 0.4860970973968506
# Idx *** 466
# [[0.3059714499028866, -1.08406519186499]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.027307436327266572
# *********** Initial sample falsified ************
# Best robustness -0.0005674628800613202
# Final simulation: 1
# Time taken: 0.00021910667419433594
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 466
# [[0.3041589375702818, -1.0776691231862858]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2335864958701184
# Best robustness -0.018010667295889016
# Final simulation: 2
# Time taken: 0.4823622703552246
# Idx *** 467
# [[0.34365031579553135, -1.0845500628402307]]
# 75
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08629318698860163
# Best robustness -0.008937809968878108
# Final simulation: 2
# Time taken: 0.47003889083862305
# Idx *** 468
# [[0.31566745181152583, -1.074998424361828]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12045553998751195
# Best robustness -0.025568267868119
# Final simulation: 2
# Time taken: 0.5028824806213379
# Idx *** 469
# [[0.33267817537348116, -1.0988388610560096]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10625830539899027
# Best robustness -0.02871217778051266
# Final simulation: 2
# Time taken: 0.4673900604248047
# Idx *** 470
# [[0.3351299379201371, -1.0599593377601257]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09727604784983324
# Best robustness -0.0028565890249502845
# Final simulation: 2
# Time taken: 0.44043493270874023
# Idx *** 471
# [[0.32605412977685133, -1.0518327441176571]]
# 73
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.022695271845868246
# Best robustness -0.0008245286562594267
# Final simulation: 2
# Time taken: 0.46587252616882324
# Idx *** 472
# [[0.3417386754589064, -1.0994558928724372]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.14699880163488577
# Best robustness -0.0206318077342601
# Final simulation: 2
# Time taken: 0.46107935905456543
# Idx *** 473
# [[0.3367927870733831, -1.0543974396855147]]
# 76
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.011320587482967878
# *********** Initial sample falsified ************
# Best robustness -0.0011285284815629182
# Final simulation: 1
# Time taken: 0.0001506805419921875
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 473
# [[0.3040312773903796, -1.0539909045872349]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20955282328615302
# Best robustness -0.02284888564942361
# Final simulation: 2
# Time taken: 0.47565412521362305
# Idx *** 474
# [[0.3225472253273467, -1.0798406190764307]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06118790253179251
# Best robustness -0.004354491678413064
# Final simulation: 2
# Time taken: 0.48280858993530273
# Idx *** 475
# [[0.31986345515055026, -1.0896924875557077]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.34671866515858296
# Best robustness -0.035887174305042624
# Final simulation: 2
# Time taken: 0.4636993408203125
# Idx *** 476
# [[0.3099525608018157, -1.0840623048780862]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1715469164456245
# Best robustness -0.01659360292555262
# Final simulation: 2
# Time taken: 0.46267056465148926
# Idx *** 477
# [[0.30707257159939844, -1.078126685470368]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.23288445074796488
# Best robustness -0.019677369917352416
# Final simulation: 2
# Time taken: 0.5046131610870361
# Idx *** 478
# [[0.33792344033500443, -1.094451903286761]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09784525586417203
# Best robustness -0.0053532088805774425
# Final simulation: 2
# Time taken: 0.448108434677124
# Idx *** 479
# [[0.3431398625376771, -1.0751343341117392]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.03512468140464357
# Best robustness -0.003404851152633781
# Final simulation: 2
# Time taken: 0.46311521530151367
# Idx *** 480
# [[0.3312706010914272, -1.095896035566317]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.21921267610266587
# Best robustness -0.012535705495526794
# Final simulation: 2
# Time taken: 0.4969611167907715
# Idx *** 481
# [[0.3233684575328757, -1.0780550639903714]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02619161649230782
# *********** Initial sample falsified ************
# Best robustness -0.008246064192993119
# Final simulation: 1
# Time taken: 0.00018477439880371094
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 481
# [[0.3300744187148876, -1.0642138981529468]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09227347499899209
# Best robustness -0.020612958420672567
# Final simulation: 2
# Time taken: 0.5147802829742432
# Idx *** 482
# [[0.3319875977245806, -1.0957892891286911]]
# 77
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0012217794941446957
# *********** Initial sample falsified ************
# Best robustness -0.019134630903970273
# Final simulation: 1
# Time taken: 0.000194549560546875
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 482
# [[0.30600167714910903, -1.0800139279339098]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20715100855340549
# Best robustness -0.028673364309041938
# Final simulation: 2
# Time taken: 0.4747581481933594
# Idx *** 483
# [[0.32798049639040333, -1.0685130157330367]]
# 74
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.014903218817025138
# *********** Initial sample falsified ************
# Best robustness -0.0008240694741433185
# Final simulation: 1
# Time taken: 0.0005199909210205078
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 483
# [[0.3070200532044871, -1.0987540691262072]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.051333997570720366
# *********** Initial sample falsified ************
# Best robustness -0.009339781727062735
# Final simulation: 1
# Time taken: 0.0001747608184814453
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 483
# [[0.31126109766969146, -1.0978968296212694]]
# 76
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07565734465371521
# Best robustness -0.02318452584939973
# Final simulation: 2
# Time taken: 0.46475744247436523
# Idx *** 484
# [[0.3429840461073304, -1.099303929460889]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10465102688872724
# Best robustness -0.017049554497502062
# Final simulation: 2
# Time taken: 0.478574275970459
# Idx *** 485
# [[0.3148454666957504, -1.0879812021119144]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.3972384356517595
# Best robustness -0.02616616205534661
# Final simulation: 2
# Time taken: 0.47397851943969727
# Idx *** 486
# [[0.3352946794022949, -1.093234209302399]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.3294504490013947
# Best robustness -0.021984176431362357
# Final simulation: 2
# Time taken: 0.4963045120239258
# Idx *** 487
# [[0.3402031027623231, -1.0824683871807927]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20103252323196016
# Best robustness -0.017082896079440024
# Final simulation: 2
# Time taken: 0.4553842544555664
# Idx *** 488
# [[0.3162331990306604, -1.0623611214406483]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2614600621133093
# Best robustness -0.03324437994313684
# Final simulation: 2
# Time taken: 0.44989919662475586
# Idx *** 489
# [[0.30964138820902304, -1.0917573163540446]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11663415231537917
# Best robustness -0.02675143630728183
# Final simulation: 2
# Time taken: 0.4624948501586914
# Idx *** 490
# [[0.33394954005674793, -1.0757496299988265]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09526842793352633
# Best robustness -0.024643675086211958
# Final simulation: 2
# Time taken: 0.4590013027191162
# Idx *** 491
# [[0.3342399625496782, -1.0717791292713779]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20895514648228042
# Best robustness -0.026153569360899742
# Final simulation: 2
# Time taken: 0.5130133628845215
# Idx *** 492
# [[0.3395911733078102, -1.0595300692657066]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0034402422833750765
# *********** Initial sample falsified ************
# Best robustness -0.0022619949567285746
# Final simulation: 1
# Time taken: 0.0003905296325683594
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 492
# [[0.34726653674253244, -1.0594786668790501]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07239008568126361
# Best robustness -0.0005479959753526553
# Final simulation: 2
# Time taken: 0.4645562171936035
# Idx *** 493
# [[0.33010243557793095, -1.0861030898055752]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.41193683080515325
# Best robustness -0.028383757082413863
# Final simulation: 2
# Time taken: 0.4811265468597412
# Idx *** 494
# [[0.3288937851231469, -1.0629849483731955]]
# 72
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0070064928970884136
# *********** Initial sample falsified ************
# Best robustness -0.00819727108887125
# Final simulation: 1
# Time taken: 0.00015211105346679688
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 494
# [[0.324211382913818, -1.090089547518228]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09359567101162101
# Best robustness -0.024182629177681936
# Final simulation: 2
# Time taken: 0.4880795478820801
# Idx *** 495
# [[0.3018809928073291, -1.0903707698534235]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.30815695863123177
# Best robustness -0.03280665114305503
# Final simulation: 2
# Time taken: 0.47542738914489746
# Idx *** 496
# [[0.31609235341546993, -1.064398138765881]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20365213919841926
# Best robustness -0.021332759547255775
# Final simulation: 2
# Time taken: 0.4713432788848877
# Idx *** 497
# [[0.30153642763741834, -1.0784170624341745]]
# 79
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07451706068084127
# Best robustness -0.02235493023895513
# Final simulation: 2
# Time taken: 0.5052871704101562
# Idx *** 498
# [[0.3171385801795825, -1.0699606792170167]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.22077894329075767
# Best robustness -0.023574099375027247
# Final simulation: 2
# Time taken: 0.4868924617767334
# Idx *** 499
# [[0.3362768932223797, -1.0563089980318223]]
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.4184020766832591
# Best robustness -0.029070372539091338
# Final simulation: 2
# Time taken: 0.47629570960998535
# 2.096
# -0.01678113866301383
# 6.0
# 0.230784

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen_nongr import EvaluationInvSenNonGr

evalObject = EvaluationInvSenNonGr(dynamics='OtherBenchC2')

evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()
dataObject.setSteps(150)

dataObject.setLowerBound([0.8, 0.9])
dataObject.setUpperBound([1.2, 1.2])
lowerBound = [1.5, 0.2]
upperBound = [1.55, 0.25]
evalObject.setUnsafeSet(lowerBound, upperBound)
dest_traj = dataObject.generateTrajectories(samples=1)[0]
time_steps = [75, 95]

max_iter = 100
f_simulations = np.zeros(max_iter)
min_dists = np.zeros(max_iter)
idx = 0
while idx < max_iter:
    print("Idx *** " + str(idx))
    ref_traj = dataObject.generateTrajectories(samples=1)[0]
    dest = evalObject.generateRandomUnsafeStates(1)
    dests = dest
    print(dests)
    evalObject.reachDestInvSen(dests=dests, d_time_steps=time_steps, threshold=0.0, correction_steps=[10],
                            scaling_factors=[0.1], i_state=[ref_traj[0]])
    f_sims = evalObject.getFSimulations()
    min_dist = evalObject.getFDistance()
    rel_dist = evalObject.getFRelDistance()
    if f_sims > 1 and rel_dist < 1.0:
        f_simulations[idx] = f_sims
        min_dists[idx] = min_dist
        idx = idx + 1
    else:
        print("** either f_iter is 1 or rel_dist is 1.0 **")
# print(f_iterations, min_rel_dists)
print(np.sum(f_simulations)/max_iter)
print(np.sum(min_dists)/max_iter)
print(np.max(f_simulations))
print(np.var(f_simulations))
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# Idx *** 0
# [[1.5207542792570503, 0.24668084021049466]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09247749038423124
# Best robustness -0.0070689883686553545
# Final simulation: 5
# Time taken: 3.307803153991699
# Idx *** 1
# [[1.5090225206174048, 0.20024226184883384]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.19032876405787846
# Best robustness -0.04555967366022193
# Final simulation: 8
# Time taken: 5.7361671924591064
# Idx *** 2
# [[1.5031916761763637, 0.21039209832319922]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.13027491045821799
# Best robustness -0.010636292594983277
# Final simulation: 3
# Time taken: 1.6740152835845947
# Idx *** 3
# [[1.5290687429596823, 0.21470869352178312]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.15551224939638808
# Best robustness -0.031214929172795586
# Final simulation: 5
# Time taken: 3.1179730892181396
# Idx *** 4
# [[1.518776066901859, 0.2455895202674845]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.273849899211834
# /home/manishg/Research/NExG/core/evaluation_isen_nongr.py:376: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Best robustness -0.006993461495358622
# Final simulation: 4
# Time taken: 2.5316226482391357
# Idx *** 5
# [[1.5121431017301794, 0.23041232134295064]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02512091942607433
# *********** Initial sample falsified ************
# Best robustness -0.001255267533498361
# Final simulation: 1
# Time taken: 0.00019407272338867188
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 5
# [[1.5105823714920124, 0.2457464399083255]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.029472540923222587
# Best robustness -0.018787598204655614
# Final simulation: 3
# Time taken: 1.7508347034454346
# Idx *** 6
# [[1.5118354395479374, 0.24061156238030273]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1485286659079316
# Best robustness -0.0076909557044277654
# Final simulation: 7
# Time taken: 4.7311766147613525
# Idx *** 7
# [[1.527566185847235, 0.2359955472939063]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.18015900468831872
# Best robustness -0.008050615393895427
# Final simulation: 6
# Time taken: 3.950749397277832
# Idx *** 8
# [[1.5271834619601123, 0.23347328541706117]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1841993160471275
# Best robustness -0.010743668643499349
# Final simulation: 6
# Time taken: 3.9365270137786865
# Idx *** 9
# [[1.5453525375934622, 0.2346076402708826]]
# 84
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.037158935891157034
# Best robustness -0.0024644997134183333
# Final simulation: 4
# Time taken: 2.3428194522857666
# Idx *** 10
# [[1.5337631677030032, 0.20306977337262913]]
# 94
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.17729076059027596
# Best robustness -0.005196752898569662
# Final simulation: 6
# Time taken: 3.9915683269500732
# Idx *** 11
# [[1.534723928026704, 0.22620829546770088]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.13078693337537006
# Best robustness -0.005594699267284675
# Final simulation: 5
# Time taken: 3.0409393310546875
# Idx *** 12
# [[1.524250173661445, 0.2081170066605876]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.02705198328198673
# Best robustness -0.011013265263612848
# Final simulation: 2
# Time taken: 0.860499382019043
# Idx *** 13
# [[1.518366164936722, 0.23969985380687042]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04807485986746394
# Best robustness -0.03251343067438364
# Final simulation: 3
# Time taken: 1.5416970252990723
# Idx *** 14
# [[1.5104474811803774, 0.22146056716877072]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.009544061827002159
# *********** Initial sample falsified ************
# Best robustness -0.012399872593199801
# Final simulation: 1
# Time taken: 0.00033283233642578125
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 14
# [[1.5064144942331814, 0.24617967291649584]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.05835642569324956
# Best robustness -0.04162091379108093
# Final simulation: 5
# Time taken: 3.087122917175293
# Idx *** 15
# [[1.5478097849534505, 0.20255002832357322]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12092129993104717
# Best robustness -0.003940419150685548
# Final simulation: 5
# Time taken: 3.1350595951080322
# Idx *** 16
# [[1.5017544006569103, 0.23951979364063136]]
# 83
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07942577553711073
# Best robustness -0.0045805927219575715
# Final simulation: 2
# Time taken: 0.7566623687744141
# Idx *** 17
# [[1.533728493129796, 0.21562291835552458]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06623236493719704
# Best robustness -0.01099192628423648
# Final simulation: 3
# Time taken: 1.5214428901672363
# Idx *** 18
# [[1.5311098208037588, 0.2345638366849503]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.05535977145185576
# Best robustness -0.04835728858050792
# Final simulation: 2
# Time taken: 0.8660683631896973
# Idx *** 19
# [[1.514407487438425, 0.21167740447057307]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20547274526826517
# Best robustness -0.004182103361992123
# Final simulation: 3
# Time taken: 1.5569052696228027
# Idx *** 20
# [[1.5336163433552354, 0.23871760500716543]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12491361372666479
# Best robustness -0.004643253143650911
# Final simulation: 4
# Time taken: 2.6503829956054688
# Idx *** 21
# [[1.5103458216852002, 0.2130314558060241]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08178546352016282
# Best robustness -0.0064891683218637475
# Final simulation: 2
# Time taken: 0.8302426338195801
# Idx *** 22
# [[1.515391205545626, 0.20037199085701637]]
# 93
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07066400354846286
# Best robustness -0.0489790644674184
# Final simulation: 5
# Time taken: 2.950690746307373
# Idx *** 23
# [[1.5250040211113152, 0.24041878717350307]]
# 86
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.008555045499913906
# *********** Initial sample falsified ************
# Best robustness -0.012398198392914533
# Final simulation: 1
# Time taken: 0.00018024444580078125
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 23
# [[1.5224555339429913, 0.23340233014944428]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.29685092271655583
# Best robustness -0.008005739568514025
# Final simulation: 4
# Time taken: 2.3136720657348633
# Idx *** 24
# [[1.5027502713736567, 0.2068741044463581]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.05837008026505376
# Best robustness -0.04645395189531329
# Final simulation: 8
# Time taken: 5.134875297546387
# Idx *** 25
# [[1.524341841798513, 0.23443306008682474]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10276102622395601
# Best robustness -0.04765655208695985
# Final simulation: 4
# Time taken: 2.2447352409362793
# Idx *** 26
# [[1.538257160231733, 0.2063005578741864]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.046324244341571646
# Best robustness -0.011612555223840804
# Final simulation: 2
# Time taken: 0.7638201713562012
# Idx *** 27
# [[1.526538607464225, 0.2261785096345796]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2001772942886865
# Best robustness -0.02274813168490175
# Final simulation: 6
# Time taken: 3.874452829360962
# Idx *** 28
# [[1.535948013906396, 0.22029577120510546]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.15774075890442427
# Best robustness -0.005370971369094146
# Final simulation: 4
# Time taken: 2.339643716812134
# Idx *** 29
# [[1.5381330026251483, 0.2014660895287744]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.031494371808651285
# Best robustness -0.003463181964866724
# Final simulation: 2
# Time taken: 0.8464875221252441
# Idx *** 30
# [[1.5021344595254995, 0.2418102863758719]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04169276752003357
# Best robustness -0.0417514313493515
# Final simulation: 5
# Time taken: 3.084275245666504
# Idx *** 31
# [[1.5058564675209927, 0.2330303123218059]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.24117149265350663
# Best robustness -0.0008136285916287012
# Final simulation: 3
# Time taken: 1.5586519241333008
# Idx *** 32
# [[1.5132873987444388, 0.24793387609478396]]
# 86
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10403531832068874
# Best robustness -0.0124526001327869
# Final simulation: 3
# Time taken: 1.6487085819244385
# Idx *** 33
# [[1.5368547959990557, 0.2031399288890637]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.060883500235333246
# Best robustness -0.00811307224060731
# Final simulation: 3
# Time taken: 1.7204713821411133
# Idx *** 34
# [[1.5361282203176545, 0.22676841901440442]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.19168749346441277
# Best robustness -0.010982985618774033
# Final simulation: 5
# Time taken: 3.0862293243408203
# Idx *** 35
# [[1.53318056155014, 0.2477331951691632]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.005498214208433603
# *********** Initial sample falsified ************
# Best robustness -0.0015087528795773575
# Final simulation: 1
# Time taken: 0.0005140304565429688
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 35
# [[1.509457567223698, 0.22645942671206162]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.18603742718290214
# Best robustness -0.004436548172861349
# Final simulation: 3
# Time taken: 1.5763466358184814
# Idx *** 36
# [[1.5152087857050787, 0.2034703803268593]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09352065520219711
# Best robustness -0.009678129875166475
# Final simulation: 3
# Time taken: 1.5305507183074951
# Idx *** 37
# [[1.5434636497535192, 0.22477704682427704]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.13016981151848533
# Best robustness -0.0006291492342850313
# Final simulation: 5
# Time taken: 2.918567419052124
# Idx *** 38
# [[1.508739654960312, 0.23850697775455101]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.023675382209905234
# Best robustness -0.01262356896682118
# Final simulation: 3
# Time taken: 1.5258982181549072
# Idx *** 39
# [[1.5036365764396458, 0.20344955337095302]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.017836419578078935
# Best robustness -0.0492613568109459
# Final simulation: 5
# Time taken: 3.0966949462890625
# Idx *** 40
# [[1.54072579793004, 0.24496969481148878]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.15826537942046817
# Best robustness -0.003179482410165857
# Final simulation: 5
# Time taken: 3.144014358520508
# Idx *** 41
# [[1.5177736931953185, 0.21539964026939143]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06478903381763094
# Best robustness -0.04707614606962454
# Final simulation: 4
# Time taken: 2.248023748397827
# Idx *** 42
# [[1.5403195866405666, 0.20069499299498242]]
# 93
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.21591590329378163
# Best robustness -0.0008183313968967987
# Final simulation: 4
# Time taken: 2.485123634338379
# Idx *** 43
# [[1.5025407660096104, 0.22502930042356376]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10949705492687878
# Best robustness -0.043365799291662704
# Final simulation: 8
# Time taken: 5.245318174362183
# Idx *** 44
# [[1.548306047222308, 0.22653778672934974]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.20774536180831907
# Best robustness -0.0034807579104065567
# Final simulation: 5
# Time taken: 3.0207855701446533
# Idx *** 45
# [[1.528031020325684, 0.23830654689404687]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.28162821306954117
# Best robustness -0.001413295065435638
# Final simulation: 4
# Time taken: 2.21014666557312
# Idx *** 46
# [[1.5108802272146378, 0.20312076526951975]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07684507735975789
# Best robustness -0.004020918827047443
# Final simulation: 2
# Time taken: 0.7304666042327881
# Idx *** 47
# [[1.5000643561639726, 0.2037878962481766]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.03473326189728795
# *********** Initial sample falsified ************
# Best robustness -0.003940404773402628
# Final simulation: 1
# Time taken: 0.00032067298889160156
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 47
# [[1.5049763718511333, 0.21083327031679855]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08383188318941695
# Best robustness -0.045005288805858856
# Final simulation: 7
# Time taken: 4.23917293548584
# Idx *** 48
# [[1.521098907496055, 0.22106148844659243]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.18499899302069295
# Best robustness -0.0019028658350304095
# Final simulation: 3
# Time taken: 1.385915994644165
# Idx *** 49
# [[1.513944822639761, 0.2147138841431558]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.016441771666794808
# Best robustness -0.02282245280649875
# Final simulation: 2
# Time taken: 0.806342601776123
# Idx *** 50
# [[1.5479374841236158, 0.20270742659643412]]
# 94
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.3002348406348381
# Best robustness -0.0009635724628535292
# Final simulation: 5
# Time taken: 3.159982442855835
# Idx *** 51
# [[1.5081636776347551, 0.24538448137806562]]
# 86
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.021623740713336725
# *********** Initial sample falsified ************
# Best robustness -0.00350327713783094
# Final simulation: 1
# Time taken: 0.0001971721649169922
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 51
# [[1.5257555362679496, 0.20490376158995768]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06660138184066011
# Best robustness -0.017061476607966447
# Final simulation: 4
# Time taken: 2.2199344635009766
# Idx *** 52
# [[1.517581717893145, 0.2162470715779081]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2528430960678089
# Best robustness -0.009577522467298427
# Final simulation: 4
# Time taken: 2.253530263900757
# Idx *** 53
# [[1.5464900785866271, 0.24287634625747462]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.24058969554487677
# Best robustness -0.0012679540281448354
# Final simulation: 7
# Time taken: 4.434772491455078
# Idx *** 54
# [[1.5385083419621266, 0.21917447120823086]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04642598155991173
# Best robustness -0.008332165850687662
# Final simulation: 2
# Time taken: 0.7698626518249512
# Idx *** 55
# [[1.5353485040646464, 0.208348469951361]]
# 94
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2890982582241154
# Best robustness -0.0004878825192354552
# Final simulation: 4
# Time taken: 2.3368091583251953
# Idx *** 56
# [[1.5371629853111837, 0.22206056057352644]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06571306493219835
# Best robustness -0.004602399070919833
# Final simulation: 3
# Time taken: 1.597280502319336
# Idx *** 57
# [[1.512344940534397, 0.20700309372214132]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06932490978001196
# Best robustness -0.023257732438343864
# Final simulation: 6
# Time taken: 3.797842502593994
# Idx *** 58
# [[1.5173661142411716, 0.22895857977153067]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11548440553027896
# Best robustness -0.007051103499133543
# Final simulation: 6
# Time taken: 3.6041297912597656
# Idx *** 59
# [[1.500100005117113, 0.21177782820441649]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.01143027886309079
# Best robustness -0.0383376213061806
# Final simulation: 12
# Time taken: 8.297989845275879
# Idx *** 60
# [[1.5424836753929156, 0.23796348402823134]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.10173961357191781
# Best robustness -0.0011630255464059047
# Final simulation: 4
# Time taken: 2.355299472808838
# Idx *** 61
# [[1.505949985771232, 0.20086181632586173]]
# 94
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.2752454848966977
# Best robustness -0.0018407094714694705
# Final simulation: 3
# Time taken: 1.523172378540039
# Idx *** 62
# [[1.5061614429845274, 0.22057265965229814]]
# 85
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.09963060597464611
# Best robustness -0.003563520793670394
# Final simulation: 2
# Time taken: 0.7767424583435059
# Idx *** 63
# [[1.5182229998689836, 0.22100883981772468]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.11008850195599078
# Best robustness -0.04723264358266749
# Final simulation: 5
# Time taken: 2.8849737644195557
# Idx *** 64
# [[1.5355773197105962, 0.24218305347644592]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.22680421876432338
# Best robustness -0.010608164477503568
# Final simulation: 6
# Time taken: 3.644841432571411
# Idx *** 65
# [[1.5027254979447762, 0.2466026732091809]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07250703416995613
# Best robustness -0.024002916817884606
# Final simulation: 7
# Time taken: 4.561599254608154
# Idx *** 66
# [[1.513690482762406, 0.23610001491278554]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12317593641861439
# Best robustness -0.04700847875901182
# Final simulation: 6
# Time taken: 3.6980321407318115
# Idx *** 67
# [[1.53699871354889, 0.24372501097581992]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.04146101384071116
# Best robustness -0.002313084154421219
# Final simulation: 3
# Time taken: 1.5040009021759033
# Idx *** 68
# [[1.5104139273051294, 0.20023641457761604]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.005107157916234544
# *********** Initial sample falsified ************
# Best robustness -0.012954932610510866
# Final simulation: 1
# Time taken: 0.0003292560577392578
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 68
# [[1.543927410991472, 0.21790945541622952]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.21020475233249616
# Best robustness -0.0018308968793669944
# Final simulation: 5
# Time taken: 3.0679702758789062
# Idx *** 69
# [[1.5294825445770015, 0.2398296762800966]]
# 90
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1929138870551191
# Best robustness -0.0068527982697779155
# Final simulation: 4
# Time taken: 2.3239099979400635
# Idx *** 70
# [[1.5362946783405889, 0.223395624120706]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06136054610183893
# Best robustness -2.797408953647551e-06
# Final simulation: 3
# Time taken: 1.494105577468872
# Idx *** 71
# [[1.527541524997608, 0.22057490518280967]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.00817242536012348
# *********** Initial sample falsified ************
# Best robustness -0.008895477646850114
# Final simulation: 1
# Time taken: 0.00018453598022460938
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 71
# [[1.5323052775583708, 0.23281471908697435]]
# 85
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.21281472265729806
# Best robustness -0.005322987551106634
# Final simulation: 5
# Time taken: 2.892416000366211
# Idx *** 72
# [[1.5147799525363252, 0.23112031293806787]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12584170486349833
# Best robustness -0.006740745853795194
# Final simulation: 3
# Time taken: 1.581441879272461
# Idx *** 73
# [[1.5179499640530054, 0.23168761578251115]]
# 85
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.19183637961982297
# Best robustness -0.011419809413739435
# Final simulation: 4
# Time taken: 2.302016496658325
# Idx *** 74
# [[1.501061468865308, 0.23040501236164931]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0516678392992035
# Best robustness -0.005214472280617777
# Final simulation: 2
# Time taken: 0.7185540199279785
# Idx *** 75
# [[1.5470333038467385, 0.21409209159806583]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.23100386884149327
# Best robustness -0.013416800604618945
# Final simulation: 5
# Time taken: 2.8308956623077393
# Idx *** 76
# [[1.527719946894966, 0.23732585679741292]]
# 85
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.010478778478655991
# *********** Initial sample falsified ************
# Best robustness -0.00580389406500223
# Final simulation: 1
# Time taken: 0.00028586387634277344
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 76
# [[1.5397031101714262, 0.24534319258017326]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08376609847133781
# Best robustness -0.003380514706072979
# Final simulation: 3
# Time taken: 1.5204315185546875
# Idx *** 77
# [[1.5322420577503437, 0.2489535709845906]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.03871696545254167
# *********** Initial sample falsified ************
# Best robustness -0.04908947749855197
# Final simulation: 1
# Time taken: 0.000171661376953125
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 77
# [[1.5387041393732428, 0.21408746534973316]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1333758723361108
# Best robustness -0.03497422580329157
# Final simulation: 4
# Time taken: 2.204705238342285
# Idx *** 78
# [[1.5367017711732827, 0.24245538034602654]]
# 86
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.023078644798767495
# Best robustness -0.0018666081802685142
# Final simulation: 2
# Time taken: 0.8646388053894043
# Idx *** 79
# [[1.5459664899177743, 0.21744921497169598]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07863012575379336
# Best robustness -0.001094310627148154
# Final simulation: 4
# Time taken: 2.2513017654418945
# Idx *** 80
# [[1.5244656368233012, 0.23310421255139124]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1056556761458092
# Best robustness -0.007673666269462087
# Final simulation: 3
# Time taken: 1.5435619354248047
# Idx *** 81
# [[1.5219393359227589, 0.20574343262356923]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1443520294200811
# Best robustness -0.02137961927407689
# Final simulation: 6
# Time taken: 3.8425838947296143
# Idx *** 82
# [[1.5256077191704613, 0.20702665659744696]]
# 92
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.009885653737799045
# *********** Initial sample falsified ************
# Best robustness -0.005197284072185865
# Final simulation: 1
# Time taken: 0.0003437995910644531
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 82
# [[1.5222007314731905, 0.24157296565448613]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.053337684116492146
# Best robustness -0.003798035257989607
# Final simulation: 2
# Time taken: 0.7950983047485352
# Idx *** 83
# [[1.5207006449230893, 0.2168098858296314]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.049910079785610635
# Best robustness -0.03919668962754158
# Final simulation: 3
# Time taken: 1.4818167686462402
# Idx *** 84
# [[1.5377349863849554, 0.2324135396950123]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.025762155367708837
# *********** Initial sample falsified ************
# Best robustness -0.0016594309017728126
# Final simulation: 1
# Time taken: 0.0003345012664794922
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 84
# [[1.5033984982652544, 0.23421356524392778]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.06676540253859892
# Best robustness -0.007867019350997095
# Final simulation: 2
# Time taken: 0.7315542697906494
# Idx *** 85
# [[1.5360140648459095, 0.24742974186108008]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.149218265743323
# Best robustness -0.001730160277494175
# Final simulation: 4
# Time taken: 2.3485820293426514
# Idx *** 86
# [[1.5471582000841344, 0.21395932986163235]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.17912567677266739
# Best robustness -0.0002408972301572998
# Final simulation: 5
# Time taken: 3.0130932331085205
# Idx *** 87
# [[1.5159207604052525, 0.22992601421404943]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.23656965189759965
# Best robustness -0.0003350321377029175
# Final simulation: 3
# Time taken: 1.4373373985290527
# Idx *** 88
# [[1.519731234625964, 0.22099129432390766]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08742286707024033
# Best robustness -0.008343131092608619
# Final simulation: 3
# Time taken: 1.5099599361419678
# Idx *** 89
# [[1.5304052246620468, 0.2029332241036496]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.034955560445043436
# Best robustness -0.008666873924273677
# Final simulation: 2
# Time taken: 0.7696857452392578
# Idx *** 90
# [[1.5400546610488801, 0.2241553485612541]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.1591445309591937
# Best robustness -0.007281249424503783
# Final simulation: 5
# Time taken: 2.919609785079956
# Idx *** 91
# [[1.5133610467672758, 0.2069006643281973]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.027342956301605385
# Best robustness -0.038113001824223475
# Final simulation: 3
# Time taken: 1.4276049137115479
# Idx *** 92
# [[1.5146152010528098, 0.22216157689101526]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.12632929628109613
# Best robustness -0.04466492455136031
# Final simulation: 6
# Time taken: 3.8413543701171875
# Idx *** 93
# [[1.500910786628145, 0.22983704211352873]]
# 84
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.006022106977792396
# Best robustness -0.03161797083185025
# Final simulation: 2
# Time taken: 0.7531981468200684
# Idx *** 94
# [[1.502619914393983, 0.21707380223146272]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07211572030075628
# Best robustness -0.03545705479068978
# Final simulation: 9
# Time taken: 6.034327507019043
# Idx *** 95
# [[1.5075869482287985, 0.218549528850318]]
# 87
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.24275570320954137
# Best robustness -0.0004117788932022637
# Final simulation: 3
# Time taken: 1.5358192920684814
# Idx *** 96
# [[1.5054561974696532, 0.20433931024497853]]
# 93
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.15087763746450708
# Best robustness 0.0063733280389682845
# Final simulation: 51
# Time taken: 37.93312120437622
# Idx *** 97
# [[1.523067867062643, 0.20376305769754902]]
# 88
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.07666661297850352
# Best robustness -0.012910897423442674
# Final simulation: 3
# Time taken: 1.4326927661895752
# Idx *** 98
# [[1.5439332178763654, 0.21333565674823782]]
# 91
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.0083211970029997
# *********** Initial sample falsified ************
# Best robustness -0.012218139403510853
# Final simulation: 1
# Time taken: 0.0001742839813232422
# ** either f_iter is 1 or rel_dist is 1.0 **
# Idx *** 98
# [[1.5449660539971832, 0.21830817460659904]]
# 86
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.08966230147191967
# Best robustness -0.0010388471152960044
# Final simulation: 4
# Time taken: 2.1903483867645264
# Idx *** 99
# [[1.5480511999875728, 0.22098093063326213]]
# 89
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 s_factor 0.1 correction steps 10
# Starting distance: 0.03556030822858276
# Best robustness -0.002981220855439365
# Final simulation: 4
# Time taken: 2.341475009918213
# 4.66
# -0.014545761376304023
# 51.0
# 24.8644
