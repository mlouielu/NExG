# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen_nongr import EvaluationInvSenNonGr

evalObject = EvaluationInvSenNonGr(dynamics='OtherBenchC1')

evalObject.setSimsBound(50)
dataObject = evalObject.setDataObject()

evalObject.coverage(d_time_steps=[53], partitions=7)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/dconfigs_inv/d_object_OtherBenchC1.txt
# 148
#  **** idx **** 0
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.33225161 -0.8716561 ] [ 0.35273929 -0.88558466]
# Starting distance: 0.024773974420941147
# Final distance 0.02756597503041785
# Final relative distance 1.1126989380887007
# Min relative distance 1.1126989380887007
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02756597503041785
# 50
# Time taken: 3.140796422958374
#  **** idx **** 1
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.33353759 -0.87733451] [ 0.33225161 -0.8716561 ]
# Starting distance: 0.005822204749446743
# Final distance 0.026705367487564642
# Final relative distance 4.586813524567704
# Min relative distance 4.586813524567704
# Min simulation: 50
# Final simulation: 50
# Min distance 0.026705367487564642
# 50
# Time taken: 3.4078123569488525
#  **** idx **** 2
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.33179453 -0.8119128 ] [ 0.33353759 -0.87733451]
# Starting distance: 0.06544492415324593
# Final distance 0.02303422155028576
# Final relative distance 0.35196345397771095
# Min relative distance 0.35196345397771095
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02303422155028576
# 50
# Time taken: 3.6227962970733643
#  **** idx **** 3
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.33658458 -0.82196823] [ 0.33179453 -0.8119128 ]
# Starting distance: 0.011138056143924135
# Final distance 0.03384962353509803
# Final relative distance 3.0390961490675523
# Min relative distance 3.0390961490675523
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03384962353509803
# 50
# Time taken: 2.960087537765503
#  **** idx **** 4
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.37391437 -0.88682687] [ 0.33658458 -0.82196823]
# Starting distance: 0.07483419295130762
# Final distance 0.059175627912277616
# Final relative distance 0.7907565456178759
# Min relative distance 0.7907565456178759
# Min simulation: 50
# Final simulation: 50
# Min distance 0.059175627912277616
# 50
# Time taken: 2.9809114933013916
#  **** idx **** 5
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.43310837 -0.91877354] [ 0.37391437 -0.88682687]
# Starting distance: 0.06726454717857994
# Final distance 0.04208096024788695
# Final relative distance 0.6256038583916524
# Min relative distance 0.6256038583916524
# Min simulation: 50
# Final simulation: 50
# Min distance 0.04208096024788695
# 50
# Time taken: 3.409229278564453
#  **** idx **** 6
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.43494868 -0.91920721] [ 0.43310837 -0.91877354]
# Starting distance: 0.0018907172633856977
# Final distance 0.0018907172633856977
# Final relative distance 1.0
# Min relative distance 1.0
# Min simulation: 1
# Final simulation: 1
# Min distance 0.0018907172633856977
# 1
# Time taken: 0.00054168701171875
#  **** idx **** 7
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.39901113 -0.87661626] [ 0.43494868 -0.91920721]
# Starting distance: 0.05572698086513488
# Final distance 0.05877610278937082
# Final relative distance 1.05471536187498
# Min relative distance 1.05471536187498
# Min simulation: 50
# Final simulation: 50
# Min distance 0.05877610278937082
# 50
# Time taken: 3.5715506076812744
#  **** idx **** 8
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.47898506 -0.90164387] [ 0.39901113 -0.87661626]
# Starting distance: 0.08379863668246675
# Final distance 0.03745727976157453
# Final relative distance 0.44699151733827364
# Min relative distance 0.44699151733827364
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03745727976157453
# 50
# Time taken: 3.6114399433135986
#  **** idx **** 9
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.44362878 -0.85458062] [ 0.47898506 -0.90164387]
# Starting distance: 0.05886439373111359
# Final distance 0.04985131910148832
# Final relative distance 0.8468840999060306
# Min relative distance 0.8468840999060306
# Min simulation: 50
# Final simulation: 50
# Min distance 0.04985131910148832
# 50
# Time taken: 3.2853589057922363
#  **** idx **** 10
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.43839216 -0.88507897] [ 0.44362878 -0.85458062]
# Starting distance: 0.030944656657449537
# Final distance 0.0497679308322834
# Final relative distance 1.6082883511426
# Min relative distance 1.6082883511426
# Min simulation: 50
# Final simulation: 50
# Min distance 0.0497679308322834
# 50
# Time taken: 3.1392662525177
#  **** idx **** 11
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.50814756 -0.84257297] [ 0.43839216 -0.88507897]
# Starting distance: 0.08168583731443248
# Final distance 0.034142609926923605
# Final relative distance 0.41797465814666007
# Min relative distance 0.41797465814666007
# Min simulation: 50
# Final simulation: 50
# Min distance 0.034142609926923605
# 50
# Time taken: 3.0274691581726074
#  **** idx **** 12
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.50408238 -0.80954146] [ 0.50814756 -0.84257297]
# Starting distance: 0.03328071876437394
# Final distance 0.03362370245293569
# Final relative distance 1.0103057776783626
# Min relative distance 1.0103057776783626
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03362370245293569
# 50
# Time taken: 3.074218988418579
#  **** idx **** 13
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.4803462 -0.7937335] [ 0.50408238 -0.80954146]
# Starting distance: 0.028518379234806147
# Final distance 0.007893218556986036
# Final relative distance 0.276776547923611
# Min relative distance 0.276776547923611
# Min simulation: 50
# Final simulation: 50
# Min distance 0.007893218556986036
# 50
# Time taken: 2.936070442199707
#  **** idx **** 14
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.5893558  -0.77738302] [ 0.4803462 -0.7937335]
# Starting distance: 0.1102289977939839
# Final distance 0.026474371262559953
# Final relative distance 0.2401761042229568
# Min relative distance 0.2401761042229568
# Min simulation: 50
# Final simulation: 50
# Min distance 0.026474371262559953
# 50
# Time taken: 3.2958791255950928
#  **** idx **** 15
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.55730933 -0.80991687] [ 0.5893558  -0.77738302]
# Starting distance: 0.04566648879118826
# Final distance 0.027264859119565936
# Final relative distance 0.5970430361798896
# Min relative distance 0.5970430361798896
# Min simulation: 50
# Final simulation: 50
# Min distance 0.027264859119565936
# 50
# Time taken: 3.097707509994507
#  **** idx **** 16
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.52102651 -0.80035146] [ 0.55730933 -0.80991687]
# Starting distance: 0.037522529513063375
# Final distance 0.030339818048325157
# Final relative distance 0.8085760326409345
# Min relative distance 0.8085760326409345
# Min simulation: 50
# Final simulation: 50
# Min distance 0.030339818048325157
# 50
# Time taken: 3.80989146232605
#  **** idx **** 17
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.61780917 -0.68645984] [ 0.52102651 -0.80035146]
# Starting distance: 0.1494596395062455
# Final distance 0.023220808824774817
# Final relative distance 0.15536507984019648
# Min relative distance 0.15536507984019648
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023220808824774817
# 50
# Time taken: 3.435039758682251
#  **** idx **** 18
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.60695823 -0.68840753] [ 0.61780917 -0.68645984]
# Starting distance: 0.01102434824605842
# Final distance 0.022659040804943128
# Final relative distance 2.0553633012313908
# Min relative distance 2.0553633012313908
# Min simulation: 50
# Final simulation: 50
# Min distance 0.022659040804943128
# 50
# Time taken: 3.2393603324890137
#  **** idx **** 19
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.5947905  -0.65263298] [ 0.60695823 -0.68840753]
# Starting distance: 0.03778719773738481
# Final distance 0.01778614636181619
# Final relative distance 0.47069238860809853
# Min relative distance 0.47069238860809853
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01778614636181619
# 50
# Time taken: 3.7806427478790283
#  **** idx **** 20
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.6317266  -0.71589761] [ 0.5947905  -0.65263298]
# Starting distance: 0.07325769402923152
# Final distance 0.024857726913882144
# Final relative distance 0.3393189922680795
# Min relative distance 0.3393189922680795
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024857726913882144
# 50
# Time taken: 3.4413001537323
#  **** idx **** 21
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.67533656 -0.66605212] [ 0.6317266  -0.71589761]
# Starting distance: 0.06622991410995775
# Final distance 0.024321836919560278
# Final relative distance 0.3672334057263024
# Min relative distance 0.3672334057263024
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024321836919560278
# 50
# Time taken: 3.3973898887634277
#  **** idx **** 22
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.63251047 -0.74906871] [ 0.67533656 -0.66605212]
# Starting distance: 0.09341214332531374
# Final distance 0.025979292023451755
# Final relative distance 0.27811471933554954
# Min relative distance 0.27811471933554954
# Min simulation: 50
# Final simulation: 50
# Min distance 0.025979292023451755
# 50
# Time taken: 3.814582109451294
#  **** idx **** 23
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.62771522 -0.83386552] [ 0.63251047 -0.74906871]
# Starting distance: 0.08493228593083185
# Final distance 0.024623663548977503
# Final relative distance 0.2899211210331818
# Min relative distance 0.2899211210331818
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024623663548977503
# 50
# Time taken: 3.4516303539276123
#  **** idx **** 24
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.60741607 -0.78817855] [ 0.62771522 -0.83386552]
# Starting distance: 0.04999354730341898
# Final distance 0.02713307951114306
# Final relative distance 0.5427316318737693
# Min relative distance 0.5427316318737693
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02713307951114306
# 50
# Time taken: 3.202401638031006
#  **** idx **** 25
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.65312106 -0.78262902] [ 0.60741607 -0.78817855]
# Starting distance: 0.04604066781225024
# Final distance 0.023975691093567772
# Final relative distance 0.5207502895339945
# Min relative distance 0.5207502895339945
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023975691093567772
# 50
# Time taken: 3.7553675174713135
#  **** idx **** 26
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.59013078 -0.86299249] [ 0.65312106 -0.78262902]
# Starting distance: 0.10210809763550752
# Final distance 0.023610000309197583
# Final relative distance 0.23122554288963013
# Min relative distance 0.23122554288963013
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023610000309197583
# 50
# Time taken: 3.2449746131896973
#  **** idx **** 27
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.57289435 -0.91467464] [ 0.59013078 -0.86299249]
# Starting distance: 0.054480627481858335
# Final distance 0.0212924932301512
# Final relative distance 0.3908268721251687
# Min relative distance 0.3908268721251687
# Min simulation: 50
# Final simulation: 50
# Min distance 0.0212924932301512
# 50
# Time taken: 3.679917573928833
#  **** idx **** 28
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.5649362  -0.93553072] [ 0.57289435 -0.91467464]
# Starting distance: 0.022322815999322936
# Final distance 0.021523980453343736
# Final relative distance 0.9642143918579346
# Min relative distance 0.9642143918579346
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021523980453343736
# 50
# Time taken: 3.949049949645996
#  **** idx **** 29
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.48306685 -0.93114502] [ 0.5649362  -0.93553072]
# Starting distance: 0.08198673244039274
# Final distance 0.03290348753970139
# Final relative distance 0.4013269776743864
# Min relative distance 0.4013269776743864
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03290348753970139
# 50
# Time taken: 3.266374349594116
#  **** idx **** 30
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.5149689  -0.90061031] [ 0.48306685 -0.93114502]
# Starting distance: 0.04416004536162153
# Final distance 0.030101380156278227
# Final relative distance 0.6816428721886829
# Min relative distance 0.6816428721886829
# Min simulation: 50
# Final simulation: 50
# Min distance 0.030101380156278227
# 50
# Time taken: 3.950042486190796
#  **** idx **** 31
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.4780671  -0.92272677] [ 0.5149689  -0.90061031]
# Starting distance: 0.04302186690719239
# Final distance 0.03417778783268065
# Final relative distance 0.794428282399033
# Min relative distance 0.794428282399033
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03417778783268065
# 50
# Time taken: 3.5980865955352783
#  **** idx **** 32
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.51398207 -0.98716176] [ 0.4780671  -0.92272677]
# Starting distance: 0.07376823338983718
# Final distance 0.027090432748027825
# Final relative distance 0.3672371087547284
# Min relative distance 0.3672371087547284
# Min simulation: 50
# Final simulation: 50
# Min distance 0.027090432748027825
# 50
# Time taken: 3.3277363777160645
#  **** idx **** 33
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.46878737 -0.9406442 ] [ 0.51398207 -0.98716176]
# Starting distance: 0.06485710356687822
# Final distance 0.035509477864887305
# Final relative distance 0.5475032943503445
# Min relative distance 0.5475032943503445
# Min simulation: 50
# Final simulation: 50
# Min distance 0.035509477864887305
# 50
# Time taken: 3.5290462970733643
#  **** idx **** 34
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.50687241 -0.97533292] [ 0.46878737 -0.9406442 ]
# Starting distance: 0.05151482643447652
# Final distance 0.02822857928176351
# Final relative distance 0.5479699969030938
# Min relative distance 0.5479699969030938
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02822857928176351
# 50
# Time taken: 3.324845314025879
#  **** idx **** 35
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.40618069 -0.93256851] [ 0.50687241 -0.97533292]
# Starting distance: 0.10939660405998332
# Final distance 0.044705932339611905
# Final relative distance 0.40865923328935483
# Min relative distance 0.40865923328935483
# Min simulation: 50
# Final simulation: 50
# Min distance 0.044705932339611905
# 50
# Time taken: 4.2040815353393555
#  **** idx **** 36
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.44405906 -0.9728116 ] [ 0.40618069 -0.93256851]
# Starting distance: 0.05526551682163643
# Final distance 0.03439763375974833
# Final relative distance 0.6224068051469243
# Min relative distance 0.6224068051469243
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03439763375974833
# 50
# Time taken: 3.3242223262786865
#  **** idx **** 37
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.39613215 -0.94193908] [ 0.44405906 -0.9728116 ]
# Starting distance: 0.05700965578547309
# Final distance 0.0407247708034688
# Final relative distance 0.7143486527390344
# Min relative distance 0.7143486527390344
# Min simulation: 50
# Final simulation: 50
# Min distance 0.0407247708034688
# 50
# Time taken: 4.030980348587036
#  **** idx **** 38
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.38804635 -0.9845495 ] [ 0.39613215 -0.94193908]
# Starting distance: 0.04337082129583441
# Final distance 0.031527149422103974
# Final relative distance 0.7269207379554979
# Min relative distance 0.7269207379554979
# Min simulation: 50
# Final simulation: 50
# Min distance 0.031527149422103974
# 50
# Time taken: 3.6104423999786377
#  **** idx **** 39
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.38521009 -0.96382965] [ 0.38804635 -0.9845495 ]
# Starting distance: 0.020913079207472676
# Final distance 0.03386707944348581
# Final relative distance 1.6194209904481405
# Min relative distance 1.6194209904481405
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03386707944348581
# 50
# Time taken: 3.3618547916412354
#  **** idx **** 40
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.39734615 -0.9593975 ] [ 0.38521009 -0.96382965]
# Starting distance: 0.012920061300252882
# Final distance 0.03508684150308404
# Final relative distance 2.7156869218876922
# Min relative distance 2.7156869218876922
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03508684150308404
# 50
# Time taken: 3.3890058994293213
#  **** idx **** 41
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.4475862  -1.04761005] [ 0.39734615 -0.9593975 ]
# Starting distance: 0.10151608663801144
# Final distance 0.03276836704709573
# Final relative distance 0.3227898959890168
# Min relative distance 0.3227898959890168
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03276836704709573
# 50
# Time taken: 3.3013315200805664
#  **** idx **** 42
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.41594915 -1.0425053 ] [ 0.4475862  -1.04761005]
# Starting distance: 0.03204623634767589
# Final distance 0.03028656514186252
# Final relative distance 0.9450896140588133
# Min relative distance 0.9450896140588133
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03028656514186252
# 50
# Time taken: 3.431786298751831
#  **** idx **** 43
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.44863525 -1.04274952] [ 0.41594915 -1.0425053 ]
# Starting distance: 0.03268701414425184
# Final distance 0.03369084224312487
# Final relative distance 1.0307103027044018
# Min relative distance 1.0307103027044018
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03369084224312487
# 50
# Time taken: 3.2351179122924805
#  **** idx **** 44
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.49995461 -1.0562357 ] [ 0.44863525 -1.04274952]
# Starting distance: 0.05306179581002293
# Final distance 0.02576158574801517
# Final relative distance 0.4855015808407491
# Min relative distance 0.4855015808407491
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02576158574801517
# 50
# Time taken: 3.111506700515747
#  **** idx **** 45
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.51445178 -1.06322704] [ 0.49995461 -1.0562357 ]
# Starting distance: 0.016094928720471115
# Final distance 0.024763452069157543
# Final relative distance 1.5385872469047313
# Min relative distance 1.5385872469047313
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024763452069157543
# 50
# Time taken: 3.2883949279785156
#  **** idx **** 46
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.4730215  -1.06175617] [ 0.51445178 -1.06322704]
# Starting distance: 0.04145638958992325
# Final distance 0.029640467824166062
# Final relative distance 0.7149794788538636
# Min relative distance 0.7149794788538636
# Min simulation: 50
# Final simulation: 50
# Min distance 0.029640467824166062
# 50
# Time taken: 4.093747615814209
#  **** idx **** 47
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.5366066  -1.06630819] [ 0.4730215  -1.06175617]
# Starting distance: 0.0637478316245237
# Final distance 0.02425033542764182
# Final relative distance 0.3804103576491337
# Min relative distance 0.3804103576491337
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02425033542764182
# 50
# Time taken: 3.5460352897644043
#  **** idx **** 48
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.54095966 -1.03031141] [ 0.5366066  -1.06630819]
# Starting distance: 0.036259031471078854
# Final distance 0.024060269016021037
# Final relative distance 0.663566235496724
# Min relative distance 0.663566235496724
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024060269016021037
# 50
# Time taken: 3.490108013153076
#  **** idx **** 49
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.49520208 -1.0127631 ] [ 0.54095966 -1.03031141]
# Starting distance: 0.04900713964098332
# Final distance 0.02813348542788714
# Final relative distance 0.5740691179690863
# Min relative distance 0.5740691179690863
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02813348542788714
# 50
# Time taken: 3.273266315460205
#  **** idx **** 50
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.56098795 -0.96593333] [ 0.49520208 -1.0127631 ]
# Starting distance: 0.08075152435912056
# Final distance 0.021791410655467046
# Final relative distance 0.26985757641621283
# Min relative distance 0.26985757641621283
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021791410655467046
# 50
# Time taken: 3.10578989982605
#  **** idx **** 51
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.55460664 -0.98993975] [ 0.56098795 -0.96593333]
# Starting distance: 0.02484007400970502
# Final distance 0.023235986282247472
# Final relative distance 0.9354233917809249
# Min relative distance 0.9354233917809249
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023235986282247472
# 50
# Time taken: 3.2493648529052734
#  **** idx **** 52
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.59975102 -0.9677036 ] [ 0.55460664 -0.98993975]
# Starting distance: 0.050323564657186175
# Final distance 0.02022326801385443
# Final relative distance 0.4018647755106227
# Min relative distance 0.4018647755106227
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02022326801385443
# 50
# Time taken: 3.4279568195343018
#  **** idx **** 53
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.62936677 -0.89490912] [ 0.59975102 -0.9677036 ]
# Starting distance: 0.07858835437972386
# Final distance 0.021117355139094206
# Final relative distance 0.2687084531260089
# Min relative distance 0.2687084531260089
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021117355139094206
# 50
# Time taken: 3.540788173675537
#  **** idx **** 54
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.61063734 -0.92667975] [ 0.62936677 -0.89490912]
# Starting distance: 0.036880411999253834
# Final distance 0.020768395714675775
# Final relative distance 0.5631280831433217
# Min relative distance 0.5631280831433217
# Min simulation: 50
# Final simulation: 50
# Min distance 0.020768395714675775
# 50
# Time taken: 3.2313127517700195
#  **** idx **** 55
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.59095451 -0.91627946] [ 0.61063734 -0.92667975]
# Starting distance: 0.022261624308376377
# Final distance 0.020534196857090615
# Final relative distance 0.9224033508356448
# Min relative distance 0.9224033508356448
# Min simulation: 50
# Final simulation: 50
# Min distance 0.020534196857090615
# 50
# Time taken: 3.2764780521392822
#  **** idx **** 56
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.65229513 -0.82567118] [ 0.59095451 -0.91627946]
# Starting distance: 0.10941906942164446
# Final distance 0.02223705535406691
# Final relative distance 0.2032283355324181
# Min relative distance 0.2032283355324181
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02223705535406691
# 50
# Time taken: 3.4096224308013916
#  **** idx **** 57
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.66324758 -0.77218391] [ 0.65229513 -0.82567118]
# Starting distance: 0.05459711127256505
# Final distance 0.02405221987251228
# Final relative distance 0.44054015518213835
# Min relative distance 0.44054015518213835
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02405221987251228
# 50
# Time taken: 3.1175968647003174
#  **** idx **** 58
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.68380177 -0.7991647 ] [ 0.66324758 -0.77218391]
# Starting distance: 0.033918109572613896
# Final distance 0.023668761042421493
# Final relative distance 0.6978207612588199
# Min relative distance 0.6978207612588199
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023668761042421493
# 50
# Time taken: 3.243802785873413
#  **** idx **** 59
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.71425812 -0.66195272] [ 0.68380177 -0.7991647 ]
# Starting distance: 0.14055147440587257
# Final distance 0.028426224569570162
# Final relative distance 0.20224778636959248
# Min relative distance 0.20224778636959248
# Min simulation: 50
# Final simulation: 50
# Min distance 0.028426224569570162
# 50
# Time taken: 3.2752091884613037
#  **** idx **** 60
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.73221644 -0.67839438] [ 0.71425812 -0.66195272]
# Starting distance: 0.024348088891306525
# Final distance 0.02850912705886701
# Final relative distance 1.170897937252323
# Min relative distance 1.170897937252323
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02850912705886701
# 50
# Time taken: 3.1863763332366943
#  **** idx **** 61
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.70846545 -0.67930954] [ 0.73221644 -0.67839438]
# Starting distance: 0.02376861046858164
# Final distance 0.02806295818083393
# Final relative distance 1.1806730653408932
# Min relative distance 1.1806730653408932
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02806295818083393
# 50
# Time taken: 3.442120313644409
#  **** idx **** 62
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.73885101 -0.69663751] [ 0.70846545 -0.67930954]
# Starting distance: 0.03497914532332448
# Final distance 0.02703464027969312
# Final relative distance 0.7728788119264345
# Min relative distance 0.7728788119264345
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02703464027969312
# 50
# Time taken: 3.2904183864593506
#  **** idx **** 63
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.73939555 -0.73417098] [ 0.73885101 -0.69663751]
# Starting distance: 0.0375374194057778
# Final distance 0.02450869740583334
# Final relative distance 0.652913753630622
# Min relative distance 0.652913753630622
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02450869740583334
# 50
# Time taken: 3.189744472503662
#  **** idx **** 64
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.73503779 -0.71542467] [ 0.73939555 -0.73417098]
# Starting distance: 0.01924614225325886
# Final distance 0.026403054704621027
# Final relative distance 1.3718621818951962
# Min relative distance 1.3718621818951962
# Min simulation: 50
# Final simulation: 50
# Min distance 0.026403054704621027
# 50
# Time taken: 3.325490713119507
#  **** idx **** 65
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.69735572 -0.80997724] [ 0.73503779 -0.71542467]
# Starting distance: 0.10178470844624897
# Final distance 0.023103953154480227
# Final relative distance 0.2269884495143108
# Min relative distance 0.2269884495143108
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023103953154480227
# 50
# Time taken: 3.32774019241333
#  **** idx **** 66
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.68134985 -0.88149381] [ 0.69735572 -0.80997724]
# Starting distance: 0.07328578849327529
# Final distance 0.017629782895234144
# Final relative distance 0.24056209611297086
# Min relative distance 0.24056209611297086
# Min simulation: 50
# Final simulation: 50
# Min distance 0.017629782895234144
# 50
# Time taken: 3.6045773029327393
#  **** idx **** 67
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.70299926 -0.85873443] [ 0.68134985 -0.88149381]
# Starting distance: 0.03141156001499443
# Final distance 0.01625805560190349
# Final relative distance 0.5175819218829834
# Min relative distance 0.5175819218829834
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01625805560190349
# 50
# Time taken: 3.6507534980773926
#  **** idx **** 68
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.65711531 -0.97200813] [ 0.70299926 -0.85873443]
# Starting distance: 0.12221402976121101
# Final distance 0.01725118579647909
# Final relative distance 0.14115552715335117
# Min relative distance 0.14115552715335117
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01725118579647909
# 50
# Time taken: 3.4271080493927
#  **** idx **** 69
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.66190483 -0.9091961 ] [ 0.65711531 -0.97200813]
# Starting distance: 0.06299437398104223
# Final distance 0.018980028186886093
# Final relative distance 0.3012971950891681
# Min relative distance 0.3012971950891681
# Min simulation: 50
# Final simulation: 50
# Min distance 0.018980028186886093
# 50
# Time taken: 3.216053009033203
#  **** idx **** 70
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.6851779  -0.90203113] [ 0.66190483 -0.9091961 ]
# Starting distance: 0.02435103077420372
# Final distance 0.0160748495450203
# Final relative distance 0.6601301478395403
# Min relative distance 0.6601301478395403
# Min simulation: 50
# Final simulation: 50
# Min distance 0.0160748495450203
# 50
# Time taken: 3.0864853858947754
#  **** idx **** 71
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.60584112 -1.05732673] [ 0.6851779  -0.90203113]
# Starting distance: 0.17438763455656664
# Final distance 0.018165683863365874
# Final relative distance 0.10416841715616836
# Min relative distance 0.10416841715616836
# Min simulation: 50
# Final simulation: 50
# Min distance 0.018165683863365874
# 50
# Time taken: 3.112445592880249
#  **** idx **** 72
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.58668454 -1.02462795] [ 0.60584112 -1.05732673]
# Starting distance: 0.03789702894392724
# Final distance 0.02090207844210518
# Final relative distance 0.551549264535541
# Min relative distance 0.551549264535541
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02090207844210518
# 50
# Time taken: 3.2604401111602783
#  **** idx **** 73
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.61986675 -1.00386643] [ 0.58668454 -1.02462795]
# Starting distance: 0.03914204937926908
# Final distance 0.018556095061432413
# Final relative distance 0.4740706057986921
# Min relative distance 0.4740706057986921
# Min simulation: 50
# Final simulation: 50
# Min distance 0.018556095061432413
# 50
# Time taken: 3.2251620292663574
#  **** idx **** 74
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.58565363 -1.09228908] [ 0.61986675 -1.00386643]
# Starting distance: 0.09481088002602181
# Final distance 0.021461043391051128
# Final relative distance 0.22635633574080238
# Min relative distance 0.22635633574080238
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021461043391051128
# 50
# Time taken: 3.307133674621582
#  **** idx **** 75
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.56719098 -1.05600133] [ 0.58565363 -1.09228908]
# Starting distance: 0.0407144961209616
# Final distance 0.02288369449802864
# Final relative distance 0.5620527497145449
# Min relative distance 0.5620527497145449
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02288369449802864
# 50
# Time taken: 3.8921892642974854
#  **** idx **** 76
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.57100651 -1.09478072] [ 0.56719098 -1.05600133]
# Starting distance: 0.03896664270849037
# Final distance 0.02267955502834662
# Final relative distance 0.5820248667049013
# Min relative distance 0.5820248667049013
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02267955502834662
# 50
# Time taken: 3.3729031085968018
#  **** idx **** 77
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.53224367 -1.12373662] [ 0.57100651 -1.09478072]
# Starting distance: 0.04838390603754296
# Final distance 0.02508787006830772
# Final relative distance 0.5185168400591937
# Min relative distance 0.5185168400591937
# Min simulation: 50
# Final simulation: 50
# Min distance 0.02508787006830772
# 50
# Time taken: 3.1356310844421387
#  **** idx **** 78
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.5224858 -1.0823456] [ 0.53224367 -1.12373662]
# Starting distance: 0.04252567457913373
# Final distance 0.023761415195628542
# Final relative distance 0.5587545742845821
# Min relative distance 0.5587545742845821
# Min simulation: 50
# Final simulation: 50
# Min distance 0.023761415195628542
# 50
# Time taken: 3.07659649848938
#  **** idx **** 79
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.53183845 -1.10704297] [ 0.5224858 -1.0823456]
# Starting distance: 0.02640894792887187
# Final distance 0.024326974460817927
# Final relative distance 0.9211640890178059
# Min relative distance 0.9211640890178059
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024326974460817927
# 50
# Time taken: 3.3015005588531494
#  **** idx **** 80
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.45848885 -1.10828112] [ 0.53183845 -1.10704297]
# Starting distance: 0.07336005161596737
# Final distance 0.026210211847578116
# Final relative distance 0.3572818076081242
# Min relative distance 0.3572818076081242
# Min simulation: 50
# Final simulation: 50
# Min distance 0.026210211847578116
# 50
# Time taken: 3.0929653644561768
#  **** idx **** 81
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.49383347 -1.119012  ] [ 0.45848885 -1.10828112]
# Starting distance: 0.03693770213807903
# Final distance 0.028653460331223915
# Final relative distance 0.7757239533773028
# Min relative distance 0.7757239533773028
# Min simulation: 50
# Final simulation: 50
# Min distance 0.028653460331223915
# 50
# Time taken: 3.1669270992279053
#  **** idx **** 82
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.47407496 -1.10982301] [ 0.49383347 -1.119012  ]
# Starting distance: 0.021790734461023475
# Final distance 0.027605181842676588
# Final relative distance 1.2668311796490046
# Min relative distance 1.2668311796490046
# Min simulation: 50
# Final simulation: 50
# Min distance 0.027605181842676588
# 50
# Time taken: 3.088064432144165
#  **** idx **** 83
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.54223836 -1.17779725] [ 0.47407496 -1.10982301]
# Starting distance: 0.0962639439716517
# Final distance 0.024802299974818573
# Final relative distance 0.25764890728061673
# Min relative distance 0.25764890728061673
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024802299974818573
# 50
# Time taken: 3.0864179134368896
#  **** idx **** 84
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.52801104 -1.208287  ] [ 0.54223836 -1.17779725]
# Starting distance: 0.033645825878101596
# Final distance 0.03081890017221514
# Final relative distance 0.9159798984834443
# Min relative distance 0.9159798984834443
# Min simulation: 50
# Final simulation: 50
# Min distance 0.03081890017221514
# 50
# Time taken: 3.254732847213745
#  **** idx **** 85
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.56613351 -1.19702383] [ 0.52801104 -1.208287  ]
# Starting distance: 0.03975150101343343
# Final distance 0.022768610565993462
# Final relative distance 0.5727736056633219
# Min relative distance 0.5727736056633219
# Min simulation: 50
# Final simulation: 50
# Min distance 0.022768610565993462
# 50
# Time taken: 3.3551299571990967
#  **** idx **** 86
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.57450739 -1.16743267] [ 0.56613351 -1.19702383]
# Starting distance: 0.030753191995854332
# Final distance 0.021429598194529335
# Final relative distance 0.6968251685034237
# Min relative distance 0.6968251685034237
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021429598194529335
# 50
# Time taken: 3.0938737392425537
#  **** idx **** 87
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.57432621 -1.14334913] [ 0.57450739 -1.16743267]
# Starting distance: 0.02408421462477536
# Final distance 0.021989597355816532
# Final relative distance 0.9130294551185364
# Min relative distance 0.9130294551185364
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021989597355816532
# 50
# Time taken: 3.076637029647827
#  **** idx **** 88
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.53812552 -1.14828062] [ 0.57432621 -1.14334913]
# Starting distance: 0.036535040698401466
# Final distance 0.024485780966177293
# Final relative distance 0.6701999094050176
# Min relative distance 0.6701999094050176
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024485780966177293
# 50
# Time taken: 3.0677576065063477
#  **** idx **** 89
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.59532186 -1.1102786 ] [ 0.53812552 -1.14828062]
# Starting distance: 0.06867004490357366
# Final distance 0.019665114290295056
# Final relative distance 0.28637107079089247
# Min relative distance 0.28637107079089247
# Min simulation: 50
# Final simulation: 50
# Min distance 0.019665114290295056
# 50
# Time taken: 3.004265546798706
#  **** idx **** 90
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.63448781 -1.09957758] [ 0.59532186 -1.1102786 ]
# Starting distance: 0.04060151782792906
# Final distance 0.015323549616944179
# Final relative distance 0.37741322090188906
# Min relative distance 0.37741322090188906
# Min simulation: 50
# Final simulation: 50
# Min distance 0.015323549616944179
# 50
# Time taken: 3.1479828357696533
#  **** idx **** 91
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.60469448 -1.14798405] [ 0.63448781 -1.09957758]
# Starting distance: 0.05684037447734792
# Final distance 0.019313213784226423
# Final relative distance 0.3397798477193908
# Min relative distance 0.3397798477193908
# Min simulation: 50
# Final simulation: 50
# Min distance 0.019313213784226423
# 50
# Time taken: 3.0331976413726807
#  **** idx **** 92
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.64304722 -1.06029157] [ 0.60469448 -1.14798405]
# Starting distance: 0.0957126006372131
# Final distance 0.014733263609508017
# Final relative distance 0.15393232982303606
# Min relative distance 0.15393232982303606
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014733263609508017
# 50
# Time taken: 3.0729384422302246
#  **** idx **** 93
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.66905809 -1.00695813] [ 0.64304722 -1.06029157]
# Starting distance: 0.05933819313277895
# Final distance 0.014691675889080028
# Final relative distance 0.24759223551355852
# Min relative distance 0.24759223551355852
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014691675889080028
# 50
# Time taken: 2.958103895187378
#  **** idx **** 94
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.65246945 -1.04720086] [ 0.66905809 -1.00695813]
# Starting distance: 0.04352769480280239
# Final distance 0.015197618681463933
# Final relative distance 0.34914825492861806
# Min relative distance 0.34914825492861806
# Min simulation: 50
# Final simulation: 50
# Min distance 0.015197618681463933
# 50
# Time taken: 2.9692766666412354
#  **** idx **** 95
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.70082957 -0.96771037] [ 0.65246945 -1.04720086]
# Starting distance: 0.09304536159513224
# Final distance 0.013578826800291122
# Final relative distance 0.14593770788249064
# Min relative distance 0.14593770788249064
# Min simulation: 50
# Final simulation: 50
# Min distance 0.013578826800291122
# 50
# Time taken: 2.971665859222412
#  **** idx **** 96
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.72033608 -0.92204584] [ 0.70082957 -0.96771037]
# Starting distance: 0.049656356269689804
# Final distance 0.014698518851185224
# Final relative distance 0.2960047807647374
# Min relative distance 0.2960047807647374
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014698518851185224
# 50
# Time taken: 3.075984001159668
#  **** idx **** 97
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.7116306  -0.92165117] [ 0.72033608 -0.92204584]
# Starting distance: 0.008714414086067745
# Final distance 0.01399613663781577
# Final relative distance 1.6060903807855804
# Min relative distance 1.6060903807855804
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01399613663781577
# 50
# Time taken: 2.933314085006714
#  **** idx **** 98
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.71087439 -0.87701794] [ 0.7116306  -0.92165117]
# Starting distance: 0.04463963312307792
# Final distance 0.014798535300062995
# Final relative distance 0.33151113180660097
# Min relative distance 0.33151113180660097
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014798535300062995
# 50
# Time taken: 2.9731547832489014
#  **** idx **** 99
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.72083443 -0.86751485] [ 0.71087439 -0.87701794]
# Starting distance: 0.01376630115192541
# Final distance 0.014823476854885047
# Final relative distance 1.0767944628911286
# Min relative distance 1.0767944628911286
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014823476854885047
# 50
# Time taken: 2.9304721355438232
#  **** idx **** 100
# 53
# ...
# 50
# Time taken: 2.9250247478485107
#  **** idx **** 114
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.68860495 -1.04773233] [ 0.69075161 -1.01852681]
# Starting distance: 0.029284303601967626
# Final distance 0.016477327896041366
# Final relative distance 0.5626675682645992
# Min relative distance 0.5626675682645992
# Min simulation: 50
# Final simulation: 50
# Min distance 0.016477327896041366
# 50
# Time taken: 3.0396058559417725
#  **** idx **** 115
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.70271989 -1.04754479] [ 0.68860495 -1.04773233]
# Starting distance: 0.014116190152423477
# Final distance 0.013358091553800331
# Final relative distance 0.9462958071237801
# Min relative distance 0.9462958071237801
# Min simulation: 50
# Final simulation: 50
# Min distance 0.013358091553800331
# 50
# Time taken: 2.9556326866149902
#  **** idx **** 116
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.63637571 -1.13788426] [ 0.70271989 -1.04754479]
# Starting distance: 0.11208375873240242
# Final distance 0.01803341710309199
# Final relative distance 0.16089233004887343
# Min relative distance 0.16089233004887343
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01803341710309199
# 50
# Time taken: 3.1094303131103516
#  **** idx **** 117
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.62831798 -1.1616303 ] [ 0.63637571 -1.13788426]
# Starting distance: 0.02507591997646067
# Final distance 0.018922589721740067
# Final relative distance 0.754611983907395
# Min relative distance 0.754611983907395
# Min simulation: 50
# Final simulation: 50
# Min distance 0.018922589721740067
# 50
# Time taken: 2.8609862327575684
#  **** idx **** 118
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.62839912 -1.15510163] [ 0.62831798 -1.1616303 ]
# Starting distance: 0.006529177566359609
# Final distance 0.019604822754484694
# Final relative distance 3.0026481214869927
# Min relative distance 3.0026481214869927
# Min simulation: 50
# Final simulation: 50
# Min distance 0.019604822754484694
# 50
# Time taken: 2.8868584632873535
#  **** idx **** 119
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.61795901 -1.19982034] [ 0.62839912 -1.15510163]
# Starting distance: 0.04592122507166371
# Final distance 0.016913213618208307
# Final relative distance 0.3683092859960486
# Min relative distance 0.3683092859960486
# Min simulation: 50
# Final simulation: 50
# Min distance 0.016913213618208307
# 50
# Time taken: 3.0117812156677246
#  **** idx **** 120
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.58197963 -1.18433709] [ 0.61795901 -1.19982034]
# Starting distance: 0.03916946602956613
# Final distance 0.021702579796661663
# Final relative distance 0.5540688193267683
# Min relative distance 0.5540688193267683
# Min simulation: 50
# Final simulation: 50
# Min distance 0.021702579796661663
# 50
# Time taken: 3.0412490367889404
#  **** idx **** 121
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.586359   -1.20248337] [ 0.58197963 -1.18433709]
# Starting distance: 0.018667253324982973
# Final distance 0.022701543544845947
# Final relative distance 1.2161158982325353
# Min relative distance 1.2161158982325353
# Min simulation: 50
# Final simulation: 50
# Min distance 0.022701543544845947
# 50
# Time taken: 3.0426130294799805
#  **** idx **** 122
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.54049276 -1.23233175] [ 0.586359   -1.20248337]
# Starting distance: 0.05472328188374789
# Final distance 0.029442756138397426
# Final relative distance 0.5380297950869344
# Min relative distance 0.5380297950869344
# Min simulation: 50
# Final simulation: 50
# Min distance 0.029442756138397426
# 50
# Time taken: 2.87414813041687
#  **** idx **** 123
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.55702593 -1.24984593] [ 0.54049276 -1.23233175]
# Starting distance: 0.024085103590838278
# Final distance 0.018811466922187395
# Final relative distance 0.7810415616955486
# Min relative distance 0.7810415616955486
# Min simulation: 50
# Final simulation: 50
# Min distance 0.018811466922187395
# 50
# Time taken: 2.938788890838623
#  **** idx **** 124
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.59004617 -1.22107546] [ 0.55702593 -1.24984593]
# Starting distance: 0.04379584714511632
# Final distance 0.01777566389872765
# Final relative distance 0.40587555801417613
# Min relative distance 0.40587555801417613
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01777566389872765
# 50
# Time taken: 2.9761247634887695
#  **** idx **** 125
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.58256779 -1.28486178] [ 0.59004617 -1.22107546]
# Starting distance: 0.06422320819964365
# Final distance 0.011766805409140216
# Final relative distance 0.18321734056888028
# Min relative distance 0.18321734056888028
# Min simulation: 50
# Final simulation: 50
# Min distance 0.011766805409140216
# 50
# Time taken: 2.953474760055542
#  **** idx **** 126
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.57464564 -1.27645208] [ 0.58256779 -1.28486178]
# Starting distance: 0.011553506902853646
# Final distance 0.011937671328860073
# Final relative distance 1.0332508933639484
# Min relative distance 1.0332508933639484
# Min simulation: 50
# Final simulation: 50
# Min distance 0.011937671328860073
# 50
# Time taken: 2.9493441581726074
#  **** idx **** 127
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.57973953 -1.27121775] [ 0.57464564 -1.27645208]
# Starting distance: 0.0073038322243242524
# Final distance 0.010290113307206486
# Final relative distance 1.4088649617302131
# Min relative distance 1.4088649617302131
# Min simulation: 50
# Final simulation: 50
# Min distance 0.010290113307206486
# 50
# Time taken: 3.12446928024292
#  **** idx **** 128
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.65534923 -1.19512776] [ 0.57973953 -1.27121775]
# Starting distance: 0.1072684177238069
# Final distance 0.01345793970735716
# Final relative distance 0.12546041036988595
# Min relative distance 0.12546041036988595
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01345793970735716
# 50
# Time taken: 3.0181031227111816
#  **** idx **** 129
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.62440565 -1.21061101] [ 0.65534923 -1.19512776]
# Starting distance: 0.03460110343958434
# Final distance 0.015283220448864899
# Final relative distance 0.44169748735182224
# Min relative distance 0.44169748735182224
# Min simulation: 50
# Final simulation: 50
# Min distance 0.015283220448864899
# 50
# Time taken: 2.9863579273223877
#  **** idx **** 130
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.60341541 -1.22456218] [ 0.62440565 -1.21061101]
# Starting distance: 0.025203671722027417
# Final distance 0.014653144779832733
# Final relative distance 0.5813892888878658
# Min relative distance 0.5813892888878658
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014653144779832733
# 50
# Time taken: 2.9092905521392822
#  **** idx **** 131
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.69193964 -1.12756693] [ 0.60341541 -1.22456218]
# Starting distance: 0.13131875737206092
# Final distance 0.012837231049861786
# Final relative distance 0.09775626351299153
# Min relative distance 0.09775626351299153
# Min simulation: 50
# Final simulation: 50
# Min distance 0.012837231049861786
# 50
# Time taken: 2.987060308456421
#  **** idx **** 132
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.67041999 -1.15094518] [ 0.69193964 -1.12756693]
# Starting distance: 0.031774793972119304
# Final distance 0.012393058912979288
# Final relative distance 0.3900279864553501
# Min relative distance 0.3900279864553501
# Min simulation: 50
# Final simulation: 50
# Min distance 0.012393058912979288
# 50
# Time taken: 2.879854679107666
#  **** idx **** 133
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.66667715 -1.17499915] [ 0.67041999 -1.15094518]
# Starting distance: 0.024343420384623195
# Final distance 0.012795994378378531
# Final relative distance 0.5256448837592793
# Min relative distance 0.5256448837592793
# Min simulation: 50
# Final simulation: 50
# Min distance 0.012795994378378531
# 50
# Time taken: 3.038538932800293
#  **** idx **** 134
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.72977608 -1.04368047] [ 0.66667715 -1.17499915]
# Starting distance: 0.14569169078313826
# Final distance 0.01298545427122302
# Final relative distance 0.08912968338429017
# Min relative distance 0.08912968338429017
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01298545427122302
# 50
# Time taken: 3.009992837905884
#  **** idx **** 135
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.72502825 -1.05671198] [ 0.72977608 -1.04368047]
# Starting distance: 0.01386946730300691
# Final distance 0.013342309107110189
# Final relative distance 0.9619914604952108
# Min relative distance 0.9619914604952108
# Min simulation: 50
# Final simulation: 50
# Min distance 0.013342309107110189
# 50
# Time taken: 2.8794288635253906
#  **** idx **** 136
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.72971972 -1.03022694] [ 0.72502825 -1.05671198]
# Starting distance: 0.026897350636818574
# Final distance 0.01261759530063152
# Final relative distance 0.4691017889085277
# Min relative distance 0.4691017889085277
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01261759530063152
# 50
# Time taken: 3.0397756099700928
#  **** idx **** 137
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.76642065 -0.92238516] [ 0.72971972 -1.03022694]
# Starting distance: 0.11391578392857861
# Final distance 0.014527597230783458
# Final relative distance 0.1275292740810332
# Min relative distance 0.1275292740810332
# Min simulation: 50
# Final simulation: 50
# Min distance 0.014527597230783458
# 50
# Time taken: 2.8865933418273926
#  **** idx **** 138
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.75419811 -0.92030158] [ 0.76642065 -0.92238516]
# Starting distance: 0.0123988545994428
# Final distance 0.015548145639434397
# Final relative distance 1.2539985459732002
# Min relative distance 1.2539985459732002
# Min simulation: 50
# Final simulation: 50
# Min distance 0.015548145639434397
# 50
# Time taken: 2.792905807495117
#  **** idx **** 139
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.75154871 -0.98505218] [ 0.75419811 -0.92030158]
# Starting distance: 0.0648047807528207
# Final distance 0.01379436210610457
# Final relative distance 0.212860254225984
# Min relative distance 0.212860254225984
# Min simulation: 50
# Final simulation: 50
# Min distance 0.01379436210610457
# 50
# Time taken: 2.8736572265625
#  **** idx **** 140
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.78350652 -0.8684314 ] [ 0.75154871 -0.98505218]
# Starting distance: 0.12092025513215234
# Final distance 0.013064041617524818
# Final relative distance 0.10803848869858304
# Min relative distance 0.10803848869858304
# Min simulation: 50
# Final simulation: 50
# Min distance 0.013064041617524818
# 50
# Time taken: 3.0670387744903564
#  **** idx **** 141
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.80636372 -0.78057242] [ 0.78350652 -0.8684314 ]
# Starting distance: 0.09078354961511498
# Final distance 0.020101663721372075
# Final relative distance 0.2214240774523015
# Min relative distance 0.2214240774523015
# Min simulation: 50
# Final simulation: 50
# Min distance 0.020101663721372075
# 50
# Time taken: 2.838893413543701
#  **** idx **** 142
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.78121885 -0.83589677] [ 0.80636372 -0.78057242]
# Starting distance: 0.06077045245484411
# Final distance 0.015267349298852588
# Final relative distance 0.25122981123428517
# Min relative distance 0.25122981123428517
# Min simulation: 50
# Final simulation: 50
# Min distance 0.015267349298852588
# 50
# Time taken: 3.027219295501709
#  **** idx **** 143
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.83898991 -0.6325393 ] [ 0.78121885 -0.83589677]
# Starting distance: 0.2114042442005311
# Final distance 0.012652052550424184
# Final relative distance 0.059847675235994144
# Min relative distance 0.059847675235994144
# Min simulation: 50
# Final simulation: 50
# Min distance 0.012652052550424184
# 50
# Time taken: 2.8766143321990967
#  **** idx **** 144
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.80904595 -0.75273207] [ 0.83898991 -0.6325393 ]
# Starting distance: 0.1238666319679078
# Final distance 0.024409103805006604
# Final relative distance 0.19705955847197557
# Min relative distance 0.19705955847197557
# Min simulation: 50
# Final simulation: 50
# Min distance 0.024409103805006604
# 50
# Time taken: 2.9109199047088623
#  **** idx **** 145
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.81848592 -0.70761601] [ 0.80904595 -0.75273207]
# Starting distance: 0.04609307358818789
# Final distance 0.026986011309783522
# Final relative distance 0.5854678199784692
# Min relative distance 0.5854678199784692
# Min simulation: 50
# Final simulation: 50
# Min distance 0.026986011309783522
# 50
# Time taken: 2.9427506923675537
#  **** idx **** 146
# 53
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC1_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 0.35273929 -0.88558466] [ 0.81848592 -0.70761601]
# Starting distance: 0.4985907747618218
# Final distance 0.040085717988255165
# Final relative distance 0.08039803385332235
# Min relative distance 0.08039803385332235
# Min simulation: 50
# Final simulation: 50
# Min distance 0.040085717988255165
# 50
# Time taken: 2.881749391555786
# 147 147
#  Mean final distance 0.02327899581862508
#  Mean simulations count 49.33108108108108

# %%
import matplotlib
# %matplotlib inline
import numpy as np

import os
import sys
nxg_path = os.environ.get('NXG_PATH')
sys.path.append(nxg_path + 'core')
sys.path.append(nxg_path + 'configuration-setup')
sys.path.append(nxg_path + 'core/rrtAlgorithms/src/')

from evaluation_isen_nongr import EvaluationInvSenNonGr

evalObject = EvaluationInvSenNonGr(dynamics='OtherBenchC2')

evalObject.setSimsBound(40)
dataObject = evalObject.setDataObject()

evalObject.coverage(d_time_steps=[71], partitions=7)
# Out:
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/dconfigs_inv/d_object_OtherBenchC2.txt
# 148
#  **** idx **** 0
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.85782769 0.26602176] [0.8415137  0.31085446]
# Starting distance: 0.04770867269155833
# Final distance 0.027518526891166135
# Final relative distance 0.5768034476472728
# Min relative distance 0.5768034476472728
# Min simulation: 40
# Final simulation: 40
# Min distance 0.027518526891166135
# 40
# Time taken: 17.795592784881592
#  **** idx **** 1
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.86216304 0.29568415] [0.85782769 0.26602176]
# Starting distance: 0.02997752632190151
# Final distance 0.01622549350443388
# Final relative distance 0.5412552500230672
# Min relative distance 0.5412552500230672
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01622549350443388
# 40
# Time taken: 18.532310247421265
#  **** idx **** 2
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.89398692 0.34601791] [0.86216304 0.29568415]
# Starting distance: 0.0595503788341608
# Final distance 0.010087736066450798
# Final relative distance 0.16939835252003493
# Min relative distance 0.16939835252003493
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010087736066450798
# 40
# Time taken: 19.17672824859619
#  **** idx **** 3
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.91640341 0.33411232] [0.89398692 0.34601791]
# Starting distance: 0.02538192262681188
# Final distance 0.015353089220558823
# Final relative distance 0.6048828312296869
# Min relative distance 0.6048828312296869
# Min simulation: 40
# Final simulation: 40
# Min distance 0.015353089220558823
# 40
# Time taken: 18.85128951072693
#  **** idx **** 4
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.87062512 0.3473804 ] [0.91640341 0.33411232]
# Starting distance: 0.04766229027320244
# Final distance 0.007733516710311158
# Final relative distance 0.1622565064746634
# Min relative distance 0.1622565064746634
# Min simulation: 40
# Final simulation: 40
# Min distance 0.007733516710311158
# 40
# Time taken: 19.26174283027649
#  **** idx **** 5
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.92033659 0.36396369] [0.87062512 0.3473804 ]
# Starting distance: 0.052404536893841794
# Final distance 0.008512299303468073
# Final relative distance 0.16243439610413535
# Min relative distance 0.16243439610413535
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008512299303468073
# 40
# Time taken: 18.330352544784546
#  **** idx **** 6
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.91754576 0.36142403] [0.92033659 0.36396369]
# Starting distance: 0.0037734041423350974
# Final distance 0.0037734041423350974
# Final relative distance 1.0
# Min relative distance 1.0
# Min simulation: 1
# Final simulation: 1
# Min distance 0.0037734041423350974
# 1
# Time taken: 0.0013647079467773438
#  **** idx **** 7
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.87914378 0.37405061] [0.91754576 0.36142403]
# Starting distance: 0.04042453077210283
# Final distance 0.009223500634804682
# Final relative distance 0.22816592941555836
# Min relative distance 0.22816592941555836
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009223500634804682
# 40
# Time taken: 18.68159008026123
#  **** idx **** 8
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.97831599 0.37028256] [0.87914378 0.37405061]
# Starting distance: 0.09924377195192059
# Final distance 0.011238354653677361
# Final relative distance 0.11323989841016793
# Min relative distance 0.11323989841016793
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011238354653677361
# 40
# Time taken: 17.880473375320435
#  **** idx **** 9
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.91054485 0.37464915] [0.97831599 0.37028256]
# Starting distance: 0.06791167110022076
# Final distance 0.010919623690782103
# Final relative distance 0.16079156224365987
# Min relative distance 0.16079156224365987
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010919623690782103
# 40
# Time taken: 16.925800561904907
#  **** idx **** 10
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.94597275 0.37557168] [0.91054485 0.37464915]
# Starting distance: 0.035439906272633104
# Final distance 0.012164263285377258
# Final relative distance 0.34323632776564567
# Min relative distance 0.34323632776564567
# Min simulation: 40
# Final simulation: 40
# Min distance 0.012164263285377258
# 40
# Time taken: 18.331505060195923
#  **** idx **** 11
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.94550246 0.3927882 ] [0.94597275 0.37557168]
# Starting distance: 0.017222941550576094
# Final distance 0.010116902077092446
# Final relative distance 0.5874084892748209
# Min relative distance 0.5874084892748209
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010116902077092446
# 40
# Time taken: 18.0539288520813
#  **** idx **** 12
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.97606998 0.38617429] [0.94550246 0.3927882 ]
# Starting distance: 0.03127486375480744
# Final distance 0.009189602427262845
# Final relative distance 0.293833491947675
# Min relative distance 0.293833491947675
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009189602427262845
# 40
# Time taken: 19.47493314743042
#  **** idx **** 13
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.99077088 0.39604602] [0.97606998 0.38617429]
# Starting distance: 0.01770783171459073
# Final distance 0.00878039359606623
# Final relative distance 0.49584803704857017
# Min relative distance 0.49584803704857017
# Min simulation: 40
# Final simulation: 40
# Min distance 0.00878039359606623
# 40
# Time taken: 19.34096074104309
#  **** idx **** 14
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.01375934 0.40471215] [0.99077088 0.39604602]
# Starting distance: 0.02456768412561731
# Final distance 0.008741084576222085
# Final relative distance 0.3557960339903405
# Min relative distance 0.3557960339903405
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008741084576222085
# 40
# Time taken: 18.24418330192566
#  **** idx **** 15
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.94190989 0.40539542] [1.01375934 0.40471215]
# Starting distance: 0.07185269780134024
# Final distance 0.01128879230263879
# Final relative distance 0.15711020807945536
# Min relative distance 0.15711020807945536
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01128879230263879
# 40
# Time taken: 18.488476276397705
#  **** idx **** 16
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.00408793 0.40361416] [0.94190989 0.40539542]
# Starting distance: 0.062203547659901715
# Final distance 0.009000638626712881
# Final relative distance 0.1446965481120776
# Min relative distance 0.1446965481120776
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009000638626712881
# 40
# Time taken: 18.767653226852417
#  **** idx **** 17
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.93674352 0.41813016] [1.00408793 0.40361416]
# Starting distance: 0.0688911001272478
# Final distance 0.006064456211120613
# Final relative distance 0.08802960324220457
# Min relative distance 0.08802960324220457
# Min simulation: 40
# Final simulation: 40
# Min distance 0.006064456211120613
# 40
# Time taken: 18.742064714431763
#  **** idx **** 18
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.98983214 0.41891291] [0.93674352 0.41813016]
# Starting distance: 0.053094397163963976
# Final distance 0.0054718755884339155
# Final relative distance 0.10305937878032384
# Min relative distance 0.10305937878032384
# Min simulation: 40
# Final simulation: 40
# Min distance 0.0054718755884339155
# 40
# Time taken: 18.57107925415039
#  **** idx **** 19
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.97903336 0.41293767] [0.98983214 0.41891291]
# Starting distance: 0.012341683821925584
# Final distance 0.0023244336426065117
# Final relative distance 0.18834007386229143
# Min relative distance 0.18834007386229143
# Min simulation: 2
# Final simulation: 2
# Min distance 0.0023244336426065117
# 2
# Time taken: 0.5244796276092529
#  **** idx **** 20
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.04250369 0.4107903 ] [0.97903336 0.41293767]
# Starting distance: 0.06350664577646968
# Final distance 0.008197436360084428
# Final relative distance 0.12907997674664973
# Min relative distance 0.12907997674664973
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008197436360084428
# 40
# Time taken: 18.238272190093994
#  **** idx **** 21
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.12433357 0.41676377] [1.04250369 0.4107903 ]
# Starting distance: 0.08204761203277115
# Final distance 0.00776274975410867
# Final relative distance 0.09461274450020679
# Min relative distance 0.09461274450020679
# Min simulation: 40
# Final simulation: 40
# Min distance 0.00776274975410867
# 40
# Time taken: 18.891584396362305
#  **** idx **** 22
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.05885205 0.41767592] [1.12433357 0.41676377]
# Starting distance: 0.06548787242246147
# Final distance 0.007520791607941485
# Final relative distance 0.11484250945617762
# Min relative distance 0.11484250945617762
# Min simulation: 40
# Final simulation: 40
# Min distance 0.007520791607941485
# 40
# Time taken: 18.810601234436035
#  **** idx **** 23
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.13597077 0.40715706] [1.05885205 0.41767592]
# Starting distance: 0.07783279312946252
# Final distance 0.00828516018860385
# Final relative distance 0.10644819304920482
# Min relative distance 0.10644819304920482
# Min simulation: 40
# Final simulation: 40
# Min distance 0.00828516018860385
# 40
# Time taken: 18.635456800460815
#  **** idx **** 24
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.0302498  0.40078652] [1.13597077 0.40715706]
# Starting distance: 0.10591272979577787
# Final distance 0.007503695639015681
# Final relative distance 0.0708479108553277
# Min relative distance 0.0708479108553277
# Min simulation: 40
# Final simulation: 40
# Min distance 0.007503695639015681
# 40
# Time taken: 17.528196811676025
#  **** idx **** 25
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.08628844 0.39920405] [1.0302498  0.40078652]
# Starting distance: 0.056060976344098824
# Final distance 0.006998385404022136
# Final relative distance 0.12483523941977887
# Min relative distance 0.12483523941977887
# Min simulation: 40
# Final simulation: 40
# Min distance 0.006998385404022136
# 40
# Time taken: 18.252173900604248
#  **** idx **** 26
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.03176585 0.3907594 ] [1.08628844 0.39920405]
# Starting distance: 0.05517268195379591
# Final distance 0.007265613825248364
# Final relative distance 0.1316886105216512
# Min relative distance 0.1316886105216512
# Min simulation: 40
# Final simulation: 40
# Min distance 0.007265613825248364
# 40
# Time taken: 17.86121702194214
#  **** idx **** 27
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.03195865 0.38496416] [1.03176585 0.3907594 ]
# Starting distance: 0.005798443226534984
# Final distance 0.008330250598364649
# Final relative distance 1.4366357094337914
# Min relative distance 1.4366357094337914
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008330250598364649
# 40
# Time taken: 16.87020707130432
#  **** idx **** 28
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.06241297 0.37955656] [1.03195865 0.38496416]
# Starting distance: 0.03093069116110285
# Final distance 0.011041961987821912
# Final relative distance 0.3569904704136655
# Min relative distance 0.3569904704136655
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011041961987821912
# 40
# Time taken: 16.529863119125366
#  **** idx **** 29
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.01518591 0.37823816] [1.06241297 0.37955656]
# Starting distance: 0.04724546345655581
# Final distance 0.010542986208517083
# Final relative distance 0.22315340854284987
# Min relative distance 0.22315340854284987
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010542986208517083
# 40
# Time taken: 18.078745126724243
#  **** idx **** 30
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.00495964 0.37503345] [1.01518591 0.37823816]
# Starting distance: 0.01071665207032069
# Final distance 0.012190496825440485
# Final relative distance 1.1375284692876748
# Min relative distance 1.1375284692876748
# Min simulation: 40
# Final simulation: 40
# Min distance 0.012190496825440485
# 40
# Time taken: 17.958520650863647
#  **** idx **** 31
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.09441666 0.36237681] [1.00495964 0.37503345]
# Starting distance: 0.0903479311888467
# Final distance 0.009332285346307896
# Final relative distance 0.1032927397839515
# Min relative distance 0.1032927397839515
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009332285346307896
# 40
# Time taken: 18.533219814300537
#  **** idx **** 32
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.05175057 0.32604516] [1.09441666 0.36237681]
# Starting distance: 0.05603913048028782
# Final distance 0.016579409696470877
# Final relative distance 0.2958541568074973
# Min relative distance 0.2958541568074973
# Min simulation: 40
# Final simulation: 40
# Min distance 0.016579409696470877
# 40
# Time taken: 17.79139757156372
#  **** idx **** 33
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.97827949 0.3515939 ] [1.05175057 0.32604516]
# Starting distance: 0.0777864876114767
# Final distance 0.009868755163794424
# Final relative distance 0.12686978763054957
# Min relative distance 0.12686978763054957
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009868755163794424
# 40
# Time taken: 17.741419792175293
#  **** idx **** 34
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.99362091 0.34440785] [0.97827949 0.3515939 ]
# Starting distance: 0.016941033036793784
# Final distance 0.01038131297451632
# Final relative distance 0.6127910235443977
# Min relative distance 0.6127910235443977
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01038131297451632
# 40
# Time taken: 16.44836401939392
#  **** idx **** 35
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.98423991 0.27368725] [0.99362091 0.34440785]
# Starting distance: 0.07134007582102306
# Final distance 0.020004548872292877
# Final relative distance 0.28041109631674627
# Min relative distance 0.28041109631674627
# Min simulation: 40
# Final simulation: 40
# Min distance 0.020004548872292877
# 40
# Time taken: 16.71415114402771
#  **** idx **** 36
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.96135869 0.26771577] [0.98423991 0.27368725]
# Starting distance: 0.02364759611844756
# Final distance 0.022426684294414453
# Final relative distance 0.9483705735704497
# Min relative distance 0.9483705735704497
# Min simulation: 40
# Final simulation: 40
# Min distance 0.022426684294414453
# 40
# Time taken: 15.630115032196045
#  **** idx **** 37
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.00336176 0.31485249] [0.96135869 0.26771577]
# Starting distance: 0.06313578830386825
# Final distance 0.014655937281015021
# Final relative distance 0.23213359133930495
# Min relative distance 0.23213359133930495
# Min simulation: 40
# Final simulation: 40
# Min distance 0.014655937281015021
# 40
# Time taken: 15.958587646484375
#  **** idx **** 38
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.94284182 0.27007996] [1.00336176 0.31485249]
# Starting distance: 0.07528109075950484
# Final distance 0.020744694062396055
# Final relative distance 0.2755631441189881
# Min relative distance 0.2755631441189881
# Min simulation: 40
# Final simulation: 40
# Min distance 0.020744694062396055
# 40
# Time taken: 16.180635690689087
#  **** idx **** 39
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.90079214 0.15499334] [0.94284182 0.27007996]
# Starting distance: 0.12252797316421671
# Final distance 0.04511639802732732
# Final relative distance 0.36821304443566194
# Min relative distance 0.36821304443566194
# Min simulation: 40
# Final simulation: 40
# Min distance 0.04511639802732732
# 40
# Time taken: 15.306302785873413
#  **** idx **** 40
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.88950925 0.12489769] [0.90079214 0.15499334]
# Starting distance: 0.03214113207011221
# Final distance 0.023493078746904324
# Final relative distance 0.7309350117368876
# Min relative distance 0.7309350117368876
# Min simulation: 40
# Final simulation: 40
# Min distance 0.023493078746904324
# 40
# Time taken: 16.09071373939514
#  **** idx **** 41
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.93236347 0.07427133] [0.88950925 0.12489769]
# Starting distance: 0.06632882354371873
# Final distance 0.018833877407245528
# Final relative distance 0.2839471047580351
# Min relative distance 0.2839471047580351
# Min simulation: 40
# Final simulation: 40
# Min distance 0.018833877407245528
# 40
# Time taken: 16.882671356201172
#  **** idx **** 42
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.02760131 0.05123476] [0.93236347 0.07427133]
# Starting distance: 0.09798433717052699
# Final distance 0.0673650058664365
# Final relative distance 0.6875078998513594
# Min relative distance 0.6875078998513594
# Min simulation: 40
# Final simulation: 40
# Min distance 0.0673650058664365
# 40
# Time taken: 15.356362342834473
#  **** idx **** 43
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.9666929  0.08581513] [1.02760131 0.05123476]
# Starting distance: 0.07004025171986919
# Final distance 0.04636566625151082
# Final relative distance 0.6619860025197153
# Min relative distance 0.6619860025197153
# Min simulation: 40
# Final simulation: 40
# Min distance 0.04636566625151082
# 40
# Time taken: 15.939978837966919
#  **** idx **** 44
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.12432891 0.20981693] [0.9666929  0.08581513]
# Starting distance: 0.200563105240705
# Final distance 0.03045558183944178
# Final relative distance 0.151850370500051
# Min relative distance 0.151850370500051
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03045558183944178
# 40
# Time taken: 16.490825176239014
#  **** idx **** 45
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.07652026 0.30474456] [1.12432891 0.20981693]
# Starting distance: 0.10628697422041407
# Final distance 0.014929484582477623
# Final relative distance 0.1404639156583515
# Min relative distance 0.1404639156583515
# Min simulation: 40
# Final simulation: 40
# Min distance 0.014929484582477623
# 40
# Time taken: 18.338974714279175
#  **** idx **** 46
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.08485648 0.30694199] [1.07652026 0.30474456]
# Starting distance: 0.008620974500080484
# Final distance 0.015010248950326722
# Final relative distance 1.7411313477596517
# Min relative distance 1.7411313477596517
# Min simulation: 40
# Final simulation: 40
# Min distance 0.015010248950326722
# 40
# Time taken: 18.234726667404175
#  **** idx **** 47
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.14583949 0.32328014] [1.08485648 0.30694199]
# Starting distance: 0.06313369203288842
# Final distance 0.016688625267279825
# Final relative distance 0.26433786350695554
# Min relative distance 0.26433786350695554
# Min simulation: 40
# Final simulation: 40
# Min distance 0.016688625267279825
# 40
# Time taken: 17.92510724067688
#  **** idx **** 48
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.1709828  0.29561936] [1.14583949 0.32328014]
# Starting distance: 0.03738054243906254
# Final distance 0.013739485258192146
# Final relative distance 0.367557139669392
# Min relative distance 0.367557139669392
# Min simulation: 40
# Final simulation: 40
# Min distance 0.013739485258192146
# 40
# Time taken: 16.906286239624023
#  **** idx **** 49
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.10690027 0.34305117] [1.1709828  0.29561936]
# Starting distance: 0.07972670360012696
# Final distance 0.009116674317555726
# Final relative distance 0.11434906882994732
# Min relative distance 0.11434906882994732
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009116674317555726
# 40
# Time taken: 16.807197093963623
#  **** idx **** 50
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.13955635 0.35470794] [1.10690027 0.34305117]
# Starting distance: 0.03467419220594204
# Final distance 0.008582032082775005
# Final relative distance 0.24750488870233353
# Min relative distance 0.24750488870233353
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008582032082775005
# 40
# Time taken: 16.26280379295349
#  **** idx **** 51
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.1934137  0.35462005] [1.13955635 0.35470794]
# Starting distance: 0.05385742547141989
# Final distance 0.009014882502467386
# Final relative distance 0.167384207907436
# Min relative distance 0.167384207907436
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009014882502467386
# 40
# Time taken: 16.035252571105957
#  **** idx **** 52
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.1602873  0.36786872] [1.1934137  0.35462005]
# Starting distance: 0.035677528997325694
# Final distance 0.010096792959303828
# Final relative distance 0.28300146459304004
# Min relative distance 0.28300146459304004
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010096792959303828
# 40
# Time taken: 15.888478755950928
#  **** idx **** 53
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.1553213  0.37872511] [1.1602873  0.36786872]
# Starting distance: 0.011938271488246947
# Final distance 0.012102825179509833
# Final relative distance 1.013783711605561
# Min relative distance 1.013783711605561
# Min simulation: 40
# Final simulation: 40
# Min distance 0.012102825179509833
# 40
# Time taken: 17.08878517150879
#  **** idx **** 54
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.18055446 0.38101228] [1.1553213  0.37872511]
# Starting distance: 0.025336600069010767
# Final distance 0.012365375733125223
# Final relative distance 0.48804400351447835
# Min relative distance 0.48804400351447835
# Min simulation: 40
# Final simulation: 40
# Min distance 0.012365375733125223
# 40
# Time taken: 15.869795799255371
#  **** idx **** 55
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.13216117 0.38907547] [1.18055446 0.38101228]
# Starting distance: 0.04906042267098063
# Final distance 0.009935388274923074
# Final relative distance 0.2025133036776685
# Min relative distance 0.2025133036776685
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009935388274923074
# 40
# Time taken: 16.457496881484985
#  **** idx **** 56
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.1862089  0.39571043] [1.13216117 0.38907547]
# Starting distance: 0.054453463122132666
# Final distance 0.009869692381160804
# Final relative distance 0.1812500402228643
# Min relative distance 0.1812500402228643
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009869692381160804
# 40
# Time taken: 16.330044507980347
#  **** idx **** 57
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.22497066 0.40610161] [1.1862089  0.39571043]
# Starting distance: 0.04013041742202323
# Final distance 0.009102796808656914
# Final relative distance 0.22683035446477506
# Min relative distance 0.22683035446477506
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009102796808656914
# 40
# Time taken: 16.209074020385742
#  **** idx **** 58
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.2469322  0.40940436] [1.22497066 0.40610161]
# Starting distance: 0.022208497211983643
# Final distance 0.008926814516248164
# Final relative distance 0.40195491081815654
# Min relative distance 0.40195491081815654
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008926814516248164
# 40
# Time taken: 16.04598307609558
#  **** idx **** 59
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.20762218 0.4146706 ] [1.2469322  0.40940436]
# Starting distance: 0.03966119525127564
# Final distance 0.009339153050688548
# Final relative distance 0.23547331318483572
# Min relative distance 0.23547331318483572
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009339153050688548
# 40
# Time taken: 16.33180046081543
#  **** idx **** 60
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.24304555 0.42026793] [1.20762218 0.4146706 ]
# Starting distance: 0.03586286495468901
# Final distance 0.008896613193887841
# Final relative distance 0.24807313094278108
# Min relative distance 0.24807313094278108
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008896613193887841
# 40
# Time taken: 15.725958585739136
#  **** idx **** 61
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.22907615 0.42177473] [1.24304555 0.42026793]
# Starting distance: 0.014050434223775712
# Final distance 0.009473213845798474
# Final relative distance 0.6742292583220093
# Min relative distance 0.6742292583220093
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009473213845798474
# 40
# Time taken: 16.61711859703064
#  **** idx **** 62
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.32853007 0.42760009] [1.22907615 0.42177473]
# Starting distance: 0.09962438468078486
# Final distance 0.008637148037922352
# Final relative distance 0.08669712807358748
# Min relative distance 0.08669712807358748
# Min simulation: 40
# Final simulation: 40
# Min distance 0.008637148037922352
# 40
# Time taken: 16.81220579147339
#  **** idx **** 63
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.33255782 0.43561095] [1.32853007 0.42760009]
# Starting distance: 0.008966416673523481
# Final distance 0.009014609195253785
# Final relative distance 1.0053747805266076
# Min relative distance 1.0053747805266076
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009014609195253785
# 40
# Time taken: 15.212129592895508
#  **** idx **** 64
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.27568773 0.42859821] [1.33255782 0.43561095]
# Starting distance: 0.05730082944993071
# Final distance 0.00892625949116484
# Final relative distance 0.1557788879646948
# Min relative distance 0.1557788879646948
# Min simulation: 40
# Final simulation: 40
# Min distance 0.00892625949116484
# 40
# Time taken: 15.454273223876953
#  **** idx **** 65
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.29052932 0.40853117] [1.27568773 0.42859821]
# Starting distance: 0.024959143202153783
# Final distance 0.01011227620654344
# Final relative distance 0.40515317872253037
# Min relative distance 0.40515317872253037
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01011227620654344
# 40
# Time taken: 15.66369891166687
#  **** idx **** 66
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.29869525 0.40196204] [1.29052932 0.40853117]
# Starting distance: 0.010480260933085546
# Final distance 0.01268450220524969
# Final relative distance 1.2103231289981997
# Min relative distance 1.2103231289981997
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01268450220524969
# 40
# Time taken: 14.992420673370361
#  **** idx **** 67
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.35975951 0.41505107] [1.29869525 0.40196204]
# Starting distance: 0.062451308617837806
# Final distance 0.012665920787018286
# Final relative distance 0.20281273631151026
# Min relative distance 0.20281273631151026
# Min simulation: 40
# Final simulation: 40
# Min distance 0.012665920787018286
# 40
# Time taken: 14.92554235458374
#  **** idx **** 68
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.2880303  0.38387875] [1.35975951 0.41505107]
# Starting distance: 0.07820992726740508
# Final distance 0.011106721614564944
# Final relative distance 0.14201166018976472
# Min relative distance 0.14201166018976472
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011106721614564944
# 40
# Time taken: 14.74466586112976
#  **** idx **** 69
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.27642758 0.37750389] [1.2880303  0.38387875]
# Starting distance: 0.01323865561663697
# Final distance 0.010524156994136322
# Final relative distance 0.7949566254227999
# Min relative distance 0.7949566254227999
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010524156994136322
# 40
# Time taken: 15.156612634658813
#  **** idx **** 70
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.31507231 0.4001258 ] [1.27642758 0.37750389]
# Starting distance: 0.04477908056803833
# Final distance 0.013830064569048594
# Final relative distance 0.3088510168947057
# Min relative distance 0.3088510168947057
# Min simulation: 40
# Final simulation: 40
# Min distance 0.013830064569048594
# 40
# Time taken: 15.69936227798462
#  **** idx **** 71
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.31475075 0.34837954] [1.31507231 0.4001258 ]
# Starting distance: 0.05174725343487772
# Final distance 0.019288053231594795
# Final relative distance 0.37273578695086107
# Min relative distance 0.37273578695086107
# Min simulation: 40
# Final simulation: 40
# Min distance 0.019288053231594795
# 40
# Time taken: 16.06872320175171
#  **** idx **** 72
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.27556894 0.35670415] [1.31475075 0.34837954]
# Starting distance: 0.04005637320020784
# Final distance 0.010482302077108341
# Final relative distance 0.26168874612577137
# Min relative distance 0.26168874612577137
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010482302077108341
# 40
# Time taken: 15.356528759002686
#  **** idx **** 73
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.24645998 0.35452917] [1.27556894 0.35670415]
# Starting distance: 0.029190100917087566
# Final distance 0.009665813341735989
# Final relative distance 0.33113326223814893
# Min relative distance 0.33113326223814893
# Min simulation: 40
# Final simulation: 40
# Min distance 0.009665813341735989
# 40
# Time taken: 15.997268915176392
#  **** idx **** 74
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.2267031  0.32283044] [1.24645998 0.35452917]
# Starting distance: 0.03735162682769026
# Final distance 0.018554370672740694
# Final relative distance 0.49674866260405004
# Min relative distance 0.49674866260405004
# Min simulation: 40
# Final simulation: 40
# Min distance 0.018554370672740694
# 40
# Time taken: 16.09601855278015
#  **** idx **** 75
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.2521094 0.2700528] [1.2267031  0.32283044]
# Starting distance: 0.05857438169089101
# Final distance 0.011480459985726986
# Final relative distance 0.19599797137102906
# Min relative distance 0.19599797137102906
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011480459985726986
# 40
# Time taken: 15.458086729049683
#  **** idx **** 76
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.19736461 0.32009137] [1.2521094 0.2700528]
# Starting distance: 0.07416770868402014
# Final distance 0.017441964144465177
# Final relative distance 0.23516924621163532
# Min relative distance 0.23516924621163532
# Min simulation: 40
# Final simulation: 40
# Min distance 0.017441964144465177
# 40
# Time taken: 15.667934894561768
#  **** idx **** 77
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.16541824 0.18580586] [1.19736461 0.32009137]
# Starting distance: 0.13803321464035245
# Final distance 0.04385185251516492
# Final relative distance 0.31769058359918345
# Min relative distance 0.31769058359918345
# Min simulation: 40
# Final simulation: 40
# Min distance 0.04385185251516492
# 40
# Time taken: 16.47999382019043
#  **** idx **** 78
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.2035023  0.14316522] [1.16541824 0.18580586]
# Starting distance: 0.057171851203356217
# Final distance 0.06930756774324813
# Final relative distance 1.212267335838506
# Min relative distance 1.212267335838506
# Min simulation: 40
# Final simulation: 40
# Min distance 0.06930756774324813
# 40
# Time taken: 16.628254175186157
#  **** idx **** 79
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.23367735 0.24737606] [1.2035023  0.14316522]
# Starting distance: 0.10849163208985
# Final distance 0.013644809340073814
# Final relative distance 0.12576831113365067
# Min relative distance 0.12576831113365067
# Min simulation: 40
# Final simulation: 40
# Min distance 0.013644809340073814
# 40
# Time taken: 16.632826328277588
#  **** idx **** 80
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.01860928 0.00150955] [1.23367735 0.24737606]
# Starting distance: 0.32665672696375253
# Final distance 0.02655848379017485
# Final relative distance 0.08130395487958805
# Min relative distance 0.08130395487958805
# Min simulation: 40
# Final simulation: 40
# Min distance 0.02655848379017485
# 40
# Time taken: 16.393364906311035
#  **** idx **** 81
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.04676216 -0.03525539] [1.01860928 0.00150955]
# Starting distance: 0.046306002747584514
# Final distance 0.02253610612553316
# Final relative distance 0.4866778557496787
# Min relative distance 0.4866778557496787
# Min simulation: 40
# Final simulation: 40
# Min distance 0.02253610612553316
# 40
# Time taken: 16.1498384475708
#  **** idx **** 82
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.12426449 0.03925955] [ 1.04676216 -0.03525539]
# Starting distance: 0.10751319633487075
# Final distance 0.07293123524208979
# Final relative distance 0.6783468237232133
# Min relative distance 0.6783468237232133
# Min simulation: 40
# Final simulation: 40
# Min distance 0.07293123524208979
# 40
# Time taken: 16.663537740707397
#  **** idx **** 83
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.10731512 -0.10037168] [1.12426449 0.03925955]
# Starting distance: 0.14065618284616005
# Final distance 0.019659420724234038
# Final relative distance 0.13976933204376907
# Min relative distance 0.13976933204376907
# Min simulation: 40
# Final simulation: 40
# Min distance 0.019659420724234038
# 40
# Time taken: 15.877581596374512
#  **** idx **** 84
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.2065712  0.00378399] [ 1.10731512 -0.10037168]
# Starting distance: 0.1438755513933956
# Final distance 0.045438088376980594
# Final relative distance 0.3158152162540825
# Min relative distance 0.3158152162540825
# Min simulation: 40
# Final simulation: 40
# Min distance 0.045438088376980594
# 40
# Time taken: 16.473960161209106
#  **** idx **** 85
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.17426218 -0.11719396] [1.2065712  0.00378399]
# Starting distance: 0.12521796604372615
# Final distance 0.031673596586853925
# Final relative distance 0.25294770061824434
# Min relative distance 0.25294770061824434
# Min simulation: 40
# Final simulation: 40
# Min distance 0.031673596586853925
# 40
# Time taken: 16.575950860977173
#  **** idx **** 86
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.25457217 0.06087007] [ 1.17426218 -0.11719396]
# Starting distance: 0.1953368771228048
# Final distance 0.0642490709001653
# Final relative distance 0.32891419094292706
# Min relative distance 0.32891419094292706
# Min simulation: 40
# Final simulation: 40
# Min distance 0.0642490709001653
# 40
# Time taken: 16.229398250579834
#  **** idx **** 87
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.24069008 0.06132292] [1.25457217 0.06087007]
# Starting distance: 0.01388947537276067
# Final distance 0.0649062579851295
# Final relative distance 4.673053246663322
# Min relative distance 4.673053246663322
# Min simulation: 40
# Final simulation: 40
# Min distance 0.0649062579851295
# 40
# Time taken: 15.511981010437012
#  **** idx **** 88
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.27500274 0.22581111] [1.24069008 0.06132292]
# Starting distance: 0.16802893405636624
# Final distance 0.02515509180275249
# Final relative distance 0.14970690580179527
# Min relative distance 0.14970690580179527
# Min simulation: 40
# Final simulation: 40
# Min distance 0.02515509180275249
# 40
# Time taken: 15.520944595336914
#  **** idx **** 89
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.36779907 0.24303639] [1.27500274 0.22581111]
# Starting distance: 0.09438151009132138
# Final distance 0.03500063535639791
# Final relative distance 0.37084207831101773
# Min relative distance 0.37084207831101773
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03500063535639791
# 40
# Time taken: 16.16687321662903
#  **** idx **** 90
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.29475913 0.29031147] [1.36779907 0.24303639]
# Starting distance: 0.08700440324030138
# Final distance 0.01341057185629375
# Final relative distance 0.1541367029350743
# Min relative distance 0.1541367029350743
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01341057185629375
# 40
# Time taken: 16.11514949798584
#  **** idx **** 91
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.35695639 0.31464925] [1.29475913 0.29031147]
# Starting distance: 0.06678942143497454
# Final distance 0.019828421516969192
# Final relative distance 0.2968796718245857
# Min relative distance 0.2968796718245857
# Min simulation: 40
# Final simulation: 40
# Min distance 0.019828421516969192
# 40
# Time taken: 16.208330631256104
#  **** idx **** 92
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.40058532 0.38171983] [1.35695639 0.31464925]
# Starting distance: 0.08001217002922995
# Final distance 0.012979184805591635
# Final relative distance 0.16221513303351345
# Min relative distance 0.16221513303351345
# Min simulation: 40
# Final simulation: 40
# Min distance 0.012979184805591635
# 40
# Time taken: 16.214158296585083
#  **** idx **** 93
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.34265575 0.35547946] [1.40058532 0.38171983]
# Starting distance: 0.06359553571403392
# Final distance 0.01832464934695231
# Final relative distance 0.2881436431222408
# Min relative distance 0.2881436431222408
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01832464934695231
# 40
# Time taken: 16.502580881118774
#  **** idx **** 94
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.41552512 0.35393745] [1.34265575 0.35547946]
# Starting distance: 0.07288568102289611
# Final distance 0.03550955698589925
# Final relative distance 0.4871952417477498
# Min relative distance 0.4871952417477498
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03550955698589925
# 40
# Time taken: 15.425407409667969
#  **** idx **** 95
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.39362471 0.38819728] [1.41552512 0.35393745]
# Starting distance: 0.04066157354104898
# Final distance 0.010654404551098094
# Final relative distance 0.26202637092591063
# Min relative distance 0.26202637092591063
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010654404551098094
# 40
# Time taken: 16.057593822479248
#  **** idx **** 96
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.35801359 0.3868773 ] [1.39362471 0.38819728]
# Starting distance: 0.03563557510207891
# Final distance 0.010638837182535056
# Final relative distance 0.2985454044745978
# Min relative distance 0.2985454044745978
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010638837182535056
# 40
# Time taken: 15.819777488708496
#  **** idx **** 97
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.38331057 0.40008467] [1.35801359 0.3868773 ]
# Starting distance: 0.028537204388590625
# Final distance 0.01169385068649103
# Final relative distance 0.4097756222808676
# Min relative distance 0.4097756222808676
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01169385068649103
# 40
# Time taken: 16.487948894500732
#  **** idx **** 98
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.36990603 0.41964771] [1.38331057 0.40008467]
# Starting distance: 0.02371485191248769
# Final distance 0.011806935556460186
# Final relative distance 0.4978709375892382
# Min relative distance 0.4978709375892382
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011806935556460186
# 40
# Time taken: 16.211365938186646
#  **** idx **** 99
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.38526542 0.41849282] [1.36990603 0.41964771]
# Starting distance: 0.015402751036294602
# Final distance 0.01383524239847016
# Final relative distance 0.8982319045389483
# Min relative distance 0.8982319045389483
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01383524239847016
# 40
# Time taken: 16.277930974960327
#  **** idx **** 100
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.40353731 0.4170623 ] [1.38526542 0.41849282]
# Starting distance: 0.018327795931026004
# Final distance 0.014741404194788605
# ...
# Min relative distance 0.39951728894819855
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03604232834092072
# 40
# Time taken: 16.048035144805908
#  **** idx **** 114
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.46653305 0.34538077] [1.43227099 0.34529359]
# Starting distance: 0.034262168754679766
# Final distance 0.042025815771525456
# Final relative distance 1.226595317781373
# Min relative distance 1.226595317781373
# Min simulation: 40
# Final simulation: 40
# Min distance 0.042025815771525456
# 40
# Time taken: 16.411300897598267
#  **** idx **** 115
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.55260647 0.39465514] [1.46653305 0.34538077]
# Starting distance: 0.09917962104061827
# Final distance 0.03225988455469543
# Final relative distance 0.3252672697900674
# Min relative distance 0.3252672697900674
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03225988455469543
# 40
# Time taken: 15.684895753860474
#  **** idx **** 116
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.44657209 0.30670217] [1.55260647 0.39465514]
# Starting distance: 0.13776433834744164
# Final distance 0.038378477984364424
# Final relative distance 0.27858064318193804
# Min relative distance 0.27858064318193804
# Min simulation: 40
# Final simulation: 40
# Min distance 0.038378477984364424
# 40
# Time taken: 16.575365781784058
#  **** idx **** 117
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.50682121 0.27884888] [1.44657209 0.30670217]
# Starting distance: 0.06637591275329748
# Final distance 0.06879256442826465
# Final relative distance 1.0364085641119432
# Min relative distance 1.0364085641119432
# Min simulation: 40
# Final simulation: 40
# Min distance 0.06879256442826465
# 40
# Time taken: 15.985034465789795
#  **** idx **** 118
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.49663048 0.3213161 ] [1.50682121 0.27884888]
# Starting distance: 0.04367282701100765
# Final distance 0.05200265739466764
# Final relative distance 1.1907325665352617
# Min relative distance 1.1907325665352617
# Min simulation: 40
# Final simulation: 40
# Min distance 0.05200265739466764
# 40
# Time taken: 16.294757843017578
#  **** idx **** 119
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.35543425 0.15588752] [1.49663048 0.3213161 ]
# Starting distance: 0.21749250460076763
# Final distance 0.08009080445179297
# Final relative distance 0.36824627404428856
# Min relative distance 0.36824627404428856
# Min simulation: 40
# Final simulation: 40
# Min distance 0.08009080445179297
# 40
# Time taken: 16.49782943725586
#  **** idx **** 120
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.3050456 0.0069696] [1.35543425 0.15588752]
# Starting distance: 0.15721184192781984
# Final distance 0.05599169677601167
# Final relative distance 0.3561544479691228
# Min relative distance 0.3561544479691228
# Min simulation: 40
# Final simulation: 40
# Min distance 0.05599169677601167
# 40
# Time taken: 15.62401008605957
#  **** idx **** 121
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.37609198 0.02071569] [1.3050456 0.0069696]
# Starting distance: 0.0723639674351835
# Final distance 0.07197148400388637
# Final relative distance 0.9945762588038214
# Min relative distance 0.9945762588038214
# Min simulation: 40
# Final simulation: 40
# Min distance 0.07197148400388637
# 40
# Time taken: 15.889439582824707
#  **** idx **** 122
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.24015669 -0.13215334] [1.37609198 0.02071569]
# Starting distance: 0.20456623429343956
# Final distance 0.01873051824025602
# Final relative distance 0.0915621207231496
# Min relative distance 0.0915621207231496
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01873051824025602
# 40
# Time taken: 15.065842866897583
#  **** idx **** 123
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.25053274 -0.03132028] [ 1.24015669 -0.13215334]
# Starting distance: 0.10136552232833133
# Final distance 0.03476536897266183
# Final relative distance 0.34297035297715844
# Min relative distance 0.34297035297715844
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03476536897266183
# 40
# Time taken: 15.426944255828857
#  **** idx **** 124
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.23856939 -0.07367112] [ 1.25053274 -0.03132028]
# Starting distance: 0.04400813696421406
# Final distance 0.024346610576945097
# Final relative distance 0.5532297492334871
# Min relative distance 0.5532297492334871
# Min simulation: 40
# Final simulation: 40
# Min distance 0.024346610576945097
# 40
# Time taken: 16.004839420318604
#  **** idx **** 125
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.2762257 -0.1981629] [ 1.23856939 -0.07367112]
# Starting distance: 0.13006229653679088
# Final distance 0.03678637985249179
# Final relative distance 0.2828366162370967
# Min relative distance 0.2828366162370967
# Min simulation: 40
# Final simulation: 40
# Min distance 0.03678637985249179
# 40
# Time taken: 15.953868389129639
#  **** idx **** 126
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.28200571 -0.21964702] [ 1.2762257 -0.1981629]
# Starting distance: 0.022248055962597324
# Final distance 0.04562050819030404
# Final relative distance 2.0505390793244898
# Min relative distance 2.0505390793244898
# Min simulation: 40
# Final simulation: 40
# Min distance 0.04562050819030404
# 40
# Time taken: 15.878495216369629
#  **** idx **** 127
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.3054284  -0.22053299] [ 1.28200571 -0.21964702]
# Starting distance: 0.023439432920624035
# Final distance 0.04684904947326366
# Final relative distance 1.9987279398744253
# Min relative distance 1.9987279398744253
# Min simulation: 40
# Final simulation: 40
# Min distance 0.04684904947326366
# 40
# Time taken: 15.781792640686035
#  **** idx **** 128
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.3741712 -0.0631134] [ 1.3054284  -0.22053299]
# Starting distance: 0.17177455885145945
# Final distance 0.05501107721015939
# Final relative distance 0.3202515994101882
# Min relative distance 0.3202515994101882
# Min simulation: 40
# Final simulation: 40
# Min distance 0.05501107721015939
# 40
# Time taken: 16.38494086265564
#  **** idx **** 129
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [ 1.49044462 -0.00257136] [ 1.3741712 -0.0631134]
# Starting distance: 0.13109099126920912
# Final distance 0.09312443761976956
# Final relative distance 0.7103801467831512
# Min relative distance 0.7103801467831512
# Min simulation: 40
# Final simulation: 40
# Min distance 0.09312443761976956
# 40
# Time taken: 16.49392056465149
#  **** idx **** 130
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.40377198 0.00533668] [ 1.49044462 -0.00257136]
# Starting distance: 0.0870326639846629
# Final distance 0.07688423520958954
# Final relative distance 0.8833951724508657
# Min relative distance 0.8833951724508657
# Min simulation: 40
# Final simulation: 40
# Min distance 0.07688423520958954
# 40
# Time taken: 17.271567583084106
#  **** idx **** 131
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.51108568 0.12229943] [1.40377198 0.00533668]
# Starting distance: 0.15873410967987248
# Final distance 0.10896525836116641
# Final relative distance 0.686464040910441
# Min relative distance 0.686464040910441
# Min simulation: 40
# Final simulation: 40
# Min distance 0.10896525836116641
# 40
# Time taken: 16.297653675079346
#  **** idx **** 132
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.50620943 0.12720666] [1.51108568 0.12229943]
# Starting distance: 0.00691799699710459
# Final distance 0.10773812055432735
# Final relative distance 15.57360036429899
# Min relative distance 15.57360036429899
# Min simulation: 40
# Final simulation: 40
# Min distance 0.10773812055432735
# 40
# Time taken: 17.067841291427612
#  **** idx **** 133
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.56898781 0.20594204] [1.50620943 0.12720666]
# Starting distance: 0.10069948854450089
# Final distance 0.1332045229705306
# Final relative distance 1.3227924480635782
# Min relative distance 1.3227924480635782
# Min simulation: 40
# Final simulation: 40
# Min distance 0.1332045229705306
# 40
# Time taken: 15.854339599609375
#  **** idx **** 134
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.60799239 0.38788534] [1.56898781 0.20594204]
# Starting distance: 0.1860771863266392
# Final distance 0.0656525399714248
# Final relative distance 0.3528242299202578
# Min relative distance 0.3528242299202578
# Min simulation: 40
# Final simulation: 40
# Min distance 0.0656525399714248
# 40
# Time taken: 16.62045693397522
#  **** idx **** 135
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.66961418 0.395214  ] [1.60799239 0.38788534]
# Starting distance: 0.06205605421483079
# Final distance 0.10151820012367894
# Final relative distance 1.635911296780727
# Min relative distance 1.635911296780727
# Min simulation: 40
# Final simulation: 40
# Min distance 0.10151820012367894
# 40
# Time taken: 16.04137372970581
#  **** idx **** 136
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.69174866 0.44790464] [1.66961418 0.395214  ]
# Starting distance: 0.05715102076407568
# Final distance 0.050255214730232395
# Final relative distance 0.8793406322118066
# Min relative distance 0.8793406322118066
# Min simulation: 40
# Final simulation: 40
# Min distance 0.050255214730232395
# 40
# Time taken: 16.458823204040527
#  **** idx **** 137
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.61341504 0.44933651] [1.69174866 0.44790464]
# Starting distance: 0.0783467064590852
# Final distance 0.010148101997931099
# Final relative distance 0.12952812513223788
# Min relative distance 0.12952812513223788
# Min simulation: 40
# Final simulation: 40
# Min distance 0.010148101997931099
# 40
# Time taken: 16.8819842338562
#  **** idx **** 138
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.71454953 0.49729919] [1.61341504 0.44933651]
# Starting distance: 0.11193124865289623
# Final distance 0.028067068766361402
# Final relative distance 0.2507527531779675
# Min relative distance 0.2507527531779675
# Min simulation: 40
# Final simulation: 40
# Min distance 0.028067068766361402
# 40
# Time taken: 17.113236665725708
#  **** idx **** 139
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.60109709 0.42861817] [1.71454953 0.49729919]
# Starting distance: 0.13262178955030365
# Final distance 0.013766121481103335
# Final relative distance 0.10379984712754779
# Min relative distance 0.10379984712754779
# Min simulation: 40
# Final simulation: 40
# Min distance 0.013766121481103335
# 40
# Time taken: 16.242095947265625
#  **** idx **** 140
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.70610814 0.52598615] [1.60109709 0.42861817]
# Starting distance: 0.14320560337492522
# Final distance 0.01637581955970237
# Final relative distance 0.11435180728807794
# Min relative distance 0.11435180728807794
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01637581955970237
# 40
# Time taken: 17.174622774124146
#  **** idx **** 141
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.73024704 0.53114386] [1.70610814 0.52598615]
# Starting distance: 0.024683763769011432
# Final distance 0.025381499816599706
# Final relative distance 1.0282670039349602
# Min relative distance 1.0282670039349602
# Min simulation: 40
# Final simulation: 40
# Min distance 0.025381499816599706
# 40
# Time taken: 17.415550708770752
#  **** idx **** 142
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.72472778 0.52768249] [1.73024704 0.53114386]
# Starting distance: 0.006514852698989697
# Final distance 0.026150184602276947
# Final relative distance 4.013933362811447
# Min relative distance 4.013933362811447
# Min simulation: 40
# Final simulation: 40
# Min distance 0.026150184602276947
# 40
# Time taken: 17.720325469970703
#  **** idx **** 143
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.66600691 0.5256852 ] [1.72472778 0.52768249]
# Starting distance: 0.05875482904719721
# Final distance 0.011089466330907974
# Final relative distance 0.18874135982933263
# Min relative distance 0.18874135982933263
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011089466330907974
# 40
# Time taken: 16.388002634048462
#  **** idx **** 144
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.63452221 0.51060761] [1.66600691 0.5256852 ]
# Starting distance: 0.03490874307551443
# Final distance 0.011454972151765662
# Final relative distance 0.3281404926836329
# Min relative distance 0.3281404926836329
# Min simulation: 40
# Final simulation: 40
# Min distance 0.011454972151765662
# 40
# Time taken: 16.70423460006714
#  **** idx **** 145
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [1.68116561 0.53597109] [1.63452221 0.51060761]
# Starting distance: 0.05309343656026774
# Final distance 0.01055826442721325
# Final relative distance 0.19886195189547184
# Min relative distance 0.19886195189547184
# Min simulation: 40
# Final simulation: 40
# Min distance 0.01055826442721325
# 40
# Time taken: 17.470005989074707
#  **** idx **** 146
# 71
# /home/manishg/Research/NExG//eval-emsoft/eval-non-gr/models/model_vp_2_v_OtherBenchC2_RBF_1_512_ReLU.h5
# ***** path idx 0 correction steps 1
# [0.8415137  0.31085446] [1.68116561 0.53597109]
# Starting distance: 0.8693059476913667
# Final distance 0.014788197553114215
# Final relative distance 0.017011499337359338
# Min relative distance 0.017011499337359338
# Min simulation: 40
# Final simulation: 40
# Min distance 0.014788197553114215
# 40
# Time taken: 17.099690675735474
# 147 147
#  Mean final distance 0.02368730312128923
#  Mean simulations count 38.945945945945944
